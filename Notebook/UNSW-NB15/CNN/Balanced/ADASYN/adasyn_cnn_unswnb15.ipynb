# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 6
# 5

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']
# ['INT' 'FIN' 'CON' 'REQ' 'RST']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'ACC') & (data_train_attack['state'] != 'CLO')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'RST')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 181, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Split Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((45329, 181), (45329,), (119329, 181), (119329,))

# %% [markdown]
# ## ADASYN

# %%
from imblearn.over_sampling import ADASYN

adasyn = ADASYN()
X_adasyn, y_adasyn = adasyn.fit_resample(X_train, y_train)

X_adasyn.shape, y_adasyn.shape
# Out:
# ((169025, 181), (169025,))

# %%
#Create new dataframe from X_adasyn and y_adasyn to count every attack
data_adasyn = pd.concat([X_adasyn, y_adasyn], axis=1)

sns.countplot(data=data_adasyn, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Reconnaissance'),
#   Text(1, 0, 'Backdoor'),
#   Text(2, 0, 'DoS'),
#   Text(3, 0, 'Exploits'),
#   Text(4, 0, 'Analysis'),
#   Text(5, 0, 'Fuzzers'),
#   Text(6, 0, 'Worms'),
#   Text(7, 0, 'Shellcode'),
#   Text(8, 0, 'Generic')])

# %%
#data_adasyn.drop_duplicates(inplace=True)
print(data_adasyn.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_adasyn.shape))
print("--------------------")
print("Duplicates: " + str(data_adasyn.duplicated().sum()))
# Out:
# attack_cat
# Reconnaissance    19030
# Backdoor          18892
# Generic           18871
# Worms             18866
# Shellcode         18828
# Analysis          18732
# DoS               18730
# Exploits          18679
# Fuzzers           18397
# Name: count, dtype: int64
# --------------------
# Shape: (169025, 182)
# --------------------
# Duplicates: 45032

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (181, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall()])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 177, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 176, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5632)              0
#
#  batch_normalization (BatchN  (None, 5632)             22528
#  ormalization)
#
#  dropout (Dropout)           (None, 5632)              0
#
#  dense (Dense)               (None, 32)                180256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 203,657
# Trainable params: 192,393
# Non-trainable params: 11,264
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_adasyn = le.fit_transform(y_adasyn)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_adasyn = to_categorical(y_adasyn, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_adasyn = np.array(X_adasyn, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_adasyn, y_adasyn, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5283/5283 [==============================] - 51s 9ms/step - loss: 1.1037 - accuracy: 0.5538 - recall: 0.3680 - val_loss: 1.3763 - val_accuracy: 0.5812 - val_recall: 0.5473
# Epoch 2/50
# 5283/5283 [==============================] - 47s 9ms/step - loss: 0.9752 - accuracy: 0.5979 - recall: 0.4381 - val_loss: 0.9527 - val_accuracy: 0.6567 - val_recall: 0.5965
# Epoch 3/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.9412 - accuracy: 0.6098 - recall: 0.4572 - val_loss: 1.7264 - val_accuracy: 0.5777 - val_recall: 0.5430
# Epoch 4/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.9210 - accuracy: 0.6182 - recall: 0.4704 - val_loss: 0.9852 - val_accuracy: 0.6587 - val_recall: 0.5860
# Epoch 5/50
# 5283/5283 [==============================] - 47s 9ms/step - loss: 0.9078 - accuracy: 0.6228 - recall: 0.4786 - val_loss: 1.0722 - val_accuracy: 0.6419 - val_recall: 0.5670
# Epoch 6/50
# 5283/5283 [==============================] - 51s 10ms/step - loss: 0.8970 - accuracy: 0.6273 - recall: 0.4856 - val_loss: 1.7263 - val_accuracy: 0.5574 - val_recall: 0.5315
# Epoch 7/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.8879 - accuracy: 0.6308 - recall: 0.4932 - val_loss: 0.9708 - val_accuracy: 0.6768 - val_recall: 0.6083
# Epoch 8/50
# 5283/5283 [==============================] - 47s 9ms/step - loss: 0.8761 - accuracy: 0.6369 - recall: 0.4993 - val_loss: 0.9424 - val_accuracy: 0.6693 - val_recall: 0.6015
# Epoch 9/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8691 - accuracy: 0.6414 - recall: 0.5066 - val_loss: 1.0261 - val_accuracy: 0.6549 - val_recall: 0.5950
# Epoch 10/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8606 - accuracy: 0.6461 - recall: 0.5131 - val_loss: 1.0183 - val_accuracy: 0.6512 - val_recall: 0.5901
# Epoch 11/50
# 5283/5283 [==============================] - 45s 9ms/step - loss: 0.8541 - accuracy: 0.6477 - recall: 0.5169 - val_loss: 1.1337 - val_accuracy: 0.6253 - val_recall: 0.5792
# Epoch 12/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8471 - accuracy: 0.6514 - recall: 0.5207 - val_loss: 1.0718 - val_accuracy: 0.6491 - val_recall: 0.5842
# Epoch 13/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8419 - accuracy: 0.6536 - recall: 0.5229 - val_loss: 1.0744 - val_accuracy: 0.6582 - val_recall: 0.5900
# Epoch 14/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.8379 - accuracy: 0.6549 - recall: 0.5244 - val_loss: 1.0693 - val_accuracy: 0.6631 - val_recall: 0.6077
# Epoch 15/50
# 5283/5283 [==============================] - 56s 11ms/step - loss: 0.8346 - accuracy: 0.6571 - recall: 0.5271 - val_loss: 0.9907 - val_accuracy: 0.6713 - val_recall: 0.6053
# Epoch 16/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.8313 - accuracy: 0.6575 - recall: 0.5293 - val_loss: 0.9847 - val_accuracy: 0.6731 - val_recall: 0.5982
# Epoch 17/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8288 - accuracy: 0.6588 - recall: 0.5295 - val_loss: 1.1244 - val_accuracy: 0.6420 - val_recall: 0.5870
# Epoch 18/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8278 - accuracy: 0.6591 - recall: 0.5315 - val_loss: 1.0857 - val_accuracy: 0.6575 - val_recall: 0.5885
# Epoch 19/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8257 - accuracy: 0.6597 - recall: 0.5337 - val_loss: 1.0033 - val_accuracy: 0.6727 - val_recall: 0.6070
# Epoch 20/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.8236 - accuracy: 0.6601 - recall: 0.5329 - val_loss: 1.0114 - val_accuracy: 0.6649 - val_recall: 0.5960
# Epoch 21/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8209 - accuracy: 0.6622 - recall: 0.5343 - val_loss: 1.1735 - val_accuracy: 0.6355 - val_recall: 0.5655
# Epoch 22/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8184 - accuracy: 0.6625 - recall: 0.5354 - val_loss: 1.3477 - val_accuracy: 0.5988 - val_recall: 0.5643
# Epoch 23/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8181 - accuracy: 0.6634 - recall: 0.5361 - val_loss: 1.0427 - val_accuracy: 0.6635 - val_recall: 0.5982
# Epoch 24/50
# 5283/5283 [==============================] - 47s 9ms/step - loss: 0.8173 - accuracy: 0.6628 - recall: 0.5364 - val_loss: 0.9988 - val_accuracy: 0.6753 - val_recall: 0.6148
# Epoch 25/50
# 5283/5283 [==============================] - 47s 9ms/step - loss: 0.8153 - accuracy: 0.6638 - recall: 0.5376 - val_loss: 1.0294 - val_accuracy: 0.6699 - val_recall: 0.6211
# Epoch 26/50
# 5283/5283 [==============================] - 47s 9ms/step - loss: 0.8152 - accuracy: 0.6641 - recall: 0.5373 - val_loss: 1.0283 - val_accuracy: 0.6596 - val_recall: 0.6029
# Epoch 27/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8127 - accuracy: 0.6647 - recall: 0.5390 - val_loss: 1.0154 - val_accuracy: 0.6705 - val_recall: 0.6048
# Epoch 28/50
# 5283/5283 [==============================] - 56s 11ms/step - loss: 0.8147 - accuracy: 0.6644 - recall: 0.5383 - val_loss: 1.0725 - val_accuracy: 0.6587 - val_recall: 0.5985
# Epoch 29/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.8117 - accuracy: 0.6656 - recall: 0.5401 - val_loss: 1.0509 - val_accuracy: 0.6602 - val_recall: 0.6126
# Epoch 30/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8093 - accuracy: 0.6660 - recall: 0.5413 - val_loss: 1.0598 - val_accuracy: 0.6565 - val_recall: 0.6012
# Epoch 31/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8090 - accuracy: 0.6665 - recall: 0.5410 - val_loss: 1.0126 - val_accuracy: 0.6671 - val_recall: 0.6000
# Epoch 32/50
# 5283/5283 [==============================] - 45s 9ms/step - loss: 0.8119 - accuracy: 0.6659 - recall: 0.5409 - val_loss: 1.0687 - val_accuracy: 0.6565 - val_recall: 0.5973
# Epoch 33/50
# 5283/5283 [==============================] - 47s 9ms/step - loss: 0.8080 - accuracy: 0.6670 - recall: 0.5421 - val_loss: 1.0533 - val_accuracy: 0.6605 - val_recall: 0.6043
# Epoch 34/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8092 - accuracy: 0.6660 - recall: 0.5419 - val_loss: 1.0322 - val_accuracy: 0.6636 - val_recall: 0.6079
# Epoch 35/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8071 - accuracy: 0.6673 - recall: 0.5414 - val_loss: 1.0023 - val_accuracy: 0.6723 - val_recall: 0.6084
# Epoch 36/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8067 - accuracy: 0.6672 - recall: 0.5423 - val_loss: 0.9693 - val_accuracy: 0.6740 - val_recall: 0.6075
# Epoch 37/50
# 5283/5283 [==============================] - 46s 9ms/step - loss: 0.8056 - accuracy: 0.6682 - recall: 0.5439 - val_loss: 0.9988 - val_accuracy: 0.6616 - val_recall: 0.6094
# Epoch 38/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8034 - accuracy: 0.6686 - recall: 0.5456 - val_loss: 0.9901 - val_accuracy: 0.6701 - val_recall: 0.6158
# Epoch 39/50
# 5283/5283 [==============================] - 45s 9ms/step - loss: 0.8040 - accuracy: 0.6679 - recall: 0.5445 - val_loss: 1.0527 - val_accuracy: 0.6573 - val_recall: 0.6020
# Epoch 40/50
# 5283/5283 [==============================] - 45s 8ms/step - loss: 0.8053 - accuracy: 0.6685 - recall: 0.5440 - val_loss: 1.0787 - val_accuracy: 0.6476 - val_recall: 0.5819
# Epoch 41/50
# 5283/5283 [==============================] - 45s 9ms/step - loss: 0.8036 - accuracy: 0.6683 - recall: 0.5442 - val_loss: 0.9781 - val_accuracy: 0.6864 - val_recall: 0.6207
# Epoch 42/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8019 - accuracy: 0.6681 - recall: 0.5440 - val_loss: 1.0225 - val_accuracy: 0.6655 - val_recall: 0.5984
# Epoch 43/50
# 5283/5283 [==============================] - 51s 10ms/step - loss: 0.8022 - accuracy: 0.6698 - recall: 0.5445 - val_loss: 1.0021 - val_accuracy: 0.6702 - val_recall: 0.6055
# Epoch 44/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.8010 - accuracy: 0.6686 - recall: 0.5450 - val_loss: 0.9676 - val_accuracy: 0.6875 - val_recall: 0.6268
# Epoch 45/50
# 5283/5283 [==============================] - 48s 9ms/step - loss: 0.8018 - accuracy: 0.6686 - recall: 0.5446 - val_loss: 1.0270 - val_accuracy: 0.6542 - val_recall: 0.5850
# Epoch 46/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.7995 - accuracy: 0.6704 - recall: 0.5473 - val_loss: 1.0260 - val_accuracy: 0.6694 - val_recall: 0.6096
# Epoch 47/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.7992 - accuracy: 0.6688 - recall: 0.5468 - val_loss: 1.0586 - val_accuracy: 0.6636 - val_recall: 0.6037
# Epoch 48/50
# 5283/5283 [==============================] - 50s 9ms/step - loss: 0.7999 - accuracy: 0.6696 - recall: 0.5455 - val_loss: 0.9906 - val_accuracy: 0.6740 - val_recall: 0.6255
# Epoch 49/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.7985 - accuracy: 0.6692 - recall: 0.5468 - val_loss: 1.0572 - val_accuracy: 0.6497 - val_recall: 0.5891
# Epoch 50/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.7964 - accuracy: 0.6710 - recall: 0.5472 - val_loss: 1.0127 - val_accuracy: 0.6624 - val_recall: 0.6070

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall = model.evaluate(X_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
# Out:
# 3730/3730 [==============================] - 16s 4ms/step - loss: 1.0127 - accuracy: 0.6624 - recall: 0.6070
# Test Loss: 1.0126603841781616
# Test Accuracy: 0.6624458432197571
# Test Recall: 0.6070108413696289

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 3730/3730 [==============================] - 7s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.1915
# Backdoor: 0.1311569301260023
# DoS: 0.5780459957592562
# Exploits: 0.4037620559515965
# Fuzzers: 0.7131544214694236
# Generic: 0.977974449361234
# Reconnaissance: 0.4723043188101821
# Shellcode: 0.6725507502206531
# Worms: 0.5153846153846153

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import pickle

# %%
# save the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/predicted_classes.pkl', 'wb') as model_file:
    pickle.dump(predicted_classes, model_file)

# %%
# load the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/predicted_classes.pkl', 'rb') as model_file:
    predicted_classes = pickle.load(model_file)
