# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall, Precision

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 6
# 5

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']
# ['INT' 'FIN' 'CON' 'REQ' 'RST']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'ACC') & (data_train_attack['state'] != 'CLO')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'RST')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 181, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Initialize Train Data and Test Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((45329, 181), (45329,), (119329, 181), (119329,))

# %% [markdown]
# ## ADASYN

# %%
from imblearn.over_sampling import ADASYN

adasyn = ADASYN()
X_adasyn, y_adasyn = adasyn.fit_resample(X_train, y_train)

X_adasyn.shape, y_adasyn.shape
# Out:
# ((169025, 181), (169025,))

# %%
#Create new dataframe from X_adasyn and y_adasyn to count every attack
data_adasyn = pd.concat([X_adasyn, y_adasyn], axis=1)

sns.countplot(data=data_adasyn, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Reconnaissance'),
#   Text(1, 0, 'Backdoor'),
#   Text(2, 0, 'DoS'),
#   Text(3, 0, 'Exploits'),
#   Text(4, 0, 'Analysis'),
#   Text(5, 0, 'Fuzzers'),
#   Text(6, 0, 'Worms'),
#   Text(7, 0, 'Shellcode'),
#   Text(8, 0, 'Generic')])

# %%
#data_adasyn.drop_duplicates(inplace=True)
print(data_adasyn.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_adasyn.shape))
print("--------------------")
print("Duplicates: " + str(data_adasyn.duplicated().sum()))
# Out:
# attack_cat
# Reconnaissance    19030
# Backdoor          18892
# Generic           18871
# Worms             18866
# Shellcode         18828
# Analysis          18732
# DoS               18730
# Exploits          18679
# Fuzzers           18397
# Name: count, dtype: int64
# --------------------
# Shape: (169025, 182)
# --------------------
# Duplicates: 44964

# %% [markdown]
# # Model Architecture

# %%
# from keras import backend as K
import tensorflow_addons as tfa
# Out:
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (181, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision(), tfa.metrics.F1Score(num_classes=9, 
                                                                                                                                 average='macro')])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 177, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 176, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5632)              0
#
#  batch_normalization (BatchN  (None, 5632)             22528
#  ormalization)
#
#  dropout (Dropout)           (None, 5632)              0
#
#  dense (Dense)               (None, 32)                180256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 203,657
# Trainable params: 192,393
# Non-trainable params: 11,264
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_adasyn = le.fit_transform(y_adasyn)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_adasyn = to_categorical(y_adasyn, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_adasyn = np.array(X_adasyn, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_adasyn, y_adasyn, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5283/5283 [==============================] - 57s 10ms/step - loss: 1.0927 - accuracy: 0.5604 - recall: 0.3740 - precision: 0.7378 - f1_score: 0.5515 - val_loss: 0.9719 - val_accuracy: 0.6362 - val_recall: 0.5492 - val_precision: 0.7617 - val_f1_score: 0.3763
# Epoch 2/50
# 5283/5283 [==============================] - 56s 11ms/step - loss: 0.9681 - accuracy: 0.6011 - recall: 0.4370 - precision: 0.7582 - f1_score: 0.5955 - val_loss: 1.5065 - val_accuracy: 0.5321 - val_recall: 0.4861 - val_precision: 0.6574 - val_f1_score: 0.3063
# Epoch 3/50
# 5283/5283 [==============================] - 55s 10ms/step - loss: 0.9392 - accuracy: 0.6125 - recall: 0.4571 - precision: 0.7637 - f1_score: 0.6073 - val_loss: 1.1548 - val_accuracy: 0.6023 - val_recall: 0.5300 - val_precision: 0.7479 - val_f1_score: 0.3575
# Epoch 4/50
# 5283/5283 [==============================] - 55s 10ms/step - loss: 0.9185 - accuracy: 0.6215 - recall: 0.4712 - precision: 0.7682 - f1_score: 0.6163 - val_loss: 0.9915 - val_accuracy: 0.6495 - val_recall: 0.5694 - val_precision: 0.7633 - val_f1_score: 0.3929
# Epoch 5/50
# 5283/5283 [==============================] - 56s 11ms/step - loss: 0.9030 - accuracy: 0.6289 - recall: 0.4831 - precision: 0.7746 - f1_score: 0.6239 - val_loss: 0.9896 - val_accuracy: 0.6553 - val_recall: 0.5761 - val_precision: 0.8006 - val_f1_score: 0.3978
# Epoch 6/50
# 5283/5283 [==============================] - 57s 11ms/step - loss: 0.8915 - accuracy: 0.6364 - recall: 0.4916 - precision: 0.7808 - f1_score: 0.6312 - val_loss: 1.1367 - val_accuracy: 0.6289 - val_recall: 0.5638 - val_precision: 0.7701 - val_f1_score: 0.3782
# Epoch 7/50
# 5283/5283 [==============================] - 56s 11ms/step - loss: 0.8809 - accuracy: 0.6409 - recall: 0.5007 - precision: 0.7844 - f1_score: 0.6356 - val_loss: 1.0559 - val_accuracy: 0.6486 - val_recall: 0.5675 - val_precision: 0.7844 - val_f1_score: 0.3896
# Epoch 8/50
# 5283/5283 [==============================] - 56s 11ms/step - loss: 0.8711 - accuracy: 0.6443 - recall: 0.5082 - precision: 0.7864 - f1_score: 0.6391 - val_loss: 1.0495 - val_accuracy: 0.6443 - val_recall: 0.5706 - val_precision: 0.7703 - val_f1_score: 0.3876
# Epoch 9/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8643 - accuracy: 0.6469 - recall: 0.5109 - precision: 0.7877 - f1_score: 0.6417 - val_loss: 0.9655 - val_accuracy: 0.6779 - val_recall: 0.6027 - val_precision: 0.8246 - val_f1_score: 0.4140
# Epoch 10/50
# 5283/5283 [==============================] - 56s 11ms/step - loss: 0.8571 - accuracy: 0.6505 - recall: 0.5154 - precision: 0.7916 - f1_score: 0.6451 - val_loss: 1.0193 - val_accuracy: 0.6568 - val_recall: 0.5949 - val_precision: 0.7619 - val_f1_score: 0.4024
# Epoch 11/50
# 5283/5283 [==============================] - 55s 10ms/step - loss: 0.8537 - accuracy: 0.6513 - recall: 0.5177 - precision: 0.7923 - f1_score: 0.6463 - val_loss: 0.9913 - val_accuracy: 0.6644 - val_recall: 0.5981 - val_precision: 0.7615 - val_f1_score: 0.4073
# Epoch 12/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.8487 - accuracy: 0.6530 - recall: 0.5202 - precision: 0.7928 - f1_score: 0.6476 - val_loss: 1.3261 - val_accuracy: 0.5988 - val_recall: 0.5507 - val_precision: 0.7281 - val_f1_score: 0.3578
# Epoch 13/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8465 - accuracy: 0.6540 - recall: 0.5203 - precision: 0.7936 - f1_score: 0.6490 - val_loss: 1.0536 - val_accuracy: 0.6619 - val_recall: 0.5896 - val_precision: 0.7689 - val_f1_score: 0.3987
# Epoch 14/50
# 5283/5283 [==============================] - 56s 11ms/step - loss: 0.8436 - accuracy: 0.6533 - recall: 0.5211 - precision: 0.7928 - f1_score: 0.6483 - val_loss: 0.9932 - val_accuracy: 0.6755 - val_recall: 0.6012 - val_precision: 0.8114 - val_f1_score: 0.4156
# Epoch 15/50
# 5283/5283 [==============================] - 55s 10ms/step - loss: 0.8393 - accuracy: 0.6558 - recall: 0.5249 - precision: 0.7951 - f1_score: 0.6511 - val_loss: 1.0438 - val_accuracy: 0.6645 - val_recall: 0.6010 - val_precision: 0.7562 - val_f1_score: 0.4042
# Epoch 16/50
# 5283/5283 [==============================] - 52s 10ms/step - loss: 0.8377 - accuracy: 0.6566 - recall: 0.5260 - precision: 0.7943 - f1_score: 0.6518 - val_loss: 1.0392 - val_accuracy: 0.6674 - val_recall: 0.6036 - val_precision: 0.7747 - val_f1_score: 0.4060
# Epoch 17/50
# 5283/5283 [==============================] - 57s 11ms/step - loss: 0.8366 - accuracy: 0.6570 - recall: 0.5251 - precision: 0.7938 - f1_score: 0.6523 - val_loss: 0.9723 - val_accuracy: 0.6817 - val_recall: 0.6093 - val_precision: 0.7955 - val_f1_score: 0.4150
# Epoch 18/50
# 5283/5283 [==============================] - 52s 10ms/step - loss: 0.8335 - accuracy: 0.6572 - recall: 0.5279 - precision: 0.7934 - f1_score: 0.6523 - val_loss: 1.0042 - val_accuracy: 0.6754 - val_recall: 0.6114 - val_precision: 0.7745 - val_f1_score: 0.4088
# Epoch 19/50
# 5283/5283 [==============================] - 52s 10ms/step - loss: 0.8298 - accuracy: 0.6579 - recall: 0.5285 - precision: 0.7943 - f1_score: 0.6530 - val_loss: 0.9632 - val_accuracy: 0.6734 - val_recall: 0.6072 - val_precision: 0.8236 - val_f1_score: 0.4143
# Epoch 20/50
# 5283/5283 [==============================] - 55s 10ms/step - loss: 0.8277 - accuracy: 0.6588 - recall: 0.5298 - precision: 0.7962 - f1_score: 0.6544 - val_loss: 1.0288 - val_accuracy: 0.6742 - val_recall: 0.6079 - val_precision: 0.7866 - val_f1_score: 0.4088
# Epoch 21/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8258 - accuracy: 0.6602 - recall: 0.5308 - precision: 0.7961 - f1_score: 0.6558 - val_loss: 0.9461 - val_accuracy: 0.6759 - val_recall: 0.6055 - val_precision: 0.8150 - val_f1_score: 0.4143
# Epoch 22/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8246 - accuracy: 0.6607 - recall: 0.5322 - precision: 0.7967 - f1_score: 0.6564 - val_loss: 0.9804 - val_accuracy: 0.6694 - val_recall: 0.5881 - val_precision: 0.8289 - val_f1_score: 0.4054
# Epoch 23/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.8228 - accuracy: 0.6604 - recall: 0.5326 - precision: 0.7956 - f1_score: 0.6561 - val_loss: 1.0320 - val_accuracy: 0.6736 - val_recall: 0.6030 - val_precision: 0.7855 - val_f1_score: 0.4131
# Epoch 24/50
# 5283/5283 [==============================] - 52s 10ms/step - loss: 0.8201 - accuracy: 0.6622 - recall: 0.5333 - precision: 0.7982 - f1_score: 0.6574 - val_loss: 1.0434 - val_accuracy: 0.6659 - val_recall: 0.5994 - val_precision: 0.7667 - val_f1_score: 0.4051
# Epoch 25/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.8196 - accuracy: 0.6613 - recall: 0.5349 - precision: 0.7984 - f1_score: 0.6573 - val_loss: 1.0197 - val_accuracy: 0.6610 - val_recall: 0.5906 - val_precision: 0.7897 - val_f1_score: 0.4032
# Epoch 26/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.8164 - accuracy: 0.6618 - recall: 0.5353 - precision: 0.7987 - f1_score: 0.6579 - val_loss: 1.0208 - val_accuracy: 0.6764 - val_recall: 0.5927 - val_precision: 0.8079 - val_f1_score: 0.4125
# Epoch 27/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8165 - accuracy: 0.6630 - recall: 0.5345 - precision: 0.7993 - f1_score: 0.6587 - val_loss: 1.0520 - val_accuracy: 0.6667 - val_recall: 0.6015 - val_precision: 0.7700 - val_f1_score: 0.3981
# Epoch 28/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8143 - accuracy: 0.6635 - recall: 0.5379 - precision: 0.7989 - f1_score: 0.6597 - val_loss: 1.0824 - val_accuracy: 0.6505 - val_recall: 0.5851 - val_precision: 0.7753 - val_f1_score: 0.3996
# Epoch 29/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8148 - accuracy: 0.6631 - recall: 0.5362 - precision: 0.7987 - f1_score: 0.6590 - val_loss: 0.9754 - val_accuracy: 0.6697 - val_recall: 0.5988 - val_precision: 0.8172 - val_f1_score: 0.4159
# Epoch 30/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8131 - accuracy: 0.6642 - recall: 0.5383 - precision: 0.8013 - f1_score: 0.6603 - val_loss: 0.9951 - val_accuracy: 0.6469 - val_recall: 0.5825 - val_precision: 0.7874 - val_f1_score: 0.4053
# Epoch 31/50
# 5283/5283 [==============================] - 55s 10ms/step - loss: 0.8103 - accuracy: 0.6645 - recall: 0.5387 - precision: 0.8007 - f1_score: 0.6601 - val_loss: 1.0067 - val_accuracy: 0.6622 - val_recall: 0.6083 - val_precision: 0.7481 - val_f1_score: 0.4063
# Epoch 32/50
# 5283/5283 [==============================] - 55s 10ms/step - loss: 0.8098 - accuracy: 0.6646 - recall: 0.5387 - precision: 0.8011 - f1_score: 0.6606 - val_loss: 0.9479 - val_accuracy: 0.6817 - val_recall: 0.6071 - val_precision: 0.8142 - val_f1_score: 0.4231
# Epoch 33/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.8088 - accuracy: 0.6658 - recall: 0.5393 - precision: 0.8018 - f1_score: 0.6615 - val_loss: 0.9619 - val_accuracy: 0.6743 - val_recall: 0.6003 - val_precision: 0.8008 - val_f1_score: 0.4155
# Epoch 34/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8072 - accuracy: 0.6667 - recall: 0.5402 - precision: 0.8018 - f1_score: 0.6625 - val_loss: 1.0252 - val_accuracy: 0.6494 - val_recall: 0.5847 - val_precision: 0.7848 - val_f1_score: 0.3943
# Epoch 35/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8068 - accuracy: 0.6658 - recall: 0.5408 - precision: 0.8015 - f1_score: 0.6617 - val_loss: 1.0090 - val_accuracy: 0.6696 - val_recall: 0.6023 - val_precision: 0.7866 - val_f1_score: 0.4116
# Epoch 36/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.8064 - accuracy: 0.6663 - recall: 0.5405 - precision: 0.8029 - f1_score: 0.6624 - val_loss: 0.9652 - val_accuracy: 0.6705 - val_recall: 0.6086 - val_precision: 0.7790 - val_f1_score: 0.4129
# Epoch 37/50
# 5283/5283 [==============================] - 52s 10ms/step - loss: 0.8039 - accuracy: 0.6671 - recall: 0.5412 - precision: 0.8033 - f1_score: 0.6632 - val_loss: 1.0523 - val_accuracy: 0.6493 - val_recall: 0.5891 - val_precision: 0.7535 - val_f1_score: 0.3979
# Epoch 38/50
# 5283/5283 [==============================] - 52s 10ms/step - loss: 0.8037 - accuracy: 0.6671 - recall: 0.5423 - precision: 0.8032 - f1_score: 0.6631 - val_loss: 1.0391 - val_accuracy: 0.6590 - val_recall: 0.5952 - val_precision: 0.7871 - val_f1_score: 0.4094
# Epoch 39/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.8010 - accuracy: 0.6673 - recall: 0.5438 - precision: 0.8034 - f1_score: 0.6632 - val_loss: 1.0349 - val_accuracy: 0.6546 - val_recall: 0.5784 - val_precision: 0.7708 - val_f1_score: 0.3994
# Epoch 40/50
# 5283/5283 [==============================] - 54s 10ms/step - loss: 0.8010 - accuracy: 0.6678 - recall: 0.5416 - precision: 0.8020 - f1_score: 0.6635 - val_loss: 0.9499 - val_accuracy: 0.6693 - val_recall: 0.6003 - val_precision: 0.8047 - val_f1_score: 0.4107
# Epoch 41/50
# 5283/5283 [==============================] - 55s 10ms/step - loss: 0.7996 - accuracy: 0.6691 - recall: 0.5443 - precision: 0.8044 - f1_score: 0.6651 - val_loss: 1.1056 - val_accuracy: 0.6518 - val_recall: 0.5805 - val_precision: 0.7680 - val_f1_score: 0.3685
# Epoch 42/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.8015 - accuracy: 0.6681 - recall: 0.5442 - precision: 0.8026 - f1_score: 0.6641 - val_loss: 0.9646 - val_accuracy: 0.6741 - val_recall: 0.6114 - val_precision: 0.7735 - val_f1_score: 0.4119
# Epoch 43/50
# 5283/5283 [==============================] - 52s 10ms/step - loss: 0.7984 - accuracy: 0.6702 - recall: 0.5453 - precision: 0.8051 - f1_score: 0.6666 - val_loss: 0.9753 - val_accuracy: 0.6652 - val_recall: 0.5985 - val_precision: 0.7721 - val_f1_score: 0.4008
# Epoch 44/50
# 5283/5283 [==============================] - 49s 9ms/step - loss: 0.7983 - accuracy: 0.6686 - recall: 0.5451 - precision: 0.8026 - f1_score: 0.6641 - val_loss: 0.9791 - val_accuracy: 0.6633 - val_recall: 0.6045 - val_precision: 0.7563 - val_f1_score: 0.4134
# Epoch 45/50
# 5283/5283 [==============================] - 51s 10ms/step - loss: 0.7974 - accuracy: 0.6704 - recall: 0.5464 - precision: 0.8035 - f1_score: 0.6663 - val_loss: 1.0161 - val_accuracy: 0.6658 - val_recall: 0.6023 - val_precision: 0.7851 - val_f1_score: 0.4154
# Epoch 46/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.7964 - accuracy: 0.6699 - recall: 0.5463 - precision: 0.8043 - f1_score: 0.6659 - val_loss: 1.1062 - val_accuracy: 0.6604 - val_recall: 0.5849 - val_precision: 0.8158 - val_f1_score: 0.3553
# Epoch 47/50
# 5283/5283 [==============================] - 53s 10ms/step - loss: 0.7946 - accuracy: 0.6703 - recall: 0.5468 - precision: 0.8051 - f1_score: 0.6666 - val_loss: 1.0291 - val_accuracy: 0.6778 - val_recall: 0.5965 - val_precision: 0.8316 - val_f1_score: 0.3961
# Epoch 48/50
# 5283/5283 [==============================] - 50s 10ms/step - loss: 0.7933 - accuracy: 0.6712 - recall: 0.5472 - precision: 0.8051 - f1_score: 0.6671 - val_loss: 1.0867 - val_accuracy: 0.6378 - val_recall: 0.5677 - val_precision: 0.7819 - val_f1_score: 0.3861
# Epoch 49/50
# 5283/5283 [==============================] - 52s 10ms/step - loss: 0.7956 - accuracy: 0.6694 - recall: 0.5462 - precision: 0.8062 - f1_score: 0.6656 - val_loss: 1.0154 - val_accuracy: 0.6782 - val_recall: 0.6155 - val_precision: 0.7777 - val_f1_score: 0.4118
# Epoch 50/50
# 5283/5283 [==============================] - 51s 10ms/step - loss: 0.7931 - accuracy: 0.6704 - recall: 0.5467 - precision: 0.8056 - f1_score: 0.6664 - val_loss: 1.1391 - val_accuracy: 0.6368 - val_recall: 0.5709 - val_precision: 0.7938 - val_f1_score: 0.3508

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall, precision, f1_score = model.evaluate(X_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
print('Test Precision:', precision)
print('Test F1-Score:', f1_score)
# Out:
# 3730/3730 [==============================] - 18s 5ms/step - loss: 1.1391 - accuracy: 0.6368 - recall: 0.5709 - precision: 0.7938 - f1_score: 0.3508
# Test Loss: 1.1391422748565674
# Test Accuracy: 0.6368359923362732
# Test Recall: 0.570867121219635
# Test Precision: 0.793784499168396
# Test F1-Score: 0.350786954164505

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 3730/3730 [==============================] - 6s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.1265
# Backdoor: 0.140893470790378
# DoS: 0.6140107649649323
# Exploits: 0.416461990055712
# Fuzzers: 0.7710624725032996
# Generic: 0.9778244456111402
# Reconnaissance: 0.03727714748784441
# Shellcode: 0.4510150044130627
# Worms: 0.2

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import pickle

# %%
# save the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/predicted_classes.pkl', 'wb') as model_file:
    pickle.dump(predicted_classes, model_file)

# %%
# load the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/predicted_classes.pkl', 'rb') as model_file:
    predicted_classes = pickle.load(model_file)
