# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall, Precision

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data-Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data-Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 5
# 6

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ' 'RST']
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']

# %%
#Drop ACC, CLO, and RST from data

data_train_attack = data_train_attack[(data_train_attack['state'] != 'RST')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'ACC') & (data_test_attack['state'] != 'CLO')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 182, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Initialize Train Data and Test Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((119329, 182), (119329,), (45329, 182), (45329,))

# %% [markdown]
# ## ADASYN

# %%
from imblearn.over_sampling import ADASYN

adasyn = ADASYN()
X_adasyn, y_adasyn = adasyn.fit_resample(X_train, y_train)

X_adasyn.shape, y_adasyn.shape
# Out:
# ((354631, 182), (354631,))

# %%
#Create new dataframe from X_adasyn and y_adasyn to count every attack
data_adasyn = pd.concat([X_adasyn, y_adasyn], axis=1)

sns.countplot(data=data_adasyn, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Backdoor'),
#   Text(1, 0, 'Analysis'),
#   Text(2, 0, 'Fuzzers'),
#   Text(3, 0, 'Shellcode'),
#   Text(4, 0, 'Reconnaissance'),
#   Text(5, 0, 'Exploits'),
#   Text(6, 0, 'DoS'),
#   Text(7, 0, 'Worms'),
#   Text(8, 0, 'Generic')])

# %%
#data_adasyn.drop_duplicates(inplace=True)
print(data_adasyn.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_adasyn.shape))
print("--------------------")
print("Duplicates: " + str(data_adasyn.duplicated().sum()))
# Out:
# attack_cat
# Fuzzers           40597
# Backdoor          40186
# Shellcode         40152
# Generic           39999
# Worms             39979
# Analysis          39719
# DoS               39446
# Reconnaissance    39271
# Exploits          35282
# Name: count, dtype: int64
# --------------------
# Shape: (354631, 183)
# --------------------
# Duplicates: 96695

# %% [markdown]
# # Model Architecture

# %%
# from keras import backend as K
import tensorflow_addons as tfa
# Out:
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (182, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision(), tfa.metrics.F1Score(num_classes=9, 
                                                                                                                                 average='macro')])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 178, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 177, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5664)              0
#
#  batch_normalization (BatchN  (None, 5664)             22656
#  ormalization)
#
#  dropout (Dropout)           (None, 5664)              0
#
#  dense (Dense)               (None, 32)                181280
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 204,809
# Trainable params: 193,481
# Non-trainable params: 11,328
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_adasyn = le.fit_transform(y_adasyn)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_adasyn = to_categorical(y_adasyn, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_adasyn = np.array(X_adasyn, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_adasyn, y_adasyn, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 11083/11083 [==============================] - 97s 8ms/step - loss: 1.1329 - accuracy: 0.5489 - recall: 0.3856 - precision: 0.7960 - f1_score: 0.5400 - val_loss: 0.9923 - val_accuracy: 0.6271 - val_recall: 0.5930 - val_precision: 0.8137 - val_f1_score: 0.3034
# Epoch 2/50
# 11083/11083 [==============================] - 96s 9ms/step - loss: 1.0237 - accuracy: 0.5903 - recall: 0.4474 - precision: 0.8215 - f1_score: 0.5905 - val_loss: 0.9469 - val_accuracy: 0.6550 - val_recall: 0.6173 - val_precision: 0.7938 - val_f1_score: 0.3456
# Epoch 3/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.9795 - accuracy: 0.6110 - recall: 0.4777 - precision: 0.8383 - f1_score: 0.6125 - val_loss: 1.0391 - val_accuracy: 0.6306 - val_recall: 0.6015 - val_precision: 0.7782 - val_f1_score: 0.3193
# Epoch 4/50
# 11083/11083 [==============================] - 92s 8ms/step - loss: 0.9571 - accuracy: 0.6203 - recall: 0.4911 - precision: 0.8443 - f1_score: 0.6224 - val_loss: 1.0868 - val_accuracy: 0.6204 - val_recall: 0.5856 - val_precision: 0.7761 - val_f1_score: 0.3258
# Epoch 5/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.9443 - accuracy: 0.6251 - recall: 0.4978 - precision: 0.8481 - f1_score: 0.6276 - val_loss: 0.9451 - val_accuracy: 0.6386 - val_recall: 0.6048 - val_precision: 0.8019 - val_f1_score: 0.3460
# Epoch 6/50
# 11083/11083 [==============================] - 96s 9ms/step - loss: 0.9346 - accuracy: 0.6294 - recall: 0.5026 - precision: 0.8499 - f1_score: 0.6319 - val_loss: 1.1845 - val_accuracy: 0.6190 - val_recall: 0.5798 - val_precision: 0.7483 - val_f1_score: 0.3303
# Epoch 7/50
# 11083/11083 [==============================] - 95s 9ms/step - loss: 0.9276 - accuracy: 0.6303 - recall: 0.5062 - precision: 0.8517 - f1_score: 0.6333 - val_loss: 1.0601 - val_accuracy: 0.6271 - val_recall: 0.5853 - val_precision: 0.7727 - val_f1_score: 0.3442
# Epoch 8/50
# 11083/11083 [==============================] - 97s 9ms/step - loss: 0.9218 - accuracy: 0.6332 - recall: 0.5083 - precision: 0.8530 - f1_score: 0.6364 - val_loss: 1.3741 - val_accuracy: 0.6244 - val_recall: 0.6016 - val_precision: 0.7527 - val_f1_score: 0.3082
# Epoch 9/50
# 11083/11083 [==============================] - 95s 9ms/step - loss: 0.9175 - accuracy: 0.6336 - recall: 0.5100 - precision: 0.8537 - f1_score: 0.6367 - val_loss: 0.9832 - val_accuracy: 0.6393 - val_recall: 0.6101 - val_precision: 0.7930 - val_f1_score: 0.3376
# Epoch 10/50
# 11083/11083 [==============================] - 98s 9ms/step - loss: 0.9134 - accuracy: 0.6349 - recall: 0.5114 - precision: 0.8552 - f1_score: 0.6379 - val_loss: 1.0082 - val_accuracy: 0.6436 - val_recall: 0.6013 - val_precision: 0.8022 - val_f1_score: 0.3605
# Epoch 11/50
# 11083/11083 [==============================] - 96s 9ms/step - loss: 0.9102 - accuracy: 0.6363 - recall: 0.5131 - precision: 0.8558 - f1_score: 0.6392 - val_loss: 1.0188 - val_accuracy: 0.6281 - val_recall: 0.5923 - val_precision: 0.7737 - val_f1_score: 0.3514
# Epoch 12/50
# 11083/11083 [==============================] - 97s 9ms/step - loss: 0.9095 - accuracy: 0.6372 - recall: 0.5137 - precision: 0.8564 - f1_score: 0.6404 - val_loss: 0.9599 - val_accuracy: 0.6418 - val_recall: 0.6087 - val_precision: 0.7948 - val_f1_score: 0.3522
# Epoch 13/50
# 11083/11083 [==============================] - 96s 9ms/step - loss: 0.9059 - accuracy: 0.6379 - recall: 0.5148 - precision: 0.8567 - f1_score: 0.6411 - val_loss: 0.9477 - val_accuracy: 0.6523 - val_recall: 0.6138 - val_precision: 0.8113 - val_f1_score: 0.3354
# Epoch 14/50
# 11083/11083 [==============================] - 96s 9ms/step - loss: 0.9040 - accuracy: 0.6390 - recall: 0.5157 - precision: 0.8571 - f1_score: 0.6421 - val_loss: 1.0135 - val_accuracy: 0.6456 - val_recall: 0.6099 - val_precision: 0.8080 - val_f1_score: 0.3312
# Epoch 15/50
# 11083/11083 [==============================] - 98s 9ms/step - loss: 0.9028 - accuracy: 0.6397 - recall: 0.5166 - precision: 0.8568 - f1_score: 0.6426 - val_loss: 0.9678 - val_accuracy: 0.6489 - val_recall: 0.6114 - val_precision: 0.8104 - val_f1_score: 0.3551
# Epoch 16/50
# 11083/11083 [==============================] - 98s 9ms/step - loss: 0.9006 - accuracy: 0.6403 - recall: 0.5175 - precision: 0.8579 - f1_score: 0.6431 - val_loss: 1.0816 - val_accuracy: 0.6332 - val_recall: 0.6003 - val_precision: 0.7778 - val_f1_score: 0.3450
# Epoch 17/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8990 - accuracy: 0.6410 - recall: 0.5190 - precision: 0.8581 - f1_score: 0.6439 - val_loss: 0.9519 - val_accuracy: 0.6380 - val_recall: 0.6046 - val_precision: 0.7857 - val_f1_score: 0.3511
# Epoch 18/50
# 11083/11083 [==============================] - 94s 9ms/step - loss: 0.8979 - accuracy: 0.6415 - recall: 0.5187 - precision: 0.8587 - f1_score: 0.6444 - val_loss: 0.9232 - val_accuracy: 0.6614 - val_recall: 0.6275 - val_precision: 0.8080 - val_f1_score: 0.3895
# Epoch 19/50
# 11083/11083 [==============================] - 99s 9ms/step - loss: 0.8954 - accuracy: 0.6428 - recall: 0.5199 - precision: 0.8592 - f1_score: 0.6455 - val_loss: 1.0543 - val_accuracy: 0.6764 - val_recall: 0.6453 - val_precision: 0.8370 - val_f1_score: 0.3983
# Epoch 20/50
# 11083/11083 [==============================] - 93s 8ms/step - loss: 0.8954 - accuracy: 0.6432 - recall: 0.5204 - precision: 0.8593 - f1_score: 0.6461 - val_loss: 0.9617 - val_accuracy: 0.6471 - val_recall: 0.6082 - val_precision: 0.7992 - val_f1_score: 0.3625
# Epoch 21/50
# 11083/11083 [==============================] - 95s 9ms/step - loss: 0.8940 - accuracy: 0.6431 - recall: 0.5213 - precision: 0.8601 - f1_score: 0.6460 - val_loss: 1.1308 - val_accuracy: 0.6355 - val_recall: 0.6027 - val_precision: 0.7982 - val_f1_score: 0.3279
# Epoch 22/50
# 11083/11083 [==============================] - 96s 9ms/step - loss: 0.8937 - accuracy: 0.6434 - recall: 0.5212 - precision: 0.8594 - f1_score: 0.6460 - val_loss: 1.2231 - val_accuracy: 0.6187 - val_recall: 0.5798 - val_precision: 0.7629 - val_f1_score: 0.3250
# Epoch 23/50
# 11083/11083 [==============================] - 96s 9ms/step - loss: 0.8938 - accuracy: 0.6439 - recall: 0.5220 - precision: 0.8598 - f1_score: 0.6468 - val_loss: 1.0541 - val_accuracy: 0.6303 - val_recall: 0.6017 - val_precision: 0.7659 - val_f1_score: 0.3389
# Epoch 24/50
# 11083/11083 [==============================] - 94s 9ms/step - loss: 0.8926 - accuracy: 0.6446 - recall: 0.5228 - precision: 0.8600 - f1_score: 0.6472 - val_loss: 1.0087 - val_accuracy: 0.6586 - val_recall: 0.6230 - val_precision: 0.8103 - val_f1_score: 0.3814
# Epoch 25/50
# 11083/11083 [==============================] - 101s 9ms/step - loss: 0.8918 - accuracy: 0.6446 - recall: 0.5228 - precision: 0.8601 - f1_score: 0.6472 - val_loss: 0.9948 - val_accuracy: 0.6443 - val_recall: 0.6112 - val_precision: 0.7965 - val_f1_score: 0.3386
# Epoch 26/50
# 11083/11083 [==============================] - 94s 9ms/step - loss: 0.8900 - accuracy: 0.6446 - recall: 0.5233 - precision: 0.8604 - f1_score: 0.6474 - val_loss: 0.9606 - val_accuracy: 0.6506 - val_recall: 0.6183 - val_precision: 0.8102 - val_f1_score: 0.3717
# Epoch 27/50
# 11083/11083 [==============================] - 93s 8ms/step - loss: 0.8912 - accuracy: 0.6447 - recall: 0.5231 - precision: 0.8602 - f1_score: 0.6477 - val_loss: 1.0521 - val_accuracy: 0.6428 - val_recall: 0.6149 - val_precision: 0.7789 - val_f1_score: 0.3503
# Epoch 28/50
# 11083/11083 [==============================] - 123s 11ms/step - loss: 0.8892 - accuracy: 0.6459 - recall: 0.5240 - precision: 0.8612 - f1_score: 0.6487 - val_loss: 1.1268 - val_accuracy: 0.6628 - val_recall: 0.6266 - val_precision: 0.8072 - val_f1_score: 0.3808
# Epoch 29/50
# 11083/11083 [==============================] - 196s 18ms/step - loss: 0.8894 - accuracy: 0.6455 - recall: 0.5236 - precision: 0.8620 - f1_score: 0.6486 - val_loss: 0.9734 - val_accuracy: 0.6616 - val_recall: 0.6239 - val_precision: 0.8040 - val_f1_score: 0.3840
# Epoch 30/50
# 11083/11083 [==============================] - 104s 9ms/step - loss: 0.8884 - accuracy: 0.6461 - recall: 0.5240 - precision: 0.8604 - f1_score: 0.6487 - val_loss: 1.6610 - val_accuracy: 0.6310 - val_recall: 0.6055 - val_precision: 0.6926 - val_f1_score: 0.3129
# Epoch 31/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8871 - accuracy: 0.6467 - recall: 0.5254 - precision: 0.8612 - f1_score: 0.6498 - val_loss: 1.2484 - val_accuracy: 0.6373 - val_recall: 0.6029 - val_precision: 0.7994 - val_f1_score: 0.3292
# Epoch 32/50
# 11083/11083 [==============================] - 100s 9ms/step - loss: 0.8855 - accuracy: 0.6479 - recall: 0.5261 - precision: 0.8627 - f1_score: 0.6505 - val_loss: 1.0305 - val_accuracy: 0.6414 - val_recall: 0.6127 - val_precision: 0.7730 - val_f1_score: 0.3428
# Epoch 33/50
# 11083/11083 [==============================] - 98s 9ms/step - loss: 0.8858 - accuracy: 0.6479 - recall: 0.5261 - precision: 0.8618 - f1_score: 0.6507 - val_loss: 0.9882 - val_accuracy: 0.6452 - val_recall: 0.6131 - val_precision: 0.7800 - val_f1_score: 0.3445
# Epoch 34/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8848 - accuracy: 0.6476 - recall: 0.5264 - precision: 0.8623 - f1_score: 0.6504 - val_loss: 1.2037 - val_accuracy: 0.6542 - val_recall: 0.6177 - val_precision: 0.8048 - val_f1_score: 0.3549
# Epoch 35/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8853 - accuracy: 0.6480 - recall: 0.5269 - precision: 0.8616 - f1_score: 0.6508 - val_loss: 1.0254 - val_accuracy: 0.6731 - val_recall: 0.6369 - val_precision: 0.8265 - val_f1_score: 0.3882
# Epoch 36/50
# 11083/11083 [==============================] - 98s 9ms/step - loss: 0.8851 - accuracy: 0.6476 - recall: 0.5265 - precision: 0.8626 - f1_score: 0.6505 - val_loss: 1.0255 - val_accuracy: 0.6480 - val_recall: 0.6132 - val_precision: 0.7717 - val_f1_score: 0.3441
# Epoch 37/50
# 11083/11083 [==============================] - 96s 9ms/step - loss: 0.8834 - accuracy: 0.6486 - recall: 0.5279 - precision: 0.8629 - f1_score: 0.6513 - val_loss: 1.0317 - val_accuracy: 0.6437 - val_recall: 0.6115 - val_precision: 0.7682 - val_f1_score: 0.3464
# Epoch 38/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8822 - accuracy: 0.6496 - recall: 0.5282 - precision: 0.8632 - f1_score: 0.6524 - val_loss: 1.0708 - val_accuracy: 0.6352 - val_recall: 0.6051 - val_precision: 0.7789 - val_f1_score: 0.3444
# Epoch 39/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8824 - accuracy: 0.6492 - recall: 0.5280 - precision: 0.8636 - f1_score: 0.6518 - val_loss: 1.0413 - val_accuracy: 0.6554 - val_recall: 0.6258 - val_precision: 0.8019 - val_f1_score: 0.3742
# Epoch 40/50
# 11083/11083 [==============================] - 95s 9ms/step - loss: 0.8809 - accuracy: 0.6502 - recall: 0.5285 - precision: 0.8634 - f1_score: 0.6530 - val_loss: 1.0643 - val_accuracy: 0.6349 - val_recall: 0.5996 - val_precision: 0.7772 - val_f1_score: 0.3324
# Epoch 41/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8815 - accuracy: 0.6499 - recall: 0.5289 - precision: 0.8632 - f1_score: 0.6523 - val_loss: 1.0308 - val_accuracy: 0.6435 - val_recall: 0.6090 - val_precision: 0.7894 - val_f1_score: 0.3353
# Epoch 42/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8797 - accuracy: 0.6498 - recall: 0.5290 - precision: 0.8637 - f1_score: 0.6524 - val_loss: 1.0201 - val_accuracy: 0.6519 - val_recall: 0.6204 - val_precision: 0.7869 - val_f1_score: 0.3653
# Epoch 43/50
# 11083/11083 [==============================] - 95s 9ms/step - loss: 0.8801 - accuracy: 0.6502 - recall: 0.5288 - precision: 0.8640 - f1_score: 0.6528 - val_loss: 1.1327 - val_accuracy: 0.6250 - val_recall: 0.5883 - val_precision: 0.7712 - val_f1_score: 0.3313
# Epoch 44/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8781 - accuracy: 0.6509 - recall: 0.5297 - precision: 0.8641 - f1_score: 0.6535 - val_loss: 1.0061 - val_accuracy: 0.6507 - val_recall: 0.6199 - val_precision: 0.7770 - val_f1_score: 0.3570
# Epoch 45/50
# 11083/11083 [==============================] - 93s 8ms/step - loss: 0.8779 - accuracy: 0.6507 - recall: 0.5299 - precision: 0.8644 - f1_score: 0.6536 - val_loss: 1.1644 - val_accuracy: 0.6240 - val_recall: 0.5921 - val_precision: 0.7603 - val_f1_score: 0.3259
# Epoch 46/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8787 - accuracy: 0.6505 - recall: 0.5302 - precision: 0.8641 - f1_score: 0.6532 - val_loss: 1.0855 - val_accuracy: 0.6237 - val_recall: 0.5934 - val_precision: 0.7571 - val_f1_score: 0.3346
# Epoch 47/50
# 11083/11083 [==============================] - 94s 9ms/step - loss: 0.8773 - accuracy: 0.6515 - recall: 0.5307 - precision: 0.8648 - f1_score: 0.6541 - val_loss: 1.1116 - val_accuracy: 0.6414 - val_recall: 0.6125 - val_precision: 0.7678 - val_f1_score: 0.3453
# Epoch 48/50
# 11083/11083 [==============================] - 94s 8ms/step - loss: 0.8767 - accuracy: 0.6519 - recall: 0.5314 - precision: 0.8655 - f1_score: 0.6547 - val_loss: 1.0592 - val_accuracy: 0.6472 - val_recall: 0.6141 - val_precision: 0.7846 - val_f1_score: 0.3314
# Epoch 49/50
# 11083/11083 [==============================] - 93s 8ms/step - loss: 0.8768 - accuracy: 0.6513 - recall: 0.5309 - precision: 0.8654 - f1_score: 0.6542 - val_loss: 1.1013 - val_accuracy: 0.6388 - val_recall: 0.6119 - val_precision: 0.7608 - val_f1_score: 0.3439
# Epoch 50/50
# 11083/11083 [==============================] - 95s 9ms/step - loss: 0.8757 - accuracy: 0.6517 - recall: 0.5313 - precision: 0.8652 - f1_score: 0.6544 - val_loss: 1.0943 - val_accuracy: 0.6303 - val_recall: 0.5966 - val_precision: 0.7680 - val_f1_score: 0.3371

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall, precision, f1_score = model.evaluate(X_test, y_test)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
print('Test Precision:', precision)
print('Test F1-Score:', f1_score)
# Out:
# 1417/1417 [==============================] - 8s 6ms/step - loss: 1.0943 - accuracy: 0.6303 - recall: 0.5966 - precision: 0.7680 - f1_score: 0.3371
# Test Loss: 1.0943279266357422
# Test Accuracy: 0.6303249597549438
# Test Recall: 0.5966379046440125
# Test Precision: 0.767996609210968
# Test F1-Score: 0.6715584034276199

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 1417/1417 [==============================] - 3s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.45790251107828656
# Backdoor: 0.34133790737564323
# DoS: 0.16678894595255564
# Exploits: 0.45665259186056956
# Fuzzers: 0.5647582907111037
# Generic: 0.9624821154151874
# Reconnaissance: 0.10071530758226037
# Shellcode: 0.8677248677248677
# Worms: 0.7272727272727273

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import joblib

# %%
# save predicted
joblib.dump(predicted_classes, '/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/predicted_classes.joblib', compress=('zlib', 3))
# Out:
# ['/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/predicted_classes.joblib']

# %%
# load the predicted
predicted_classes = joblib.load('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/ADASYN/Saved/predicted_classes.joblib')
