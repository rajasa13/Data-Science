# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall, Precision

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data-Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data-Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 5
# 6

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ' 'RST']
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'RST')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'ACC') & (data_test_attack['state'] != 'CLO')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 182, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Initialize Train Data and Test Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((119329, 182), (119329,), (45329, 182), (45329,))

# %% [markdown]
# ## SMOTETomek

# %%
from imblearn.combine import SMOTETomek

smotetomek = SMOTETomek()
X_smotetomek, y_smotetomek = smotetomek.fit_resample(X_train, y_train)

X_smotetomek.shape, y_smotetomek.shape
# Out:
# ((342101, 182), (342101,))

# %%
#Create new dataframe from X_smotetomek and y_smotetomek to count every attack
data_smotetomek = pd.concat([X_smotetomek, y_smotetomek], axis=1)

sns.countplot(data=data_smotetomek, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Backdoor'),
#   Text(1, 0, 'Analysis'),
#   Text(2, 0, 'Fuzzers'),
#   Text(3, 0, 'Shellcode'),
#   Text(4, 0, 'Reconnaissance'),
#   Text(5, 0, 'Exploits'),
#   Text(6, 0, 'DoS'),
#   Text(7, 0, 'Worms'),
#   Text(8, 0, 'Generic')])

# %%
#data_smotetomek.drop_duplicates(inplace=True)
print(data_smotetomek.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_smotetomek.shape))
print("--------------------")
print("Duplicates: " + str(data_smotetomek.duplicated().sum()))
# Out:
# attack_cat
# Worms             39995
# Shellcode         39954
# Generic           39882
# DoS               39620
# Exploits          39497
# Fuzzers           38925
# Reconnaissance    37608
# Backdoor          33363
# Analysis          33257
# Name: count, dtype: int64
# --------------------
# Shape: (342101, 183)
# --------------------
# Duplicates: 107732

# %% [markdown]
# # Model Architecture

# %%
# from keras import backend as K
import tensorflow_addons as tfa
# Out:
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (182, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision(), tfa.metrics.F1Score(num_classes=9, 
                                                                                                                                 average='macro')])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 178, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 177, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5664)              0
#
#  batch_normalization (BatchN  (None, 5664)             22656
#  ormalization)
#
#  dropout (Dropout)           (None, 5664)              0
#
#  dense (Dense)               (None, 32)                181280
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 204,809
# Trainable params: 193,481
# Non-trainable params: 11,328
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_smotetomek = le.fit_transform(y_smotetomek)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_smotetomek = to_categorical(y_smotetomek, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_smotetomek = np.array(X_smotetomek, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_smotetomek, y_smotetomek, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 10691/10691 [==============================] - 100s 9ms/step - loss: 0.9668 - accuracy: 0.6103 - recall: 0.4525 - precision: 0.8126 - f1_score: 0.6010 - val_loss: 0.8429 - val_accuracy: 0.6936 - val_recall: 0.6311 - val_precision: 0.8407 - val_f1_score: 0.3985
# Epoch 2/50
# 10691/10691 [==============================] - 96s 9ms/step - loss: 0.8572 - accuracy: 0.6556 - recall: 0.5211 - precision: 0.8391 - f1_score: 0.6496 - val_loss: 1.2855 - val_accuracy: 0.6710 - val_recall: 0.6176 - val_precision: 0.7068 - val_f1_score: 0.3902
# Epoch 3/50
# 10691/10691 [==============================] - 97s 9ms/step - loss: 0.8233 - accuracy: 0.6710 - recall: 0.5477 - precision: 0.8470 - f1_score: 0.6653 - val_loss: 1.0206 - val_accuracy: 0.6536 - val_recall: 0.6052 - val_precision: 0.7837 - val_f1_score: 0.3445
# Epoch 4/50
# 10691/10691 [==============================] - 97s 9ms/step - loss: 0.8053 - accuracy: 0.6788 - recall: 0.5603 - precision: 0.8516 - f1_score: 0.6734 - val_loss: 0.9803 - val_accuracy: 0.6517 - val_recall: 0.5947 - val_precision: 0.7779 - val_f1_score: 0.3447
# Epoch 5/50
# 10691/10691 [==============================] - 96s 9ms/step - loss: 0.7909 - accuracy: 0.6875 - recall: 0.5705 - precision: 0.8607 - f1_score: 0.6824 - val_loss: 1.0082 - val_accuracy: 0.6617 - val_recall: 0.6421 - val_precision: 0.7447 - val_f1_score: 0.3640
# Epoch 6/50
# 10691/10691 [==============================] - 95s 9ms/step - loss: 0.7792 - accuracy: 0.6932 - recall: 0.5780 - precision: 0.8659 - f1_score: 0.6880 - val_loss: 0.9405 - val_accuracy: 0.6661 - val_recall: 0.6135 - val_precision: 0.7973 - val_f1_score: 0.3499
# Epoch 7/50
# 10691/10691 [==============================] - 95s 9ms/step - loss: 0.7704 - accuracy: 0.6975 - recall: 0.5831 - precision: 0.8696 - f1_score: 0.6921 - val_loss: 1.0078 - val_accuracy: 0.6694 - val_recall: 0.6122 - val_precision: 0.7912 - val_f1_score: 0.3769
# Epoch 8/50
# 10691/10691 [==============================] - 99s 9ms/step - loss: 0.7639 - accuracy: 0.7001 - recall: 0.5867 - precision: 0.8719 - f1_score: 0.6946 - val_loss: 1.0224 - val_accuracy: 0.6574 - val_recall: 0.6315 - val_precision: 0.7528 - val_f1_score: 0.3774
# Epoch 9/50
# 10691/10691 [==============================] - 102s 10ms/step - loss: 0.7586 - accuracy: 0.7025 - recall: 0.5900 - precision: 0.8731 - f1_score: 0.6971 - val_loss: 1.1892 - val_accuracy: 0.6386 - val_recall: 0.6191 - val_precision: 0.6949 - val_f1_score: 0.3447
# Epoch 10/50
# 10691/10691 [==============================] - 106s 10ms/step - loss: 0.7546 - accuracy: 0.7045 - recall: 0.5918 - precision: 0.8737 - f1_score: 0.6988 - val_loss: 1.1142 - val_accuracy: 0.6383 - val_recall: 0.5987 - val_precision: 0.7259 - val_f1_score: 0.3446
# Epoch 11/50
# 10691/10691 [==============================] - 106s 10ms/step - loss: 0.7493 - accuracy: 0.7063 - recall: 0.5951 - precision: 0.8757 - f1_score: 0.7005 - val_loss: 1.0537 - val_accuracy: 0.6502 - val_recall: 0.6086 - val_precision: 0.7503 - val_f1_score: 0.3488
# Epoch 12/50
# 10691/10691 [==============================] - 110s 10ms/step - loss: 0.7456 - accuracy: 0.7075 - recall: 0.5964 - precision: 0.8757 - f1_score: 0.7017 - val_loss: 1.0940 - val_accuracy: 0.6538 - val_recall: 0.5998 - val_precision: 0.7665 - val_f1_score: 0.3353
# Epoch 13/50
# 10691/10691 [==============================] - 109s 10ms/step - loss: 0.7434 - accuracy: 0.7085 - recall: 0.5982 - precision: 0.8767 - f1_score: 0.7027 - val_loss: 1.0304 - val_accuracy: 0.6508 - val_recall: 0.6065 - val_precision: 0.7667 - val_f1_score: 0.3420
# Epoch 14/50
# 10691/10691 [==============================] - 109s 10ms/step - loss: 0.7405 - accuracy: 0.7102 - recall: 0.5999 - precision: 0.8776 - f1_score: 0.7042 - val_loss: 0.9968 - val_accuracy: 0.6512 - val_recall: 0.6062 - val_precision: 0.7543 - val_f1_score: 0.3632
# Epoch 15/50
# 10691/10691 [==============================] - 112s 10ms/step - loss: 0.7394 - accuracy: 0.7098 - recall: 0.5999 - precision: 0.8764 - f1_score: 0.7042 - val_loss: 1.1251 - val_accuracy: 0.6444 - val_recall: 0.5951 - val_precision: 0.7518 - val_f1_score: 0.3423
# Epoch 16/50
# 10691/10691 [==============================] - 110s 10ms/step - loss: 0.7385 - accuracy: 0.7101 - recall: 0.6008 - precision: 0.8769 - f1_score: 0.7044 - val_loss: 1.1584 - val_accuracy: 0.6467 - val_recall: 0.6124 - val_precision: 0.7263 - val_f1_score: 0.3544
# Epoch 17/50
# 10691/10691 [==============================] - 113s 11ms/step - loss: 0.7359 - accuracy: 0.7115 - recall: 0.6024 - precision: 0.8788 - f1_score: 0.7058 - val_loss: 1.2211 - val_accuracy: 0.6560 - val_recall: 0.6247 - val_precision: 0.7316 - val_f1_score: 0.3549
# Epoch 18/50
# 10691/10691 [==============================] - 112s 10ms/step - loss: 0.7349 - accuracy: 0.7115 - recall: 0.6019 - precision: 0.8784 - f1_score: 0.7059 - val_loss: 1.0031 - val_accuracy: 0.6756 - val_recall: 0.6254 - val_precision: 0.7929 - val_f1_score: 0.3641
# Epoch 19/50
# 10691/10691 [==============================] - 113s 11ms/step - loss: 0.7333 - accuracy: 0.7118 - recall: 0.6030 - precision: 0.8790 - f1_score: 0.7062 - val_loss: 1.0110 - val_accuracy: 0.6558 - val_recall: 0.6071 - val_precision: 0.7595 - val_f1_score: 0.3598
# Epoch 20/50
# 10691/10691 [==============================] - 110s 10ms/step - loss: 0.7324 - accuracy: 0.7119 - recall: 0.6035 - precision: 0.8782 - f1_score: 0.7064 - val_loss: 0.9610 - val_accuracy: 0.6711 - val_recall: 0.6256 - val_precision: 0.7661 - val_f1_score: 0.3695
# Epoch 21/50
# 10691/10691 [==============================] - 114s 11ms/step - loss: 0.7319 - accuracy: 0.7129 - recall: 0.6039 - precision: 0.8791 - f1_score: 0.7074 - val_loss: 0.9797 - val_accuracy: 0.6821 - val_recall: 0.6242 - val_precision: 0.8035 - val_f1_score: 0.3462
# Epoch 22/50
# 10691/10691 [==============================] - 114s 11ms/step - loss: 0.7292 - accuracy: 0.7139 - recall: 0.6053 - precision: 0.8807 - f1_score: 0.7084 - val_loss: 1.0437 - val_accuracy: 0.6606 - val_recall: 0.6183 - val_precision: 0.7505 - val_f1_score: 0.3461
# Epoch 23/50
# 10691/10691 [==============================] - 105s 10ms/step - loss: 0.7293 - accuracy: 0.7132 - recall: 0.6051 - precision: 0.8804 - f1_score: 0.7079 - val_loss: 1.0347 - val_accuracy: 0.6658 - val_recall: 0.6129 - val_precision: 0.7806 - val_f1_score: 0.3513
# Epoch 24/50
# 10691/10691 [==============================] - 107s 10ms/step - loss: 0.7268 - accuracy: 0.7150 - recall: 0.6064 - precision: 0.8813 - f1_score: 0.7097 - val_loss: 1.2366 - val_accuracy: 0.6397 - val_recall: 0.5863 - val_precision: 0.7299 - val_f1_score: 0.3481
# Epoch 25/50
# 10691/10691 [==============================] - 109s 10ms/step - loss: 0.7266 - accuracy: 0.7148 - recall: 0.6064 - precision: 0.8813 - f1_score: 0.7094 - val_loss: 0.9478 - val_accuracy: 0.6741 - val_recall: 0.6265 - val_precision: 0.7680 - val_f1_score: 0.3706
# Epoch 26/50
# 10691/10691 [==============================] - 106s 10ms/step - loss: 0.7259 - accuracy: 0.7151 - recall: 0.6063 - precision: 0.8812 - f1_score: 0.7098 - val_loss: 1.0809 - val_accuracy: 0.6548 - val_recall: 0.6105 - val_precision: 0.7450 - val_f1_score: 0.3539
# Epoch 27/50
# 10691/10691 [==============================] - 107s 10ms/step - loss: 0.7247 - accuracy: 0.7154 - recall: 0.6070 - precision: 0.8813 - f1_score: 0.7100 - val_loss: 1.0089 - val_accuracy: 0.6911 - val_recall: 0.6388 - val_precision: 0.8325 - val_f1_score: 0.3998
# Epoch 28/50
# 10691/10691 [==============================] - 108s 10ms/step - loss: 0.7255 - accuracy: 0.7151 - recall: 0.6068 - precision: 0.8811 - f1_score: 0.7098 - val_loss: 1.1089 - val_accuracy: 0.6422 - val_recall: 0.5912 - val_precision: 0.7392 - val_f1_score: 0.3329
# Epoch 29/50
# 10691/10691 [==============================] - 108s 10ms/step - loss: 0.7230 - accuracy: 0.7160 - recall: 0.6076 - precision: 0.8824 - f1_score: 0.7106 - val_loss: 1.2991 - val_accuracy: 0.6303 - val_recall: 0.5947 - val_precision: 0.7241 - val_f1_score: 0.3305
# Epoch 30/50
# 10691/10691 [==============================] - 108s 10ms/step - loss: 0.7224 - accuracy: 0.7167 - recall: 0.6085 - precision: 0.8828 - f1_score: 0.7114 - val_loss: 1.1420 - val_accuracy: 0.6552 - val_recall: 0.6237 - val_precision: 0.7370 - val_f1_score: 0.3491
# Epoch 31/50
# 10691/10691 [==============================] - 108s 10ms/step - loss: 0.7220 - accuracy: 0.7169 - recall: 0.6088 - precision: 0.8828 - f1_score: 0.7117 - val_loss: 0.9813 - val_accuracy: 0.6723 - val_recall: 0.6324 - val_precision: 0.7686 - val_f1_score: 0.3493
# Epoch 32/50
# 10691/10691 [==============================] - 108s 10ms/step - loss: 0.7209 - accuracy: 0.7175 - recall: 0.6090 - precision: 0.8834 - f1_score: 0.7124 - val_loss: 1.0058 - val_accuracy: 0.6680 - val_recall: 0.6260 - val_precision: 0.7777 - val_f1_score: 0.3667
# Epoch 33/50
# 10691/10691 [==============================] - 104s 10ms/step - loss: 0.7203 - accuracy: 0.7174 - recall: 0.6097 - precision: 0.8835 - f1_score: 0.7121 - val_loss: 0.9840 - val_accuracy: 0.6605 - val_recall: 0.6052 - val_precision: 0.7747 - val_f1_score: 0.3524
# Epoch 34/50
# 10691/10691 [==============================] - 107s 10ms/step - loss: 0.7205 - accuracy: 0.7173 - recall: 0.6088 - precision: 0.8831 - f1_score: 0.7120 - val_loss: 0.9797 - val_accuracy: 0.6643 - val_recall: 0.6105 - val_precision: 0.7845 - val_f1_score: 0.3524
# Epoch 35/50
# 10691/10691 [==============================] - 107s 10ms/step - loss: 0.7196 - accuracy: 0.7175 - recall: 0.6087 - precision: 0.8838 - f1_score: 0.7124 - val_loss: 0.9555 - val_accuracy: 0.6648 - val_recall: 0.6147 - val_precision: 0.7793 - val_f1_score: 0.3575
# Epoch 36/50
# 10691/10691 [==============================] - 110s 10ms/step - loss: 0.7180 - accuracy: 0.7188 - recall: 0.6104 - precision: 0.8852 - f1_score: 0.7136 - val_loss: 1.0508 - val_accuracy: 0.6701 - val_recall: 0.6230 - val_precision: 0.7895 - val_f1_score: 0.3462
# Epoch 37/50
# 10691/10691 [==============================] - 104s 10ms/step - loss: 0.7186 - accuracy: 0.7176 - recall: 0.6095 - precision: 0.8837 - f1_score: 0.7123 - val_loss: 1.0394 - val_accuracy: 0.6752 - val_recall: 0.6207 - val_precision: 0.7924 - val_f1_score: 0.3503
# Epoch 38/50
# 10691/10691 [==============================] - 108s 10ms/step - loss: 0.7177 - accuracy: 0.7177 - recall: 0.6098 - precision: 0.8843 - f1_score: 0.7126 - val_loss: 1.0541 - val_accuracy: 0.6403 - val_recall: 0.6154 - val_precision: 0.7521 - val_f1_score: 0.3434
# Epoch 39/50
# 10691/10691 [==============================] - 114s 11ms/step - loss: 0.7171 - accuracy: 0.7186 - recall: 0.6111 - precision: 0.8853 - f1_score: 0.7135 - val_loss: 1.1072 - val_accuracy: 0.6566 - val_recall: 0.6211 - val_precision: 0.7361 - val_f1_score: 0.3445
# Epoch 40/50
# 10691/10691 [==============================] - 110s 10ms/step - loss: 0.7155 - accuracy: 0.7199 - recall: 0.6120 - precision: 0.8863 - f1_score: 0.7147 - val_loss: 1.0126 - val_accuracy: 0.6761 - val_recall: 0.6146 - val_precision: 0.7956 - val_f1_score: 0.3573
# Epoch 41/50
# 10691/10691 [==============================] - 108s 10ms/step - loss: 0.7144 - accuracy: 0.7201 - recall: 0.6122 - precision: 0.8863 - f1_score: 0.7150 - val_loss: 1.1241 - val_accuracy: 0.6606 - val_recall: 0.6205 - val_precision: 0.7524 - val_f1_score: 0.3497
# Epoch 42/50
# 10691/10691 [==============================] - 111s 10ms/step - loss: 0.7166 - accuracy: 0.7188 - recall: 0.6107 - precision: 0.8849 - f1_score: 0.7136 - val_loss: 0.9371 - val_accuracy: 0.6846 - val_recall: 0.6205 - val_precision: 0.7930 - val_f1_score: 0.3700
# Epoch 43/50
# 10691/10691 [==============================] - 116s 11ms/step - loss: 0.7155 - accuracy: 0.7190 - recall: 0.6117 - precision: 0.8853 - f1_score: 0.7138 - val_loss: 1.1484 - val_accuracy: 0.6411 - val_recall: 0.6050 - val_precision: 0.7580 - val_f1_score: 0.3378
# Epoch 44/50
# 10691/10691 [==============================] - 113s 11ms/step - loss: 0.7149 - accuracy: 0.7197 - recall: 0.6114 - precision: 0.8860 - f1_score: 0.7146 - val_loss: 0.9709 - val_accuracy: 0.6716 - val_recall: 0.6192 - val_precision: 0.7879 - val_f1_score: 0.3513
# Epoch 45/50
# 10691/10691 [==============================] - 115s 11ms/step - loss: 0.7135 - accuracy: 0.7205 - recall: 0.6125 - precision: 0.8856 - f1_score: 0.7153 - val_loss: 1.0517 - val_accuracy: 0.6693 - val_recall: 0.6247 - val_precision: 0.7927 - val_f1_score: 0.3481
# Epoch 46/50
# 10691/10691 [==============================] - 114s 11ms/step - loss: 0.7137 - accuracy: 0.7196 - recall: 0.6120 - precision: 0.8866 - f1_score: 0.7145 - val_loss: 1.0532 - val_accuracy: 0.6896 - val_recall: 0.6305 - val_precision: 0.8171 - val_f1_score: 0.3466
# Epoch 47/50
# 10691/10691 [==============================] - 113s 11ms/step - loss: 0.7125 - accuracy: 0.7210 - recall: 0.6129 - precision: 0.8875 - f1_score: 0.7159 - val_loss: 1.0535 - val_accuracy: 0.6683 - val_recall: 0.6112 - val_precision: 0.7803 - val_f1_score: 0.3482
# Epoch 48/50
# 10691/10691 [==============================] - 115s 11ms/step - loss: 0.7133 - accuracy: 0.7206 - recall: 0.6127 - precision: 0.8871 - f1_score: 0.7155 - val_loss: 1.1027 - val_accuracy: 0.6636 - val_recall: 0.6132 - val_precision: 0.7643 - val_f1_score: 0.3490
# Epoch 49/50
# 10691/10691 [==============================] - 113s 11ms/step - loss: 0.7126 - accuracy: 0.7202 - recall: 0.6128 - precision: 0.8869 - f1_score: 0.7151 - val_loss: 1.1261 - val_accuracy: 0.6838 - val_recall: 0.6490 - val_precision: 0.7703 - val_f1_score: 0.4038
# Epoch 50/50
# 10691/10691 [==============================] - 112s 11ms/step - loss: 0.7139 - accuracy: 0.7204 - recall: 0.6120 - precision: 0.8866 - f1_score: 0.7152 - val_loss: 1.0697 - val_accuracy: 0.6595 - val_recall: 0.6209 - val_precision: 0.7877 - val_f1_score: 0.3514

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall, precision, f1_score = model.evaluate(X_test, y_test)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
print('Test Precision:', precision)
print('Test F1-Score:', f1_score)
# Out:
# 1417/1417 [==============================] - 9s 6ms/step - loss: 1.0697 - accuracy: 0.6595 - recall: 0.6209 - precision: 0.7877 - f1_score: 0.3514
# Test Loss: 1.0697368383407593
# Test Accuracy: 0.6594674587249756
# Test Recall: 0.6209049224853516
# Test Precision: 0.7877134084701538
# Test F1-Score: 0.6944324407521603

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 1417/1417 [==============================] - 3s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.0413589364844904
# Backdoor: 0.37735849056603776
# DoS: 0.3379799461971142
# Exploits: 0.5200790584853113
# Fuzzers: 0.5975911565748226
# Generic: 0.9587197286842245
# Reconnaissance: 0.11301859799713877
# Shellcode: 0.873015873015873
# Worms: 0.7954545454545454

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import joblib

# %%
# save predicted
joblib.dump(predicted_classes, '/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/predicted_classes.joblib', compress=('zlib', 3))
# Out:
# ['/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/predicted_classes.joblib']

# %%
# load the predicted
predicted_classes = joblib.load('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/predicted_classes.joblib')
