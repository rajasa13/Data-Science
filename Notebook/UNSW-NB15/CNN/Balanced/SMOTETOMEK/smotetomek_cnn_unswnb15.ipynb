# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 6
# 5

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']
# ['INT' 'FIN' 'CON' 'REQ' 'RST']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'ACC') & (data_train_attack['state'] != 'CLO')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'RST')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 181, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Split Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((45329, 181), (45329,), (119329, 181), (119329,))

# %% [markdown]
# ## SMOTETomek

# %%
from imblearn.combine import SMOTETomek

smotetomek = SMOTETomek()
X_smotetomek, y_smotetomek = smotetomek.fit_resample(X_train, y_train)

X_smotetomek.shape, y_smotetomek.shape
# Out:
# ((159881, 181), (159881,))

# %%
#Create new dataframe from X_smotetomek and y_smotetomek to count every attack
data_smotetomek = pd.concat([X_smotetomek, y_smotetomek], axis=1)

sns.countplot(data=data_smotetomek, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Reconnaissance'),
#   Text(1, 0, 'Backdoor'),
#   Text(2, 0, 'DoS'),
#   Text(3, 0, 'Exploits'),
#   Text(4, 0, 'Analysis'),
#   Text(5, 0, 'Fuzzers'),
#   Text(6, 0, 'Worms'),
#   Text(7, 0, 'Shellcode'),
#   Text(8, 0, 'Generic')])

# %%
#data_smotetomek.drop_duplicates(inplace=True)
print(data_smotetomek.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_smotetomek.shape))
print("--------------------")
print("Duplicates: " + str(data_smotetomek.duplicated().sum()))
# Out:
# attack_cat
# Worms             18870
# Shellcode         18860
# Generic           18801
# Exploits          18566
# Reconnaissance    18533
# Fuzzers           18114
# DoS               18060
# Backdoor          15308
# Analysis          14769
# Name: count, dtype: int64
# --------------------
# Shape: (159881, 182)
# --------------------
# Duplicates: 46550

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (181, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall()])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 177, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 176, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5632)              0
#
#  batch_normalization (BatchN  (None, 5632)             22528
#  ormalization)
#
#  dropout (Dropout)           (None, 5632)              0
#
#  dense (Dense)               (None, 32)                180256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 203,657
# Trainable params: 192,393
# Non-trainable params: 11,264
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_smotetomek = le.fit_transform(y_smotetomek)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_smotetomek = to_categorical(y_smotetomek, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_smotetomek = np.array(X_smotetomek, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_smotetomek, y_smotetomek, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 4997/4997 [==============================] - 47s 9ms/step - loss: 0.9630 - accuracy: 0.6244 - recall: 0.4839 - val_loss: 1.2793 - val_accuracy: 0.5999 - val_recall: 0.5674
# Epoch 2/50
# 4997/4997 [==============================] - 42s 8ms/step - loss: 0.8290 - accuracy: 0.6718 - recall: 0.5590 - val_loss: 0.9977 - val_accuracy: 0.6611 - val_recall: 0.6259
# Epoch 3/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.7920 - accuracy: 0.6841 - recall: 0.5795 - val_loss: 0.9993 - val_accuracy: 0.6716 - val_recall: 0.6286
# Epoch 4/50
# 4997/4997 [==============================] - 46s 9ms/step - loss: 0.7694 - accuracy: 0.6931 - recall: 0.5933 - val_loss: 1.1217 - val_accuracy: 0.6431 - val_recall: 0.6072
# Epoch 5/50
# 4997/4997 [==============================] - 46s 9ms/step - loss: 0.7573 - accuracy: 0.6986 - recall: 0.6013 - val_loss: 0.9886 - val_accuracy: 0.6694 - val_recall: 0.6234
# Epoch 6/50
# 4997/4997 [==============================] - 47s 9ms/step - loss: 0.7454 - accuracy: 0.7033 - recall: 0.6086 - val_loss: 0.9716 - val_accuracy: 0.6854 - val_recall: 0.6471
# Epoch 7/50
# 4997/4997 [==============================] - 47s 9ms/step - loss: 0.7385 - accuracy: 0.7069 - recall: 0.6128 - val_loss: 0.9984 - val_accuracy: 0.6893 - val_recall: 0.6566
# Epoch 8/50
# 4997/4997 [==============================] - 47s 9ms/step - loss: 0.7298 - accuracy: 0.7110 - recall: 0.6184 - val_loss: 1.0006 - val_accuracy: 0.6856 - val_recall: 0.6478
# Epoch 9/50
# 4997/4997 [==============================] - 46s 9ms/step - loss: 0.7223 - accuracy: 0.7160 - recall: 0.6249 - val_loss: 1.0667 - val_accuracy: 0.6838 - val_recall: 0.6470
# Epoch 10/50
# 4997/4997 [==============================] - 46s 9ms/step - loss: 0.7168 - accuracy: 0.7185 - recall: 0.6310 - val_loss: 1.0507 - val_accuracy: 0.6658 - val_recall: 0.6285
# Epoch 11/50
# 4997/4997 [==============================] - 47s 9ms/step - loss: 0.7111 - accuracy: 0.7226 - recall: 0.6342 - val_loss: 0.9688 - val_accuracy: 0.6953 - val_recall: 0.6519
# Epoch 12/50
# 4997/4997 [==============================] - 46s 9ms/step - loss: 0.7051 - accuracy: 0.7265 - recall: 0.6387 - val_loss: 1.1652 - val_accuracy: 0.6593 - val_recall: 0.6227
# Epoch 13/50
# 4997/4997 [==============================] - 47s 9ms/step - loss: 0.7008 - accuracy: 0.7287 - recall: 0.6431 - val_loss: 1.0244 - val_accuracy: 0.6961 - val_recall: 0.6657
# Epoch 14/50
# 4997/4997 [==============================] - 47s 9ms/step - loss: 0.6931 - accuracy: 0.7319 - recall: 0.6473 - val_loss: 1.0010 - val_accuracy: 0.7069 - val_recall: 0.6768
# Epoch 15/50
# 4997/4997 [==============================] - 48s 10ms/step - loss: 0.6901 - accuracy: 0.7326 - recall: 0.6486 - val_loss: 1.0865 - val_accuracy: 0.6738 - val_recall: 0.6430
# Epoch 16/50
# 4997/4997 [==============================] - 46s 9ms/step - loss: 0.6871 - accuracy: 0.7348 - recall: 0.6510 - val_loss: 1.1153 - val_accuracy: 0.6897 - val_recall: 0.6623
# Epoch 17/50
# 4997/4997 [==============================] - 47s 9ms/step - loss: 0.6836 - accuracy: 0.7367 - recall: 0.6535 - val_loss: 1.0779 - val_accuracy: 0.6921 - val_recall: 0.6588
# Epoch 18/50
# 4997/4997 [==============================] - 45s 9ms/step - loss: 0.6798 - accuracy: 0.7367 - recall: 0.6550 - val_loss: 1.1159 - val_accuracy: 0.6703 - val_recall: 0.6381
# Epoch 19/50
# 4997/4997 [==============================] - 44s 9ms/step - loss: 0.6798 - accuracy: 0.7374 - recall: 0.6548 - val_loss: 1.0172 - val_accuracy: 0.6939 - val_recall: 0.6583
# Epoch 20/50
# 4997/4997 [==============================] - 42s 8ms/step - loss: 0.6779 - accuracy: 0.7391 - recall: 0.6570 - val_loss: 1.0569 - val_accuracy: 0.6933 - val_recall: 0.6522
# Epoch 21/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6740 - accuracy: 0.7401 - recall: 0.6582 - val_loss: 1.0562 - val_accuracy: 0.6978 - val_recall: 0.6633
# Epoch 22/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6722 - accuracy: 0.7399 - recall: 0.6594 - val_loss: 1.0516 - val_accuracy: 0.6858 - val_recall: 0.6460
# Epoch 23/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6688 - accuracy: 0.7413 - recall: 0.6616 - val_loss: 1.0645 - val_accuracy: 0.6814 - val_recall: 0.6485
# Epoch 24/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6694 - accuracy: 0.7417 - recall: 0.6599 - val_loss: 1.0413 - val_accuracy: 0.6975 - val_recall: 0.6669
# Epoch 25/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6672 - accuracy: 0.7426 - recall: 0.6607 - val_loss: 1.1245 - val_accuracy: 0.6728 - val_recall: 0.6420
# Epoch 26/50
# 4997/4997 [==============================] - 42s 8ms/step - loss: 0.6654 - accuracy: 0.7424 - recall: 0.6624 - val_loss: 0.9750 - val_accuracy: 0.6989 - val_recall: 0.6541
# Epoch 27/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6628 - accuracy: 0.7444 - recall: 0.6648 - val_loss: 1.0489 - val_accuracy: 0.6761 - val_recall: 0.6361
# Epoch 28/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6626 - accuracy: 0.7442 - recall: 0.6659 - val_loss: 0.9936 - val_accuracy: 0.7021 - val_recall: 0.6598
# Epoch 29/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6612 - accuracy: 0.7443 - recall: 0.6643 - val_loss: 1.0733 - val_accuracy: 0.6947 - val_recall: 0.6598
# Epoch 30/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6573 - accuracy: 0.7468 - recall: 0.6681 - val_loss: 1.0813 - val_accuracy: 0.6677 - val_recall: 0.6222
# Epoch 31/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6589 - accuracy: 0.7457 - recall: 0.6661 - val_loss: 1.0249 - val_accuracy: 0.6881 - val_recall: 0.6547
# Epoch 32/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6574 - accuracy: 0.7454 - recall: 0.6653 - val_loss: 0.9884 - val_accuracy: 0.6929 - val_recall: 0.6610
# Epoch 33/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6562 - accuracy: 0.7471 - recall: 0.6685 - val_loss: 0.9867 - val_accuracy: 0.7018 - val_recall: 0.6669
# Epoch 34/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6552 - accuracy: 0.7470 - recall: 0.6686 - val_loss: 1.0365 - val_accuracy: 0.6749 - val_recall: 0.6435
# Epoch 35/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6532 - accuracy: 0.7478 - recall: 0.6683 - val_loss: 0.9902 - val_accuracy: 0.7000 - val_recall: 0.6708
# Epoch 36/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6537 - accuracy: 0.7480 - recall: 0.6686 - val_loss: 1.1810 - val_accuracy: 0.6472 - val_recall: 0.6095
# Epoch 37/50
# 4997/4997 [==============================] - 44s 9ms/step - loss: 0.6521 - accuracy: 0.7480 - recall: 0.6698 - val_loss: 1.0584 - val_accuracy: 0.6794 - val_recall: 0.6570
# Epoch 38/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6497 - accuracy: 0.7490 - recall: 0.6703 - val_loss: 1.1070 - val_accuracy: 0.6719 - val_recall: 0.6359
# Epoch 39/50
# 4997/4997 [==============================] - 42s 8ms/step - loss: 0.6516 - accuracy: 0.7482 - recall: 0.6701 - val_loss: 1.0720 - val_accuracy: 0.6782 - val_recall: 0.6435
# Epoch 40/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6484 - accuracy: 0.7504 - recall: 0.6731 - val_loss: 1.0505 - val_accuracy: 0.6825 - val_recall: 0.6477
# Epoch 41/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6479 - accuracy: 0.7499 - recall: 0.6735 - val_loss: 1.0079 - val_accuracy: 0.6895 - val_recall: 0.6639
# Epoch 42/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6464 - accuracy: 0.7498 - recall: 0.6727 - val_loss: 1.0587 - val_accuracy: 0.6735 - val_recall: 0.6437
# Epoch 43/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6454 - accuracy: 0.7508 - recall: 0.6738 - val_loss: 1.0466 - val_accuracy: 0.6791 - val_recall: 0.6408
# Epoch 44/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6453 - accuracy: 0.7508 - recall: 0.6751 - val_loss: 1.0544 - val_accuracy: 0.6722 - val_recall: 0.6281
# Epoch 45/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6439 - accuracy: 0.7512 - recall: 0.6747 - val_loss: 1.0097 - val_accuracy: 0.6758 - val_recall: 0.6404
# Epoch 46/50
# 4997/4997 [==============================] - 44s 9ms/step - loss: 0.6436 - accuracy: 0.7523 - recall: 0.6754 - val_loss: 1.1258 - val_accuracy: 0.6580 - val_recall: 0.6223
# Epoch 47/50
# 4997/4997 [==============================] - 44s 9ms/step - loss: 0.6422 - accuracy: 0.7526 - recall: 0.6764 - val_loss: 1.0077 - val_accuracy: 0.6910 - val_recall: 0.6611
# Epoch 48/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6414 - accuracy: 0.7519 - recall: 0.6761 - val_loss: 1.0423 - val_accuracy: 0.6786 - val_recall: 0.6474
# Epoch 49/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6415 - accuracy: 0.7527 - recall: 0.6771 - val_loss: 1.0010 - val_accuracy: 0.6898 - val_recall: 0.6611
# Epoch 50/50
# 4997/4997 [==============================] - 43s 9ms/step - loss: 0.6416 - accuracy: 0.7534 - recall: 0.6767 - val_loss: 1.0478 - val_accuracy: 0.6826 - val_recall: 0.6550

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall = model.evaluate(X_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
# Out:
# 3730/3730 [==============================] - 14s 4ms/step - loss: 1.0478 - accuracy: 0.6826 - recall: 0.6550
# Test Loss: 1.0478042364120483
# Test Accuracy: 0.6826336979866028
# Test Recall: 0.6550377607345581

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 3730/3730 [==============================] - 6s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.1125
# Backdoor: 0.09679266895761741
# DoS: 0.6642472679823846
# Exploits: 0.4462049961061523
# Fuzzers: 0.722778266608007
# Generic: 0.9778744468611715
# Reconnaissance: 0.4901325197826294
# Shellcode: 0.5110326566637247
# Worms: 0.34615384615384615

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import pickle

# %%
# save the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/predicted_classes.pkl', 'wb') as model_file:
    pickle.dump(predicted_classes, model_file)

# %%
# load the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/predicted_classes.pkl', 'rb') as model_file:
    predicted_classes = pickle.load(model_file)
