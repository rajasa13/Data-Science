# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall, Precision

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 6
# 5

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']
# ['INT' 'FIN' 'CON' 'REQ' 'RST']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'ACC') & (data_train_attack['state'] != 'CLO')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'RST')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 181, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Initialize Train Data and Test Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((45329, 181), (45329,), (119329, 181), (119329,))

# %% [markdown]
# ## SMOTETomek

# %%
from imblearn.combine import SMOTETomek

smotetomek = SMOTETomek()
X_smotetomek, y_smotetomek = smotetomek.fit_resample(X_train, y_train)

X_smotetomek.shape, y_smotetomek.shape
# Out:
# ((159665, 181), (159665,))

# %%
#Create new dataframe from X_smotetomek and y_smotetomek to count every attack
data_smotetomek = pd.concat([X_smotetomek, y_smotetomek], axis=1)

sns.countplot(data=data_smotetomek, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Reconnaissance'),
#   Text(1, 0, 'Backdoor'),
#   Text(2, 0, 'DoS'),
#   Text(3, 0, 'Exploits'),
#   Text(4, 0, 'Analysis'),
#   Text(5, 0, 'Fuzzers'),
#   Text(6, 0, 'Worms'),
#   Text(7, 0, 'Shellcode'),
#   Text(8, 0, 'Generic')])

# %%
#data_smotetomek.drop_duplicates(inplace=True)
print(data_smotetomek.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_smotetomek.shape))
print("--------------------")
print("Duplicates: " + str(data_smotetomek.duplicated().sum()))
# Out:
# attack_cat
# Worms             18871
# Shellcode         18860
# Generic           18807
# Exploits          18572
# Reconnaissance    18539
# Fuzzers           18056
# DoS               17955
# Backdoor          15314
# Analysis          14721
# Name: count, dtype: int64
# --------------------
# Shape: (159695, 182)
# --------------------
# Duplicates: 46853

# %% [markdown]
# # Model Architecture

# %%
# from keras import backend as K
import tensorflow_addons as tfa
# Out:
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (181, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision(), tfa.metrics.F1Score(num_classes=9, 
                                                                                                                                 average='macro')])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 177, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 176, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5632)              0
#
#  batch_normalization (BatchN  (None, 5632)             22528
#  ormalization)
#
#  dropout (Dropout)           (None, 5632)              0
#
#  dense (Dense)               (None, 32)                180256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 203,657
# Trainable params: 192,393
# Non-trainable params: 11,264
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_smotetomek = le.fit_transform(y_smotetomek)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_smotetomek = to_categorical(y_smotetomek, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_smotetomek = np.array(X_smotetomek, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_smotetomek, y_smotetomek, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 4991/4991 [==============================] - 55s 10ms/step - loss: 0.9621 - accuracy: 0.6281 - recall: 0.4863 - precision: 0.7384 - f1_score: 0.6172 - val_loss: 0.9351 - val_accuracy: 0.6813 - val_recall: 0.6328 - val_precision: 0.7633 - val_f1_score: 0.4131
# Epoch 2/50
# 4991/4991 [==============================] - 51s 10ms/step - loss: 0.8317 - accuracy: 0.6725 - recall: 0.5602 - precision: 0.7678 - f1_score: 0.6638 - val_loss: 0.9355 - val_accuracy: 0.6847 - val_recall: 0.6417 - val_precision: 0.7593 - val_f1_score: 0.4197
# Epoch 3/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7901 - accuracy: 0.6865 - recall: 0.5829 - precision: 0.7790 - f1_score: 0.6783 - val_loss: 0.9580 - val_accuracy: 0.6804 - val_recall: 0.6404 - val_precision: 0.7401 - val_f1_score: 0.4159
# Epoch 4/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7718 - accuracy: 0.6944 - recall: 0.5944 - precision: 0.7843 - f1_score: 0.6861 - val_loss: 0.9518 - val_accuracy: 0.6891 - val_recall: 0.6340 - val_precision: 0.7942 - val_f1_score: 0.4306
# Epoch 5/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7576 - accuracy: 0.7008 - recall: 0.6029 - precision: 0.7891 - f1_score: 0.6927 - val_loss: 0.9490 - val_accuracy: 0.6873 - val_recall: 0.6471 - val_precision: 0.7617 - val_f1_score: 0.4244
# Epoch 6/50
# 4991/4991 [==============================] - 51s 10ms/step - loss: 0.7474 - accuracy: 0.7054 - recall: 0.6093 - precision: 0.7931 - f1_score: 0.6970 - val_loss: 0.9955 - val_accuracy: 0.6740 - val_recall: 0.6234 - val_precision: 0.7907 - val_f1_score: 0.4221
# Epoch 7/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7400 - accuracy: 0.7109 - recall: 0.6168 - precision: 0.7947 - f1_score: 0.7025 - val_loss: 0.9703 - val_accuracy: 0.6828 - val_recall: 0.6311 - val_precision: 0.7515 - val_f1_score: 0.4147
# Epoch 8/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7320 - accuracy: 0.7133 - recall: 0.6191 - precision: 0.7982 - f1_score: 0.7047 - val_loss: 0.9714 - val_accuracy: 0.7020 - val_recall: 0.6675 - val_precision: 0.7486 - val_f1_score: 0.4368
# Epoch 9/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7241 - accuracy: 0.7178 - recall: 0.6269 - precision: 0.7996 - f1_score: 0.7092 - val_loss: 1.0271 - val_accuracy: 0.6843 - val_recall: 0.6427 - val_precision: 0.7629 - val_f1_score: 0.4292
# Epoch 10/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7182 - accuracy: 0.7190 - recall: 0.6308 - precision: 0.8016 - f1_score: 0.7102 - val_loss: 1.0003 - val_accuracy: 0.6988 - val_recall: 0.6628 - val_precision: 0.7587 - val_f1_score: 0.4356
# Epoch 11/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7141 - accuracy: 0.7225 - recall: 0.6363 - precision: 0.8035 - f1_score: 0.7138 - val_loss: 0.9655 - val_accuracy: 0.6944 - val_recall: 0.6463 - val_precision: 0.7814 - val_f1_score: 0.4406
# Epoch 12/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7052 - accuracy: 0.7265 - recall: 0.6412 - precision: 0.8074 - f1_score: 0.7175 - val_loss: 0.9964 - val_accuracy: 0.6865 - val_recall: 0.6461 - val_precision: 0.7520 - val_f1_score: 0.4310
# Epoch 13/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.7016 - accuracy: 0.7292 - recall: 0.6446 - precision: 0.8087 - f1_score: 0.7201 - val_loss: 0.9818 - val_accuracy: 0.6747 - val_recall: 0.6296 - val_precision: 0.7523 - val_f1_score: 0.4105
# Epoch 14/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6969 - accuracy: 0.7307 - recall: 0.6459 - precision: 0.8120 - f1_score: 0.7215 - val_loss: 0.9650 - val_accuracy: 0.6819 - val_recall: 0.6421 - val_precision: 0.7422 - val_f1_score: 0.4206
# Epoch 15/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6913 - accuracy: 0.7329 - recall: 0.6504 - precision: 0.8122 - f1_score: 0.7238 - val_loss: 1.0040 - val_accuracy: 0.6660 - val_recall: 0.6157 - val_precision: 0.7728 - val_f1_score: 0.4071
# Epoch 16/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6857 - accuracy: 0.7355 - recall: 0.6535 - precision: 0.8131 - f1_score: 0.7263 - val_loss: 1.0113 - val_accuracy: 0.6676 - val_recall: 0.6356 - val_precision: 0.7188 - val_f1_score: 0.4049
# Epoch 17/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6825 - accuracy: 0.7374 - recall: 0.6545 - precision: 0.8158 - f1_score: 0.7281 - val_loss: 1.0522 - val_accuracy: 0.6657 - val_recall: 0.6326 - val_precision: 0.7232 - val_f1_score: 0.3981
# Epoch 18/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6783 - accuracy: 0.7381 - recall: 0.6573 - precision: 0.8167 - f1_score: 0.7286 - val_loss: 1.0470 - val_accuracy: 0.6651 - val_recall: 0.6358 - val_precision: 0.7122 - val_f1_score: 0.4109
# Epoch 19/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6781 - accuracy: 0.7394 - recall: 0.6580 - precision: 0.8182 - f1_score: 0.7303 - val_loss: 0.9641 - val_accuracy: 0.7038 - val_recall: 0.6599 - val_precision: 0.7848 - val_f1_score: 0.4522
# Epoch 20/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6734 - accuracy: 0.7409 - recall: 0.6604 - precision: 0.8191 - f1_score: 0.7316 - val_loss: 0.9511 - val_accuracy: 0.6960 - val_recall: 0.6545 - val_precision: 0.7723 - val_f1_score: 0.4562
# Epoch 21/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6737 - accuracy: 0.7406 - recall: 0.6592 - precision: 0.8198 - f1_score: 0.7314 - val_loss: 1.0069 - val_accuracy: 0.6708 - val_recall: 0.6380 - val_precision: 0.7231 - val_f1_score: 0.4041
# Epoch 22/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6709 - accuracy: 0.7415 - recall: 0.6613 - precision: 0.8207 - f1_score: 0.7320 - val_loss: 0.9655 - val_accuracy: 0.6960 - val_recall: 0.6548 - val_precision: 0.7861 - val_f1_score: 0.4576
# Epoch 23/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6685 - accuracy: 0.7426 - recall: 0.6630 - precision: 0.8210 - f1_score: 0.7332 - val_loss: 1.0240 - val_accuracy: 0.6948 - val_recall: 0.6607 - val_precision: 0.7769 - val_f1_score: 0.4504
# Epoch 24/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6667 - accuracy: 0.7429 - recall: 0.6636 - precision: 0.8210 - f1_score: 0.7335 - val_loss: 1.0231 - val_accuracy: 0.6684 - val_recall: 0.6362 - val_precision: 0.7311 - val_f1_score: 0.4148
# Epoch 25/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6640 - accuracy: 0.7437 - recall: 0.6646 - precision: 0.8222 - f1_score: 0.7342 - val_loss: 1.0869 - val_accuracy: 0.6629 - val_recall: 0.6345 - val_precision: 0.7056 - val_f1_score: 0.4037
# Epoch 26/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6633 - accuracy: 0.7446 - recall: 0.6655 - precision: 0.8234 - f1_score: 0.7354 - val_loss: 0.9764 - val_accuracy: 0.6936 - val_recall: 0.6672 - val_precision: 0.7571 - val_f1_score: 0.4481
# Epoch 27/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6604 - accuracy: 0.7461 - recall: 0.6661 - precision: 0.8242 - f1_score: 0.7368 - val_loss: 0.9615 - val_accuracy: 0.7011 - val_recall: 0.6575 - val_precision: 0.7832 - val_f1_score: 0.4543
# Epoch 28/50
# 4991/4991 [==============================] - 52s 11ms/step - loss: 0.6598 - accuracy: 0.7461 - recall: 0.6677 - precision: 0.8229 - f1_score: 0.7366 - val_loss: 1.0340 - val_accuracy: 0.6705 - val_recall: 0.6431 - val_precision: 0.7173 - val_f1_score: 0.4100
# Epoch 29/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6602 - accuracy: 0.7467 - recall: 0.6667 - precision: 0.8243 - f1_score: 0.7372 - val_loss: 1.0344 - val_accuracy: 0.6745 - val_recall: 0.6352 - val_precision: 0.7493 - val_f1_score: 0.4149
# Epoch 30/50
# 4991/4991 [==============================] - 52s 11ms/step - loss: 0.6576 - accuracy: 0.7475 - recall: 0.6681 - precision: 0.8245 - f1_score: 0.7380 - val_loss: 1.0063 - val_accuracy: 0.6907 - val_recall: 0.6564 - val_precision: 0.7687 - val_f1_score: 0.4467
# Epoch 31/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6568 - accuracy: 0.7478 - recall: 0.6671 - precision: 0.8261 - f1_score: 0.7384 - val_loss: 0.9578 - val_accuracy: 0.6910 - val_recall: 0.6592 - val_precision: 0.7479 - val_f1_score: 0.4449
# Epoch 32/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6560 - accuracy: 0.7488 - recall: 0.6692 - precision: 0.8261 - f1_score: 0.7394 - val_loss: 0.9390 - val_accuracy: 0.6856 - val_recall: 0.6448 - val_precision: 0.7592 - val_f1_score: 0.4244
# Epoch 33/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6549 - accuracy: 0.7483 - recall: 0.6695 - precision: 0.8254 - f1_score: 0.7387 - val_loss: 1.0165 - val_accuracy: 0.6764 - val_recall: 0.6452 - val_precision: 0.7479 - val_f1_score: 0.4186
# Epoch 34/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6537 - accuracy: 0.7483 - recall: 0.6698 - precision: 0.8254 - f1_score: 0.7387 - val_loss: 1.0516 - val_accuracy: 0.6869 - val_recall: 0.6612 - val_precision: 0.7341 - val_f1_score: 0.4173
# Epoch 35/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6542 - accuracy: 0.7480 - recall: 0.6694 - precision: 0.8253 - f1_score: 0.7385 - val_loss: 1.0471 - val_accuracy: 0.6700 - val_recall: 0.6348 - val_precision: 0.7245 - val_f1_score: 0.4047
# Epoch 36/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6508 - accuracy: 0.7502 - recall: 0.6719 - precision: 0.8261 - f1_score: 0.7407 - val_loss: 0.9306 - val_accuracy: 0.6845 - val_recall: 0.6407 - val_precision: 0.7731 - val_f1_score: 0.4290
# Epoch 37/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6524 - accuracy: 0.7493 - recall: 0.6712 - precision: 0.8261 - f1_score: 0.7398 - val_loss: 0.9651 - val_accuracy: 0.6935 - val_recall: 0.6565 - val_precision: 0.7516 - val_f1_score: 0.4404
# Epoch 38/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6512 - accuracy: 0.7491 - recall: 0.6709 - precision: 0.8260 - f1_score: 0.7395 - val_loss: 0.9882 - val_accuracy: 0.6817 - val_recall: 0.6442 - val_precision: 0.7462 - val_f1_score: 0.4101
# Epoch 39/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6504 - accuracy: 0.7502 - recall: 0.6709 - precision: 0.8277 - f1_score: 0.7407 - val_loss: 0.9766 - val_accuracy: 0.6975 - val_recall: 0.6667 - val_precision: 0.7541 - val_f1_score: 0.4405
# Epoch 40/50
# 4991/4991 [==============================] - 52s 11ms/step - loss: 0.6494 - accuracy: 0.7503 - recall: 0.6722 - precision: 0.8279 - f1_score: 0.7407 - val_loss: 0.9507 - val_accuracy: 0.6952 - val_recall: 0.6617 - val_precision: 0.7657 - val_f1_score: 0.4538
# Epoch 41/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6484 - accuracy: 0.7514 - recall: 0.6723 - precision: 0.8283 - f1_score: 0.7421 - val_loss: 1.0392 - val_accuracy: 0.6689 - val_recall: 0.6279 - val_precision: 0.7348 - val_f1_score: 0.4092
# Epoch 42/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6485 - accuracy: 0.7515 - recall: 0.6724 - precision: 0.8287 - f1_score: 0.7421 - val_loss: 0.9343 - val_accuracy: 0.6867 - val_recall: 0.6507 - val_precision: 0.7459 - val_f1_score: 0.4293
# Epoch 43/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6475 - accuracy: 0.7522 - recall: 0.6739 - precision: 0.8283 - f1_score: 0.7427 - val_loss: 0.9898 - val_accuracy: 0.6660 - val_recall: 0.6320 - val_precision: 0.7377 - val_f1_score: 0.4151
# Epoch 44/50
# 4991/4991 [==============================] - 53s 11ms/step - loss: 0.6460 - accuracy: 0.7526 - recall: 0.6737 - precision: 0.8286 - f1_score: 0.7432 - val_loss: 0.9318 - val_accuracy: 0.6842 - val_recall: 0.6500 - val_precision: 0.7420 - val_f1_score: 0.4271
# Epoch 45/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6459 - accuracy: 0.7526 - recall: 0.6748 - precision: 0.8283 - f1_score: 0.7430 - val_loss: 1.1360 - val_accuracy: 0.6506 - val_recall: 0.6199 - val_precision: 0.7222 - val_f1_score: 0.4178
# Epoch 46/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6445 - accuracy: 0.7526 - recall: 0.6734 - precision: 0.8294 - f1_score: 0.7429 - val_loss: 1.0031 - val_accuracy: 0.6834 - val_recall: 0.6554 - val_precision: 0.7304 - val_f1_score: 0.4201
# Epoch 47/50
# 4991/4991 [==============================] - 52s 11ms/step - loss: 0.6444 - accuracy: 0.7524 - recall: 0.6750 - precision: 0.8291 - f1_score: 0.7430 - val_loss: 1.0198 - val_accuracy: 0.6689 - val_recall: 0.6357 - val_precision: 0.7256 - val_f1_score: 0.4157
# Epoch 48/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6423 - accuracy: 0.7542 - recall: 0.6750 - precision: 0.8310 - f1_score: 0.7446 - val_loss: 0.9606 - val_accuracy: 0.6916 - val_recall: 0.6602 - val_precision: 0.7574 - val_f1_score: 0.4434
# Epoch 49/50
# 4991/4991 [==============================] - 52s 10ms/step - loss: 0.6424 - accuracy: 0.7530 - recall: 0.6755 - precision: 0.8299 - f1_score: 0.7432 - val_loss: 0.9763 - val_accuracy: 0.6864 - val_recall: 0.6565 - val_precision: 0.7351 - val_f1_score: 0.4261
# Epoch 50/50
# 4991/4991 [==============================] - 52s 11ms/step - loss: 0.6411 - accuracy: 0.7531 - recall: 0.6758 - precision: 0.8309 - f1_score: 0.7433 - val_loss: 0.9713 - val_accuracy: 0.6772 - val_recall: 0.6342 - val_precision: 0.7678 - val_f1_score: 0.4341

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall, precision, f1_score = model.evaluate(X_test, y_test)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
print('Test Precision:', precision)
print('Test F1-Score:', f1_score)
# Out:
# 3730/3730 [==============================] - 66s 16ms/step - loss: 0.9713 - accuracy: 0.6772 - recall: 0.6342 - precision: 0.7678 - f1_score: 0.4341
# Test Loss: 0.9712881445884705
# Test Accuracy: 0.6771866083145142
# Test Recall: 0.6341794729232788
# Test Precision: 0.7677931785583496
# Test F1-Score: 0.6946193604813035

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 3730/3730 [==============================] - 6s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.1985
# Backdoor: 0.14146620847651775
# DoS: 0.5926439406295874
# Exploits: 0.4253579344635476
# Fuzzers: 0.7420809502859657
# Generic: 0.9774744368609215
# Reconnaissance: 0.507865382781962
# Shellcode: 0.6425419240953222
# Worms: 0.3769230769230769

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import pickle

# %%
# save the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/predicted_classes.pkl', 'wb') as model_file:
    pickle.dump(predicted_classes, model_file)

# %%
# load the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTETOMEK/Saved/predicted_classes.pkl', 'rb') as model_file:
    predicted_classes = pickle.load(model_file)
