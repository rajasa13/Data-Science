# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall, Precision

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data-Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data-Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 5
# 6

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ' 'RST']
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'RST')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'ACC') & (data_test_attack['state'] != 'CLO')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 182, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Initialize Train Data and Test Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((119329, 182), (119329,), (45329, 182), (45329,))

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_smote, y_smote = smote.fit_resample(X_train, y_train)

X_smote.shape, y_smote.shape
# Out:
# ((359991, 182), (359991,))

# %%
#Create new dataframe from X_smote and y_smote to count every attack
data_smote = pd.concat([X_smote, y_smote], axis=1)

sns.countplot(data=data_smote, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Backdoor'),
#   Text(1, 0, 'Analysis'),
#   Text(2, 0, 'Fuzzers'),
#   Text(3, 0, 'Shellcode'),
#   Text(4, 0, 'Reconnaissance'),
#   Text(5, 0, 'Exploits'),
#   Text(6, 0, 'DoS'),
#   Text(7, 0, 'Worms'),
#   Text(8, 0, 'Generic')])

# %%
#data_smote.drop_duplicates(inplace=True)
print(data_smote.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_smote.shape))
print("--------------------")
print("Duplicates: " + str(data_smote.duplicated().sum()))
# Out:
# attack_cat
# Analysis          39999
# Backdoor          39999
# DoS               39999
# Exploits          39999
# Fuzzers           39999
# Generic           39999
# Reconnaissance    39999
# Shellcode         39999
# Worms             39999
# Name: count, dtype: int64
# --------------------
# Shape: (359991, 183)
# --------------------
# Duplicates: 107997

# %% [markdown]
# # Model Architecture

# %%
# from keras import backend as K
import tensorflow_addons as tfa
# Out:
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (182, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision(), tfa.metrics.F1Score(num_classes=9, 
                                                                                                                                 average='macro')])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 178, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 177, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5664)              0
#
#  batch_normalization (BatchN  (None, 5664)             22656
#  ormalization)
#
#  dropout (Dropout)           (None, 5664)              0
#
#  dense (Dense)               (None, 32)                181280
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 204,809
# Trainable params: 193,481
# Non-trainable params: 11,328
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_smote = le.fit_transform(y_smote)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_smote = to_categorical(y_smote, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_smote = np.array(X_smote, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_smote, y_smote, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 11250/11250 [==============================] - 97s 8ms/step - loss: 1.0103 - accuracy: 0.5856 - recall: 0.4318 - precision: 0.8078 - f1_score: 0.5864 - val_loss: 0.9856 - val_accuracy: 0.6260 - val_recall: 0.5871 - val_precision: 0.7769 - val_f1_score: 0.3272
# Epoch 2/50
# 11250/11250 [==============================] - 93s 8ms/step - loss: 0.9121 - accuracy: 0.6282 - recall: 0.4919 - precision: 0.8341 - f1_score: 0.6322 - val_loss: 0.9795 - val_accuracy: 0.6346 - val_recall: 0.6003 - val_precision: 0.7733 - val_f1_score: 0.3267
# Epoch 3/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.8783 - accuracy: 0.6459 - recall: 0.5188 - precision: 0.8459 - f1_score: 0.6504 - val_loss: 0.9286 - val_accuracy: 0.6379 - val_recall: 0.6005 - val_precision: 0.7822 - val_f1_score: 0.3331
# Epoch 4/50
# 11250/11250 [==============================] - 102s 9ms/step - loss: 0.8552 - accuracy: 0.6563 - recall: 0.5343 - precision: 0.8528 - f1_score: 0.6610 - val_loss: 1.1262 - val_accuracy: 0.6149 - val_recall: 0.5848 - val_precision: 0.7501 - val_f1_score: 0.3201
# Epoch 5/50
# 11250/11250 [==============================] - 99s 9ms/step - loss: 0.8409 - accuracy: 0.6630 - recall: 0.5422 - precision: 0.8579 - f1_score: 0.6677 - val_loss: 1.0242 - val_accuracy: 0.6359 - val_recall: 0.5984 - val_precision: 0.7705 - val_f1_score: 0.3471
# Epoch 6/50
# 11250/11250 [==============================] - 100s 9ms/step - loss: 0.8311 - accuracy: 0.6667 - recall: 0.5465 - precision: 0.8619 - f1_score: 0.6713 - val_loss: 0.9445 - val_accuracy: 0.6651 - val_recall: 0.6318 - val_precision: 0.8199 - val_f1_score: 0.3897
# Epoch 7/50
# 11250/11250 [==============================] - 103s 9ms/step - loss: 0.8233 - accuracy: 0.6694 - recall: 0.5508 - precision: 0.8638 - f1_score: 0.6742 - val_loss: 0.8922 - val_accuracy: 0.6787 - val_recall: 0.6315 - val_precision: 0.8295 - val_f1_score: 0.3674
# Epoch 8/50
# 11250/11250 [==============================] - 104s 9ms/step - loss: 0.8164 - accuracy: 0.6730 - recall: 0.5545 - precision: 0.8654 - f1_score: 0.6775 - val_loss: 0.9955 - val_accuracy: 0.6583 - val_recall: 0.6269 - val_precision: 0.8037 - val_f1_score: 0.3863
# Epoch 9/50
# 11250/11250 [==============================] - 102s 9ms/step - loss: 0.8114 - accuracy: 0.6756 - recall: 0.5577 - precision: 0.8671 - f1_score: 0.6800 - val_loss: 1.0396 - val_accuracy: 0.6408 - val_recall: 0.6037 - val_precision: 0.7784 - val_f1_score: 0.3404
# Epoch 10/50
# 11250/11250 [==============================] - 102s 9ms/step - loss: 0.8067 - accuracy: 0.6772 - recall: 0.5599 - precision: 0.8688 - f1_score: 0.6817 - val_loss: 0.9995 - val_accuracy: 0.6450 - val_recall: 0.6153 - val_precision: 0.7856 - val_f1_score: 0.3662
# Epoch 11/50
# 11250/11250 [==============================] - 104s 9ms/step - loss: 0.8030 - accuracy: 0.6782 - recall: 0.5616 - precision: 0.8698 - f1_score: 0.6825 - val_loss: 0.9316 - val_accuracy: 0.6506 - val_recall: 0.6153 - val_precision: 0.7983 - val_f1_score: 0.3619
# Epoch 12/50
# 11250/11250 [==============================] - 103s 9ms/step - loss: 0.7994 - accuracy: 0.6796 - recall: 0.5632 - precision: 0.8708 - f1_score: 0.6839 - val_loss: 0.9958 - val_accuracy: 0.6504 - val_recall: 0.6136 - val_precision: 0.7950 - val_f1_score: 0.3482
# Epoch 13/50
# 11250/11250 [==============================] - 102s 9ms/step - loss: 0.7967 - accuracy: 0.6800 - recall: 0.5638 - precision: 0.8706 - f1_score: 0.6841 - val_loss: 0.8706 - val_accuracy: 0.6901 - val_recall: 0.6578 - val_precision: 0.8584 - val_f1_score: 0.4058
# Epoch 14/50
# 11250/11250 [==============================] - 104s 9ms/step - loss: 0.7942 - accuracy: 0.6817 - recall: 0.5655 - precision: 0.8716 - f1_score: 0.6858 - val_loss: 1.2414 - val_accuracy: 0.6324 - val_recall: 0.5835 - val_precision: 0.7415 - val_f1_score: 0.3298
# Epoch 15/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7916 - accuracy: 0.6828 - recall: 0.5676 - precision: 0.8721 - f1_score: 0.6871 - val_loss: 0.9558 - val_accuracy: 0.6646 - val_recall: 0.6213 - val_precision: 0.8221 - val_f1_score: 0.3406
# Epoch 16/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7891 - accuracy: 0.6839 - recall: 0.5683 - precision: 0.8722 - f1_score: 0.6882 - val_loss: 0.9583 - val_accuracy: 0.6656 - val_recall: 0.6363 - val_precision: 0.8108 - val_f1_score: 0.3823
# Epoch 17/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7875 - accuracy: 0.6840 - recall: 0.5695 - precision: 0.8730 - f1_score: 0.6883 - val_loss: 1.0102 - val_accuracy: 0.6384 - val_recall: 0.6088 - val_precision: 0.7707 - val_f1_score: 0.3389
# Epoch 18/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7850 - accuracy: 0.6853 - recall: 0.5705 - precision: 0.8739 - f1_score: 0.6895 - val_loss: 1.0981 - val_accuracy: 0.6631 - val_recall: 0.6266 - val_precision: 0.8203 - val_f1_score: 0.3265
# Epoch 19/50
# 11250/11250 [==============================] - 108s 10ms/step - loss: 0.7841 - accuracy: 0.6854 - recall: 0.5710 - precision: 0.8745 - f1_score: 0.6899 - val_loss: 1.0062 - val_accuracy: 0.6498 - val_recall: 0.6142 - val_precision: 0.7919 - val_f1_score: 0.3473
# Epoch 20/50
# 11250/11250 [==============================] - 104s 9ms/step - loss: 0.7828 - accuracy: 0.6870 - recall: 0.5721 - precision: 0.8742 - f1_score: 0.6914 - val_loss: 1.1855 - val_accuracy: 0.6612 - val_recall: 0.6212 - val_precision: 0.8003 - val_f1_score: 0.3220
# Epoch 21/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7806 - accuracy: 0.6879 - recall: 0.5728 - precision: 0.8753 - f1_score: 0.6923 - val_loss: 1.0805 - val_accuracy: 0.6499 - val_recall: 0.6087 - val_precision: 0.7719 - val_f1_score: 0.3496
# Epoch 22/50
# 11250/11250 [==============================] - 107s 10ms/step - loss: 0.7797 - accuracy: 0.6875 - recall: 0.5732 - precision: 0.8751 - f1_score: 0.6918 - val_loss: 1.1627 - val_accuracy: 0.6222 - val_recall: 0.5849 - val_precision: 0.7482 - val_f1_score: 0.3369
# Epoch 23/50
# 11250/11250 [==============================] - 107s 10ms/step - loss: 0.7792 - accuracy: 0.6880 - recall: 0.5747 - precision: 0.8753 - f1_score: 0.6924 - val_loss: 0.9521 - val_accuracy: 0.6468 - val_recall: 0.6065 - val_precision: 0.7699 - val_f1_score: 0.3380
# Epoch 24/50
# 11250/11250 [==============================] - 107s 10ms/step - loss: 0.7785 - accuracy: 0.6882 - recall: 0.5753 - precision: 0.8757 - f1_score: 0.6927 - val_loss: 0.9280 - val_accuracy: 0.6570 - val_recall: 0.6254 - val_precision: 0.7990 - val_f1_score: 0.3688
# Epoch 25/50
# 11250/11250 [==============================] - 107s 10ms/step - loss: 0.7773 - accuracy: 0.6879 - recall: 0.5752 - precision: 0.8751 - f1_score: 0.6926 - val_loss: 0.9813 - val_accuracy: 0.6493 - val_recall: 0.6137 - val_precision: 0.7852 - val_f1_score: 0.3515
# Epoch 26/50
# 11250/11250 [==============================] - 104s 9ms/step - loss: 0.7764 - accuracy: 0.6886 - recall: 0.5754 - precision: 0.8762 - f1_score: 0.6931 - val_loss: 0.9968 - val_accuracy: 0.6523 - val_recall: 0.6127 - val_precision: 0.7763 - val_f1_score: 0.3463
# Epoch 27/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7743 - accuracy: 0.6901 - recall: 0.5768 - precision: 0.8765 - f1_score: 0.6946 - val_loss: 0.9639 - val_accuracy: 0.6435 - val_recall: 0.6131 - val_precision: 0.7742 - val_f1_score: 0.3480
# Epoch 28/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7735 - accuracy: 0.6893 - recall: 0.5764 - precision: 0.8769 - f1_score: 0.6937 - val_loss: 0.9607 - val_accuracy: 0.6546 - val_recall: 0.6123 - val_precision: 0.7838 - val_f1_score: 0.3474
# Epoch 29/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7729 - accuracy: 0.6904 - recall: 0.5773 - precision: 0.8774 - f1_score: 0.6949 - val_loss: 1.0259 - val_accuracy: 0.6493 - val_recall: 0.6094 - val_precision: 0.7641 - val_f1_score: 0.3595
# Epoch 30/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7731 - accuracy: 0.6909 - recall: 0.5776 - precision: 0.8771 - f1_score: 0.6952 - val_loss: 0.9926 - val_accuracy: 0.6513 - val_recall: 0.6113 - val_precision: 0.8018 - val_f1_score: 0.3431
# Epoch 31/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7711 - accuracy: 0.6912 - recall: 0.5783 - precision: 0.8780 - f1_score: 0.6956 - val_loss: 1.2627 - val_accuracy: 0.6481 - val_recall: 0.6161 - val_precision: 0.7774 - val_f1_score: 0.3198
# Epoch 32/50
# 11250/11250 [==============================] - 107s 10ms/step - loss: 0.7698 - accuracy: 0.6912 - recall: 0.5787 - precision: 0.8779 - f1_score: 0.6955 - val_loss: 0.9624 - val_accuracy: 0.6612 - val_recall: 0.6288 - val_precision: 0.8032 - val_f1_score: 0.3801
# Epoch 33/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7699 - accuracy: 0.6911 - recall: 0.5788 - precision: 0.8782 - f1_score: 0.6957 - val_loss: 1.0089 - val_accuracy: 0.6526 - val_recall: 0.6177 - val_precision: 0.7718 - val_f1_score: 0.3586
# Epoch 34/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7686 - accuracy: 0.6923 - recall: 0.5802 - precision: 0.8791 - f1_score: 0.6969 - val_loss: 1.0977 - val_accuracy: 0.6421 - val_recall: 0.5979 - val_precision: 0.7584 - val_f1_score: 0.3337
# Epoch 35/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7680 - accuracy: 0.6920 - recall: 0.5802 - precision: 0.8791 - f1_score: 0.6963 - val_loss: 1.0492 - val_accuracy: 0.6467 - val_recall: 0.6119 - val_precision: 0.7674 - val_f1_score: 0.3356
# Epoch 36/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7672 - accuracy: 0.6918 - recall: 0.5808 - precision: 0.8788 - f1_score: 0.6963 - val_loss: 1.2304 - val_accuracy: 0.6699 - val_recall: 0.6287 - val_precision: 0.8081 - val_f1_score: 0.3260
# Epoch 37/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7668 - accuracy: 0.6929 - recall: 0.5811 - precision: 0.8792 - f1_score: 0.6973 - val_loss: 1.0339 - val_accuracy: 0.6601 - val_recall: 0.6201 - val_precision: 0.7819 - val_f1_score: 0.3574
# Epoch 38/50
# 11250/11250 [==============================] - 109s 10ms/step - loss: 0.7655 - accuracy: 0.6931 - recall: 0.5809 - precision: 0.8798 - f1_score: 0.6977 - val_loss: 1.1545 - val_accuracy: 0.6437 - val_recall: 0.6022 - val_precision: 0.7519 - val_f1_score: 0.3401
# Epoch 39/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7633 - accuracy: 0.6941 - recall: 0.5826 - precision: 0.8801 - f1_score: 0.6987 - val_loss: 1.0334 - val_accuracy: 0.6504 - val_recall: 0.6127 - val_precision: 0.7708 - val_f1_score: 0.3471
# Epoch 40/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7626 - accuracy: 0.6937 - recall: 0.5822 - precision: 0.8809 - f1_score: 0.6983 - val_loss: 1.0760 - val_accuracy: 0.6563 - val_recall: 0.6185 - val_precision: 0.7970 - val_f1_score: 0.3468
# Epoch 41/50
# 11250/11250 [==============================] - 107s 10ms/step - loss: 0.7632 - accuracy: 0.6940 - recall: 0.5825 - precision: 0.8802 - f1_score: 0.6986 - val_loss: 1.0840 - val_accuracy: 0.6492 - val_recall: 0.6011 - val_precision: 0.7659 - val_f1_score: 0.3444
# Epoch 42/50
# 11250/11250 [==============================] - 109s 10ms/step - loss: 0.7615 - accuracy: 0.6948 - recall: 0.5838 - precision: 0.8802 - f1_score: 0.6994 - val_loss: 0.9844 - val_accuracy: 0.6579 - val_recall: 0.6151 - val_precision: 0.7844 - val_f1_score: 0.3546
# Epoch 43/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7608 - accuracy: 0.6956 - recall: 0.5842 - precision: 0.8818 - f1_score: 0.7000 - val_loss: 1.4832 - val_accuracy: 0.6511 - val_recall: 0.6158 - val_precision: 0.7931 - val_f1_score: 0.3207
# Epoch 44/50
# 11250/11250 [==============================] - 107s 9ms/step - loss: 0.7598 - accuracy: 0.6959 - recall: 0.5842 - precision: 0.8809 - f1_score: 0.7005 - val_loss: 1.1503 - val_accuracy: 0.6258 - val_recall: 0.5986 - val_precision: 0.7507 - val_f1_score: 0.3303
# Epoch 45/50
# 11250/11250 [==============================] - 107s 10ms/step - loss: 0.7603 - accuracy: 0.6956 - recall: 0.5842 - precision: 0.8815 - f1_score: 0.7003 - val_loss: 1.0637 - val_accuracy: 0.6260 - val_recall: 0.5935 - val_precision: 0.7496 - val_f1_score: 0.3361
# Epoch 46/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7593 - accuracy: 0.6965 - recall: 0.5850 - precision: 0.8831 - f1_score: 0.7012 - val_loss: 1.0737 - val_accuracy: 0.6547 - val_recall: 0.6214 - val_precision: 0.7811 - val_f1_score: 0.3460
# Epoch 47/50
# 11250/11250 [==============================] - 107s 10ms/step - loss: 0.7585 - accuracy: 0.6967 - recall: 0.5851 - precision: 0.8823 - f1_score: 0.7015 - val_loss: 1.1331 - val_accuracy: 0.6475 - val_recall: 0.6136 - val_precision: 0.7683 - val_f1_score: 0.3516
# Epoch 48/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7590 - accuracy: 0.6962 - recall: 0.5858 - precision: 0.8817 - f1_score: 0.7010 - val_loss: 1.1944 - val_accuracy: 0.6428 - val_recall: 0.6072 - val_precision: 0.7627 - val_f1_score: 0.3401
# Epoch 49/50
# 11250/11250 [==============================] - 105s 9ms/step - loss: 0.7570 - accuracy: 0.6968 - recall: 0.5861 - precision: 0.8826 - f1_score: 0.7015 - val_loss: 1.1259 - val_accuracy: 0.6387 - val_recall: 0.6038 - val_precision: 0.7539 - val_f1_score: 0.3397
# Epoch 50/50
# 11250/11250 [==============================] - 106s 9ms/step - loss: 0.7572 - accuracy: 0.6974 - recall: 0.5857 - precision: 0.8833 - f1_score: 0.7020 - val_loss: 1.1572 - val_accuracy: 0.6425 - val_recall: 0.6038 - val_precision: 0.7561 - val_f1_score: 0.3363

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall, precision, f1_score = model.evaluate(X_test, y_test)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
print('Test Precision:', precision)
print('Test F1-Score:', f1_score)
# Out:
# 1417/1417 [==============================] - 9s 6ms/step - loss: 1.1572 - accuracy: 0.6425 - recall: 0.6038 - precision: 0.7561 - f1_score: 0.3363
# Test Loss: 1.1571787595748901
# Test Accuracy: 0.6424584984779358
# Test Recall: 0.6038298010826111
# Test Precision: 0.7561049461364746
# Test F1-Score: 0.671442067579753

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 1417/1417 [==============================] - 3s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.10930576070901034
# Backdoor: 0.3516295025728988
# DoS: 0.3061873318659819
# Exploits: 0.5057047884287126
# Fuzzers: 0.5230160039597426
# Generic: 0.9623231413279636
# Reconnaissance: 0.07467811158798283
# Shellcode: 0.8941798941798942
# Worms: 0.75

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import joblib

# %%
# save predicted
joblib.dump(predicted_classes, '/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/predicted_classes.joblib', compress=('zlib', 3))
# Out:
# ['/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/predicted_classes.joblib']

# %%
# load the predicted
predicted_classes = joblib.load('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/predicted_classes.joblib')
