# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 6
# 5

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']
# ['INT' 'FIN' 'CON' 'REQ' 'RST']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'ACC') & (data_train_attack['state'] != 'CLO')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'RST')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 181, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Split Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((45329, 181), (45329,), (119329, 181), (119329,))

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_smote, y_smote = smote.fit_resample(X_train, y_train)

X_smote.shape, y_smote.shape
# Out:
# ((169839, 181), (169839,))

# %%
#Create new dataframe from X_smote and y_smote to count every attack
data_smote = pd.concat([X_smote, y_smote], axis=1)

sns.countplot(data=data_smote, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Reconnaissance'),
#   Text(1, 0, 'Backdoor'),
#   Text(2, 0, 'DoS'),
#   Text(3, 0, 'Exploits'),
#   Text(4, 0, 'Analysis'),
#   Text(5, 0, 'Fuzzers'),
#   Text(6, 0, 'Worms'),
#   Text(7, 0, 'Shellcode'),
#   Text(8, 0, 'Generic')])

# %%
#data_smote.drop_duplicates(inplace=True)
print(data_smote.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_smote.shape))
print("--------------------")
print("Duplicates: " + str(data_smote.duplicated().sum()))
# Out:
# attack_cat
# Analysis          18871
# Backdoor          18871
# DoS               18871
# Exploits          18871
# Fuzzers           18871
# Generic           18871
# Reconnaissance    18871
# Shellcode         18871
# Worms             18871
# Name: count, dtype: int64
# --------------------
# Shape: (169839, 182)
# --------------------
# Duplicates: 47381

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (181, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall()])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 177, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 176, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5632)              0
#
#  batch_normalization (BatchN  (None, 5632)             22528
#  ormalization)
#
#  dropout (Dropout)           (None, 5632)              0
#
#  dense (Dense)               (None, 32)                180256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 203,657
# Trainable params: 192,393
# Non-trainable params: 11,264
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_smote = le.fit_transform(y_smote)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_smote = to_categorical(y_smote, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_smote = np.array(X_smote, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_smote, y_smote, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5308/5308 [==============================] - 56s 10ms/step - loss: 0.9890 - accuracy: 0.6114 - recall: 0.4564 - val_loss: 1.1057 - val_accuracy: 0.6292 - val_recall: 0.5792
# Epoch 2/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.8610 - accuracy: 0.6577 - recall: 0.5342 - val_loss: 0.9307 - val_accuracy: 0.6684 - val_recall: 0.6073
# Epoch 3/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.8242 - accuracy: 0.6713 - recall: 0.5564 - val_loss: 1.0452 - val_accuracy: 0.6345 - val_recall: 0.5838
# Epoch 4/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7996 - accuracy: 0.6806 - recall: 0.5707 - val_loss: 0.9299 - val_accuracy: 0.6893 - val_recall: 0.6432
# Epoch 5/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7840 - accuracy: 0.6876 - recall: 0.5820 - val_loss: 0.9375 - val_accuracy: 0.6889 - val_recall: 0.6479
# Epoch 6/50
# 5308/5308 [==============================] - 56s 10ms/step - loss: 0.7705 - accuracy: 0.6943 - recall: 0.5919 - val_loss: 0.9500 - val_accuracy: 0.6990 - val_recall: 0.6653
# Epoch 7/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7620 - accuracy: 0.6964 - recall: 0.5980 - val_loss: 0.9462 - val_accuracy: 0.6896 - val_recall: 0.6500
# Epoch 8/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7549 - accuracy: 0.6998 - recall: 0.6009 - val_loss: 0.9562 - val_accuracy: 0.6967 - val_recall: 0.6606
# Epoch 9/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7493 - accuracy: 0.7026 - recall: 0.6053 - val_loss: 0.9425 - val_accuracy: 0.6984 - val_recall: 0.6595
# Epoch 10/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7441 - accuracy: 0.7047 - recall: 0.6096 - val_loss: 0.9262 - val_accuracy: 0.6941 - val_recall: 0.6316
# Epoch 11/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7402 - accuracy: 0.7070 - recall: 0.6118 - val_loss: 0.9618 - val_accuracy: 0.6803 - val_recall: 0.6212
# Epoch 12/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7360 - accuracy: 0.7082 - recall: 0.6133 - val_loss: 0.9534 - val_accuracy: 0.6797 - val_recall: 0.6394
# Epoch 13/50
# 5308/5308 [==============================] - 56s 10ms/step - loss: 0.7321 - accuracy: 0.7113 - recall: 0.6176 - val_loss: 0.9468 - val_accuracy: 0.6882 - val_recall: 0.6558
# Epoch 14/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7266 - accuracy: 0.7131 - recall: 0.6202 - val_loss: 0.9725 - val_accuracy: 0.6927 - val_recall: 0.6532
# Epoch 15/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7254 - accuracy: 0.7145 - recall: 0.6231 - val_loss: 0.9828 - val_accuracy: 0.7005 - val_recall: 0.6686
# Epoch 16/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7220 - accuracy: 0.7160 - recall: 0.6247 - val_loss: 0.9658 - val_accuracy: 0.7002 - val_recall: 0.6654
# Epoch 17/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7209 - accuracy: 0.7173 - recall: 0.6254 - val_loss: 0.9505 - val_accuracy: 0.6937 - val_recall: 0.6565
# Epoch 18/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7173 - accuracy: 0.7179 - recall: 0.6294 - val_loss: 0.9623 - val_accuracy: 0.7018 - val_recall: 0.6660
# Epoch 19/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7184 - accuracy: 0.7175 - recall: 0.6277 - val_loss: 0.9910 - val_accuracy: 0.6909 - val_recall: 0.6489
# Epoch 20/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7132 - accuracy: 0.7204 - recall: 0.6308 - val_loss: 0.9994 - val_accuracy: 0.6820 - val_recall: 0.6489
# Epoch 21/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.7122 - accuracy: 0.7207 - recall: 0.6311 - val_loss: 0.9685 - val_accuracy: 0.7028 - val_recall: 0.6687
# Epoch 22/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.7108 - accuracy: 0.7204 - recall: 0.6323 - val_loss: 0.9813 - val_accuracy: 0.6828 - val_recall: 0.6419
# Epoch 23/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.7073 - accuracy: 0.7231 - recall: 0.6355 - val_loss: 0.9259 - val_accuracy: 0.7067 - val_recall: 0.6714
# Epoch 24/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.7074 - accuracy: 0.7225 - recall: 0.6338 - val_loss: 0.9185 - val_accuracy: 0.7111 - val_recall: 0.6677
# Epoch 25/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.7039 - accuracy: 0.7231 - recall: 0.6360 - val_loss: 0.9854 - val_accuracy: 0.6767 - val_recall: 0.6366
# Epoch 26/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.7050 - accuracy: 0.7233 - recall: 0.6356 - val_loss: 0.9987 - val_accuracy: 0.6696 - val_recall: 0.6226
# Epoch 27/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.7013 - accuracy: 0.7234 - recall: 0.6365 - val_loss: 1.0519 - val_accuracy: 0.6824 - val_recall: 0.6292
# Epoch 28/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.7003 - accuracy: 0.7243 - recall: 0.6376 - val_loss: 0.9637 - val_accuracy: 0.6860 - val_recall: 0.6448
# Epoch 29/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6983 - accuracy: 0.7251 - recall: 0.6389 - val_loss: 0.9969 - val_accuracy: 0.6787 - val_recall: 0.6517
# Epoch 30/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6991 - accuracy: 0.7248 - recall: 0.6377 - val_loss: 0.9416 - val_accuracy: 0.6880 - val_recall: 0.6498
# Epoch 31/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6966 - accuracy: 0.7258 - recall: 0.6383 - val_loss: 0.9399 - val_accuracy: 0.7047 - val_recall: 0.6629
# Epoch 32/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.6968 - accuracy: 0.7264 - recall: 0.6398 - val_loss: 0.9956 - val_accuracy: 0.6841 - val_recall: 0.6573
# Epoch 33/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.6947 - accuracy: 0.7272 - recall: 0.6406 - val_loss: 1.0378 - val_accuracy: 0.6769 - val_recall: 0.6427
# Epoch 34/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.6936 - accuracy: 0.7284 - recall: 0.6411 - val_loss: 0.9745 - val_accuracy: 0.6981 - val_recall: 0.6643
# Epoch 35/50
# 5308/5308 [==============================] - 51s 10ms/step - loss: 0.6925 - accuracy: 0.7275 - recall: 0.6410 - val_loss: 0.9655 - val_accuracy: 0.6970 - val_recall: 0.6586
# Epoch 36/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6911 - accuracy: 0.7285 - recall: 0.6412 - val_loss: 0.9503 - val_accuracy: 0.6838 - val_recall: 0.6278
# Epoch 37/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.6898 - accuracy: 0.7298 - recall: 0.6432 - val_loss: 0.9916 - val_accuracy: 0.6878 - val_recall: 0.6612
# Epoch 38/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6886 - accuracy: 0.7292 - recall: 0.6426 - val_loss: 0.9963 - val_accuracy: 0.6765 - val_recall: 0.6285
# Epoch 39/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6892 - accuracy: 0.7293 - recall: 0.6431 - val_loss: 0.9287 - val_accuracy: 0.6900 - val_recall: 0.6475
# Epoch 40/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6877 - accuracy: 0.7309 - recall: 0.6440 - val_loss: 0.9855 - val_accuracy: 0.6831 - val_recall: 0.6524
# Epoch 41/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6856 - accuracy: 0.7303 - recall: 0.6442 - val_loss: 0.9839 - val_accuracy: 0.6854 - val_recall: 0.6522
# Epoch 42/50
# 5308/5308 [==============================] - 51s 10ms/step - loss: 0.6855 - accuracy: 0.7304 - recall: 0.6437 - val_loss: 0.9427 - val_accuracy: 0.6986 - val_recall: 0.6583
# Epoch 43/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6842 - accuracy: 0.7305 - recall: 0.6437 - val_loss: 0.9987 - val_accuracy: 0.6783 - val_recall: 0.6360
# Epoch 44/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6830 - accuracy: 0.7317 - recall: 0.6466 - val_loss: 1.0426 - val_accuracy: 0.6886 - val_recall: 0.6588
# Epoch 45/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6817 - accuracy: 0.7317 - recall: 0.6456 - val_loss: 1.0048 - val_accuracy: 0.6871 - val_recall: 0.6603
# Epoch 46/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6822 - accuracy: 0.7316 - recall: 0.6452 - val_loss: 0.9523 - val_accuracy: 0.6873 - val_recall: 0.6477
# Epoch 47/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6818 - accuracy: 0.7313 - recall: 0.6465 - val_loss: 0.9971 - val_accuracy: 0.6790 - val_recall: 0.6382
# Epoch 48/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.6797 - accuracy: 0.7320 - recall: 0.6461 - val_loss: 0.9941 - val_accuracy: 0.6805 - val_recall: 0.6450
# Epoch 49/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.6787 - accuracy: 0.7326 - recall: 0.6471 - val_loss: 1.0022 - val_accuracy: 0.6813 - val_recall: 0.6467
# Epoch 50/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.6800 - accuracy: 0.7334 - recall: 0.6468 - val_loss: 0.9910 - val_accuracy: 0.6867 - val_recall: 0.6515

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall = model.evaluate(X_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
# Out:
# 3730/3730 [==============================] - 16s 4ms/step - loss: 0.9910 - accuracy: 0.6867 - recall: 0.6515
# Test Loss: 0.9910194873809814
# Test Accuracy: 0.6866562366485596
# Test Recall: 0.6515012979507446

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 3730/3730 [==============================] - 7s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.135
# Backdoor: 0.08476517754868271
# DoS: 0.6654705594519654
# Exploits: 0.44162223686575214
# Fuzzers: 0.7547294324681039
# Generic: 0.9778994474861872
# Reconnaissance: 0.47373438840690246
# Shellcode: 0.6593115622241836
# Worms: 0.46923076923076923

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import pickle

# %%
# save the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/predicted_classes.pkl', 'wb') as model_file:
    pickle.dump(predicted_classes, model_file)

# %%
# load the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/predicted_classes.pkl', 'rb') as model_file:
    predicted_classes = pickle.load(model_file)
