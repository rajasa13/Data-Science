# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall, Precision

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 6
# 5

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']
# ['INT' 'FIN' 'CON' 'REQ' 'RST']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'ACC') & (data_train_attack['state'] != 'CLO')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'RST')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 181, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Initialize Train Data and Test Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((45329, 181), (45329,), (119329, 181), (119329,))

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_smote, y_smote = smote.fit_resample(X_train, y_train)

X_smote.shape, y_smote.shape
# Out:
# ((169839, 181), (169839,))

# %%
#Create new dataframe from X_smote and y_smote to count every attack
data_smote = pd.concat([X_smote, y_smote], axis=1)

sns.countplot(data=data_smote, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Reconnaissance'),
#   Text(1, 0, 'Backdoor'),
#   Text(2, 0, 'DoS'),
#   Text(3, 0, 'Exploits'),
#   Text(4, 0, 'Analysis'),
#   Text(5, 0, 'Fuzzers'),
#   Text(6, 0, 'Worms'),
#   Text(7, 0, 'Shellcode'),
#   Text(8, 0, 'Generic')])

# %%
#data_smote.drop_duplicates(inplace=True)
print(data_smote.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_smote.shape))
print("--------------------")
print("Duplicates: " + str(data_smote.duplicated().sum()))
# Out:
# attack_cat
# Analysis          18871
# Backdoor          18871
# DoS               18871
# Exploits          18871
# Fuzzers           18871
# Generic           18871
# Reconnaissance    18871
# Shellcode         18871
# Worms             18871
# Name: count, dtype: int64
# --------------------
# Shape: (169839, 182)
# --------------------
# Duplicates: 47307

# %% [markdown]
# # Model Architecture

# %%
# from keras import backend as K
import tensorflow_addons as tfa
# Out:
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (181, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision(), tfa.metrics.F1Score(num_classes=9, 
                                                                                                                                 average='macro')])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 177, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 176, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5632)              0
#
#  batch_normalization (BatchN  (None, 5632)             22528
#  ormalization)
#
#  dropout (Dropout)           (None, 5632)              0
#
#  dense (Dense)               (None, 32)                180256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 203,657
# Trainable params: 192,393
# Non-trainable params: 11,264
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_smote = le.fit_transform(y_smote)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_smote = to_categorical(y_smote, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_smote = np.array(X_smote, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_smote, y_smote, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5308/5308 [==============================] - 58s 10ms/step - loss: 0.9902 - accuracy: 0.6096 - recall: 0.4526 - precision: 0.7375 - f1_score: 0.6063 - val_loss: 3.6168 - val_accuracy: 0.2770 - val_recall: 0.2610 - val_precision: 0.3065 - val_f1_score: 0.1616
# Epoch 2/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.8507 - accuracy: 0.6600 - recall: 0.5355 - precision: 0.7624 - f1_score: 0.6581 - val_loss: 1.3562 - val_accuracy: 0.6248 - val_recall: 0.5763 - val_precision: 0.7165 - val_f1_score: 0.3822
# Epoch 3/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.8160 - accuracy: 0.6725 - recall: 0.5563 - precision: 0.7751 - f1_score: 0.6711 - val_loss: 0.9482 - val_accuracy: 0.6750 - val_recall: 0.6339 - val_precision: 0.7551 - val_f1_score: 0.4203
# Epoch 4/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7958 - accuracy: 0.6814 - recall: 0.5705 - precision: 0.7799 - f1_score: 0.6794 - val_loss: 1.0872 - val_accuracy: 0.6427 - val_recall: 0.5957 - val_precision: 0.7348 - val_f1_score: 0.4001
# Epoch 5/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7821 - accuracy: 0.6857 - recall: 0.5773 - precision: 0.7858 - f1_score: 0.6845 - val_loss: 0.9487 - val_accuracy: 0.6964 - val_recall: 0.6569 - val_precision: 0.7586 - val_f1_score: 0.4381
# Epoch 6/50
# 5308/5308 [==============================] - 58s 11ms/step - loss: 0.7703 - accuracy: 0.6912 - recall: 0.5840 - precision: 0.7892 - f1_score: 0.6898 - val_loss: 1.0624 - val_accuracy: 0.6754 - val_recall: 0.6381 - val_precision: 0.7439 - val_f1_score: 0.4132
# Epoch 7/50
# 5308/5308 [==============================] - 58s 11ms/step - loss: 0.7648 - accuracy: 0.6926 - recall: 0.5881 - precision: 0.7901 - f1_score: 0.6909 - val_loss: 0.9796 - val_accuracy: 0.6712 - val_recall: 0.6283 - val_precision: 0.7593 - val_f1_score: 0.4086
# Epoch 8/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7561 - accuracy: 0.6986 - recall: 0.5936 - precision: 0.7930 - f1_score: 0.6972 - val_loss: 0.9840 - val_accuracy: 0.6872 - val_recall: 0.6411 - val_precision: 0.7792 - val_f1_score: 0.4382
# Epoch 9/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7503 - accuracy: 0.7014 - recall: 0.5985 - precision: 0.7957 - f1_score: 0.7004 - val_loss: 0.9768 - val_accuracy: 0.6878 - val_recall: 0.6466 - val_precision: 0.7615 - val_f1_score: 0.4342
# Epoch 10/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7455 - accuracy: 0.7027 - recall: 0.6013 - precision: 0.7976 - f1_score: 0.7012 - val_loss: 0.9690 - val_accuracy: 0.6920 - val_recall: 0.6456 - val_precision: 0.7637 - val_f1_score: 0.4292
# Epoch 11/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7403 - accuracy: 0.7047 - recall: 0.6057 - precision: 0.7987 - f1_score: 0.7037 - val_loss: 1.0063 - val_accuracy: 0.6794 - val_recall: 0.6394 - val_precision: 0.7494 - val_f1_score: 0.4354
# Epoch 12/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7343 - accuracy: 0.7082 - recall: 0.6097 - precision: 0.8017 - f1_score: 0.7066 - val_loss: 1.1625 - val_accuracy: 0.6246 - val_recall: 0.5908 - val_precision: 0.7125 - val_f1_score: 0.3820
# Epoch 13/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7296 - accuracy: 0.7090 - recall: 0.6128 - precision: 0.8009 - f1_score: 0.7080 - val_loss: 1.0472 - val_accuracy: 0.6812 - val_recall: 0.6515 - val_precision: 0.7383 - val_f1_score: 0.4239
# Epoch 14/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7270 - accuracy: 0.7119 - recall: 0.6155 - precision: 0.8039 - f1_score: 0.7108 - val_loss: 1.2774 - val_accuracy: 0.6262 - val_recall: 0.5903 - val_precision: 0.7102 - val_f1_score: 0.3807
# Epoch 15/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7227 - accuracy: 0.7129 - recall: 0.6180 - precision: 0.8044 - f1_score: 0.7122 - val_loss: 1.1459 - val_accuracy: 0.6527 - val_recall: 0.6069 - val_precision: 0.7521 - val_f1_score: 0.4091
# Epoch 16/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7185 - accuracy: 0.7164 - recall: 0.6215 - precision: 0.8065 - f1_score: 0.7151 - val_loss: 0.9564 - val_accuracy: 0.7065 - val_recall: 0.6739 - val_precision: 0.7839 - val_f1_score: 0.4627
# Epoch 17/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7179 - accuracy: 0.7163 - recall: 0.6215 - precision: 0.8051 - f1_score: 0.7153 - val_loss: 0.9983 - val_accuracy: 0.6863 - val_recall: 0.6498 - val_precision: 0.7512 - val_f1_score: 0.4316
# Epoch 18/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7125 - accuracy: 0.7181 - recall: 0.6259 - precision: 0.8077 - f1_score: 0.7170 - val_loss: 0.9937 - val_accuracy: 0.6969 - val_recall: 0.6605 - val_precision: 0.7796 - val_f1_score: 0.4518
# Epoch 19/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7129 - accuracy: 0.7177 - recall: 0.6248 - precision: 0.8061 - f1_score: 0.7166 - val_loss: 1.0538 - val_accuracy: 0.6680 - val_recall: 0.6343 - val_precision: 0.7334 - val_f1_score: 0.4122
# Epoch 20/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7110 - accuracy: 0.7186 - recall: 0.6257 - precision: 0.8071 - f1_score: 0.7177 - val_loss: 1.0928 - val_accuracy: 0.6618 - val_recall: 0.6212 - val_precision: 0.7245 - val_f1_score: 0.4038
# Epoch 21/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7081 - accuracy: 0.7206 - recall: 0.6278 - precision: 0.8098 - f1_score: 0.7190 - val_loss: 1.0518 - val_accuracy: 0.6769 - val_recall: 0.6428 - val_precision: 0.7301 - val_f1_score: 0.4103
# Epoch 22/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7083 - accuracy: 0.7203 - recall: 0.6280 - precision: 0.8083 - f1_score: 0.7194 - val_loss: 1.0041 - val_accuracy: 0.6740 - val_recall: 0.6413 - val_precision: 0.7455 - val_f1_score: 0.4208
# Epoch 23/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7057 - accuracy: 0.7213 - recall: 0.6291 - precision: 0.8094 - f1_score: 0.7199 - val_loss: 1.0028 - val_accuracy: 0.6817 - val_recall: 0.6490 - val_precision: 0.7474 - val_f1_score: 0.4216
# Epoch 24/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7045 - accuracy: 0.7215 - recall: 0.6295 - precision: 0.8097 - f1_score: 0.7208 - val_loss: 1.0236 - val_accuracy: 0.6688 - val_recall: 0.6334 - val_precision: 0.7394 - val_f1_score: 0.4121
# Epoch 25/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7022 - accuracy: 0.7234 - recall: 0.6318 - precision: 0.8108 - f1_score: 0.7225 - val_loss: 0.9547 - val_accuracy: 0.6979 - val_recall: 0.6639 - val_precision: 0.7621 - val_f1_score: 0.4334
# Epoch 26/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7017 - accuracy: 0.7228 - recall: 0.6314 - precision: 0.8111 - f1_score: 0.7213 - val_loss: 1.0577 - val_accuracy: 0.6678 - val_recall: 0.6403 - val_precision: 0.7141 - val_f1_score: 0.4109
# Epoch 27/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7019 - accuracy: 0.7226 - recall: 0.6317 - precision: 0.8110 - f1_score: 0.7214 - val_loss: 0.9452 - val_accuracy: 0.6884 - val_recall: 0.6520 - val_precision: 0.7533 - val_f1_score: 0.4235
# Epoch 28/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.6991 - accuracy: 0.7246 - recall: 0.6332 - precision: 0.8122 - f1_score: 0.7234 - val_loss: 1.0258 - val_accuracy: 0.6764 - val_recall: 0.6323 - val_precision: 0.7497 - val_f1_score: 0.4145
# Epoch 29/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6982 - accuracy: 0.7241 - recall: 0.6327 - precision: 0.8122 - f1_score: 0.7225 - val_loss: 1.0931 - val_accuracy: 0.6570 - val_recall: 0.6165 - val_precision: 0.7244 - val_f1_score: 0.4066
# Epoch 30/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6960 - accuracy: 0.7248 - recall: 0.6344 - precision: 0.8123 - f1_score: 0.7237 - val_loss: 1.0118 - val_accuracy: 0.6955 - val_recall: 0.6637 - val_precision: 0.7537 - val_f1_score: 0.4437
# Epoch 31/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6946 - accuracy: 0.7259 - recall: 0.6361 - precision: 0.8128 - f1_score: 0.7247 - val_loss: 1.4343 - val_accuracy: 0.6292 - val_recall: 0.5949 - val_precision: 0.6936 - val_f1_score: 0.3822
# Epoch 32/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6950 - accuracy: 0.7252 - recall: 0.6354 - precision: 0.8132 - f1_score: 0.7240 - val_loss: 1.0140 - val_accuracy: 0.6814 - val_recall: 0.6435 - val_precision: 0.7436 - val_f1_score: 0.4282
# Epoch 33/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6962 - accuracy: 0.7252 - recall: 0.6341 - precision: 0.8135 - f1_score: 0.7238 - val_loss: 1.1714 - val_accuracy: 0.6251 - val_recall: 0.5838 - val_precision: 0.7217 - val_f1_score: 0.3730
# Epoch 34/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6936 - accuracy: 0.7254 - recall: 0.6346 - precision: 0.8137 - f1_score: 0.7241 - val_loss: 1.0450 - val_accuracy: 0.6760 - val_recall: 0.6457 - val_precision: 0.7275 - val_f1_score: 0.4163
# Epoch 35/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6916 - accuracy: 0.7263 - recall: 0.6361 - precision: 0.8147 - f1_score: 0.7248 - val_loss: 0.9837 - val_accuracy: 0.6827 - val_recall: 0.6475 - val_precision: 0.7588 - val_f1_score: 0.4262
# Epoch 36/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6916 - accuracy: 0.7268 - recall: 0.6365 - precision: 0.8140 - f1_score: 0.7257 - val_loss: 1.0594 - val_accuracy: 0.6680 - val_recall: 0.6358 - val_precision: 0.7377 - val_f1_score: 0.4183
# Epoch 37/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6914 - accuracy: 0.7260 - recall: 0.6363 - precision: 0.8140 - f1_score: 0.7247 - val_loss: 1.0256 - val_accuracy: 0.6861 - val_recall: 0.6578 - val_precision: 0.7320 - val_f1_score: 0.4236
# Epoch 38/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6893 - accuracy: 0.7263 - recall: 0.6374 - precision: 0.8158 - f1_score: 0.7254 - val_loss: 1.0030 - val_accuracy: 0.6831 - val_recall: 0.6433 - val_precision: 0.7532 - val_f1_score: 0.4246
# Epoch 39/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6887 - accuracy: 0.7268 - recall: 0.6367 - precision: 0.8146 - f1_score: 0.7259 - val_loss: 1.0589 - val_accuracy: 0.6767 - val_recall: 0.6476 - val_precision: 0.7323 - val_f1_score: 0.4209
# Epoch 40/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.6876 - accuracy: 0.7286 - recall: 0.6381 - precision: 0.8166 - f1_score: 0.7275 - val_loss: 1.0454 - val_accuracy: 0.6777 - val_recall: 0.6438 - val_precision: 0.7450 - val_f1_score: 0.4137
# Epoch 41/50
# 5308/5308 [==============================] - 58s 11ms/step - loss: 0.6858 - accuracy: 0.7279 - recall: 0.6396 - precision: 0.8163 - f1_score: 0.7275 - val_loss: 1.0522 - val_accuracy: 0.6822 - val_recall: 0.6529 - val_precision: 0.7293 - val_f1_score: 0.4312
# Epoch 42/50
# 5308/5308 [==============================] - 58s 11ms/step - loss: 0.6867 - accuracy: 0.7285 - recall: 0.6384 - precision: 0.8158 - f1_score: 0.7276 - val_loss: 1.0173 - val_accuracy: 0.6818 - val_recall: 0.6488 - val_precision: 0.7394 - val_f1_score: 0.4197
# Epoch 43/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.6853 - accuracy: 0.7285 - recall: 0.6397 - precision: 0.8154 - f1_score: 0.7279 - val_loss: 1.0163 - val_accuracy: 0.6743 - val_recall: 0.6384 - val_precision: 0.7477 - val_f1_score: 0.4200
# Epoch 44/50
# 5308/5308 [==============================] - 52s 10ms/step - loss: 0.6853 - accuracy: 0.7285 - recall: 0.6395 - precision: 0.8170 - f1_score: 0.7277 - val_loss: 1.0427 - val_accuracy: 0.6814 - val_recall: 0.6489 - val_precision: 0.7527 - val_f1_score: 0.4241
# Epoch 45/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.6831 - accuracy: 0.7293 - recall: 0.6408 - precision: 0.8175 - f1_score: 0.7286 - val_loss: 1.0510 - val_accuracy: 0.6886 - val_recall: 0.6597 - val_precision: 0.7384 - val_f1_score: 0.4361
# Epoch 46/50
# 5308/5308 [==============================] - 52s 10ms/step - loss: 0.6831 - accuracy: 0.7295 - recall: 0.6416 - precision: 0.8157 - f1_score: 0.7287 - val_loss: 1.4062 - val_accuracy: 0.6022 - val_recall: 0.5673 - val_precision: 0.6533 - val_f1_score: 0.3466
# Epoch 47/50
# 5308/5308 [==============================] - 52s 10ms/step - loss: 0.6823 - accuracy: 0.7300 - recall: 0.6411 - precision: 0.8177 - f1_score: 0.7290 - val_loss: 1.0354 - val_accuracy: 0.6725 - val_recall: 0.6336 - val_precision: 0.7484 - val_f1_score: 0.4183
# Epoch 48/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.6834 - accuracy: 0.7294 - recall: 0.6404 - precision: 0.8172 - f1_score: 0.7286 - val_loss: 0.9884 - val_accuracy: 0.6873 - val_recall: 0.6549 - val_precision: 0.7442 - val_f1_score: 0.4239
# Epoch 49/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.6812 - accuracy: 0.7296 - recall: 0.6419 - precision: 0.8158 - f1_score: 0.7290 - val_loss: 1.0303 - val_accuracy: 0.6779 - val_recall: 0.6490 - val_precision: 0.7375 - val_f1_score: 0.4246
# Epoch 50/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.6800 - accuracy: 0.7305 - recall: 0.6428 - precision: 0.8174 - f1_score: 0.7298 - val_loss: 1.0942 - val_accuracy: 0.6762 - val_recall: 0.6488 - val_precision: 0.7213 - val_f1_score: 0.4230

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall, precision, f1_score = model.evaluate(X_test, y_test)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
print('Test Precision:', precision)
print('Test F1-Score:', f1_score)
# Out:
# 3730/3730 [==============================] - 55s 13ms/step - loss: 1.0942 - accuracy: 0.6762 - recall: 0.6488 - precision: 0.7213 - f1_score: 0.4230
# Test Loss: 1.0941988229751587
# Test Accuracy: 0.6761893630027771
# Test Recall: 0.6487526297569275
# Test Precision: 0.7213406562805176
# Test F1-Score: 0.6831237733687923

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 3730/3730 [==============================] - 6s 1ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.1415
# Backdoor: 0.06930126002290951
# DoS: 0.7262273691078127
# Exploits: 0.3921703708141137
# Fuzzers: 0.6994610646722393
# Generic: 0.9776244406110153
# Reconnaissance: 0.5363714367432548
# Shellcode: 0.6893203883495146
# Worms: 0.43846153846153846

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import pickle

# %%
# save the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/predicted_classes.pkl', 'wb') as model_file:
    pickle.dump(predicted_classes, model_file)

# %%
# load the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/SMOTE/Saved/predicted_classes.pkl', 'rb') as model_file:
    predicted_classes = pickle.load(model_file)
