# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 6
# 5

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']
# ['INT' 'FIN' 'CON' 'REQ' 'RST']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'ACC') & (data_train_attack['state'] != 'CLO')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'RST')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 181, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Split Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((45329, 181), (45329,), (119329, 181), (119329,))

# %% [markdown]
# ## BorderlineSMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE

borderlinesmote = BorderlineSMOTE()
X_borderlinesmote, y_borderlinesmote = borderlinesmote.fit_resample(X_train, y_train)

X_borderlinesmote.shape, y_borderlinesmote.shape
# Out:
# ((169839, 181), (169839,))

# %%
#Create new dataframe from X_borderlinesmote and y_borderlinesmote to count every attack
data_borderlinesmote = pd.concat([X_borderlinesmote, y_borderlinesmote], axis=1)

sns.countplot(data=data_borderlinesmote, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Reconnaissance'),
#   Text(1, 0, 'Backdoor'),
#   Text(2, 0, 'DoS'),
#   Text(3, 0, 'Exploits'),
#   Text(4, 0, 'Analysis'),
#   Text(5, 0, 'Fuzzers'),
#   Text(6, 0, 'Worms'),
#   Text(7, 0, 'Shellcode'),
#   Text(8, 0, 'Generic')])

# %%
#data_borderlinesmote.drop_duplicates(inplace=True)
print(data_borderlinesmote.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_borderlinesmote.shape))
print("--------------------")
print("Duplicates: " + str(data_borderlinesmote.duplicated().sum()))
# Out:
# attack_cat
# Analysis          18871
# Backdoor          18871
# DoS               18871
# Exploits          18871
# Fuzzers           18871
# Generic           18871
# Reconnaissance    18871
# Shellcode         18871
# Worms             18871
# Name: count, dtype: int64
# --------------------
# Shape: (169839, 182)
# --------------------
# Duplicates: 49482

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (181, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall()])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 177, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 176, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5632)              0
#
#  batch_normalization (BatchN  (None, 5632)             22528
#  ormalization)
#
#  dropout (Dropout)           (None, 5632)              0
#
#  dense (Dense)               (None, 32)                180256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 203,657
# Trainable params: 192,393
# Non-trainable params: 11,264
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_borderlinesmote = le.fit_transform(y_borderlinesmote)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_borderlinesmote = to_categorical(y_borderlinesmote, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_borderlinesmote = np.array(X_borderlinesmote, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_borderlinesmote, y_borderlinesmote, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5308/5308 [==============================] - 53s 9ms/step - loss: 0.9678 - accuracy: 0.6074 - recall: 0.4447 - val_loss: 1.0262 - val_accuracy: 0.5912 - val_recall: 0.5260
# Epoch 2/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.8665 - accuracy: 0.6439 - recall: 0.5105 - val_loss: 0.9959 - val_accuracy: 0.6324 - val_recall: 0.5872
# Epoch 3/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.8372 - accuracy: 0.6547 - recall: 0.5312 - val_loss: 0.9041 - val_accuracy: 0.6632 - val_recall: 0.6075
# Epoch 4/50
# 5308/5308 [==============================] - 50s 9ms/step - loss: 0.8218 - accuracy: 0.6618 - recall: 0.5405 - val_loss: 0.8695 - val_accuracy: 0.6610 - val_recall: 0.5933
# Epoch 5/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.8084 - accuracy: 0.6670 - recall: 0.5497 - val_loss: 0.9378 - val_accuracy: 0.6567 - val_recall: 0.6098
# Epoch 6/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7971 - accuracy: 0.6720 - recall: 0.5574 - val_loss: 0.8989 - val_accuracy: 0.6707 - val_recall: 0.6252
# Epoch 7/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7884 - accuracy: 0.6765 - recall: 0.5643 - val_loss: 0.9689 - val_accuracy: 0.6538 - val_recall: 0.5902
# Epoch 8/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.7792 - accuracy: 0.6808 - recall: 0.5686 - val_loss: 0.9383 - val_accuracy: 0.6598 - val_recall: 0.6003
# Epoch 9/50
# 5308/5308 [==============================] - 44s 8ms/step - loss: 0.7737 - accuracy: 0.6832 - recall: 0.5720 - val_loss: 0.9168 - val_accuracy: 0.6710 - val_recall: 0.6205
# Epoch 10/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7710 - accuracy: 0.6831 - recall: 0.5723 - val_loss: 0.8901 - val_accuracy: 0.6696 - val_recall: 0.6170
# Epoch 11/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7664 - accuracy: 0.6858 - recall: 0.5750 - val_loss: 0.8669 - val_accuracy: 0.6876 - val_recall: 0.6359
# Epoch 12/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7651 - accuracy: 0.6859 - recall: 0.5749 - val_loss: 0.9588 - val_accuracy: 0.6608 - val_recall: 0.6139
# Epoch 13/50
# 5308/5308 [==============================] - 47s 9ms/step - loss: 0.7620 - accuracy: 0.6875 - recall: 0.5771 - val_loss: 0.9031 - val_accuracy: 0.6762 - val_recall: 0.6353
# Epoch 14/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7597 - accuracy: 0.6884 - recall: 0.5786 - val_loss: 0.9637 - val_accuracy: 0.6613 - val_recall: 0.6127
# Epoch 15/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7588 - accuracy: 0.6890 - recall: 0.5789 - val_loss: 0.9187 - val_accuracy: 0.6753 - val_recall: 0.6339
# Epoch 16/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7542 - accuracy: 0.6904 - recall: 0.5811 - val_loss: 0.9394 - val_accuracy: 0.6592 - val_recall: 0.6115
# Epoch 17/50
# 5308/5308 [==============================] - 47s 9ms/step - loss: 0.7552 - accuracy: 0.6899 - recall: 0.5799 - val_loss: 0.9152 - val_accuracy: 0.6750 - val_recall: 0.6254
# Epoch 18/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7517 - accuracy: 0.6918 - recall: 0.5821 - val_loss: 0.8905 - val_accuracy: 0.6913 - val_recall: 0.6461
# Epoch 19/50
# 5308/5308 [==============================] - 47s 9ms/step - loss: 0.7507 - accuracy: 0.6923 - recall: 0.5825 - val_loss: 0.9949 - val_accuracy: 0.6693 - val_recall: 0.6203
# Epoch 20/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7505 - accuracy: 0.6919 - recall: 0.5826 - val_loss: 0.9112 - val_accuracy: 0.6800 - val_recall: 0.6369
# Epoch 21/50
# 5308/5308 [==============================] - 44s 8ms/step - loss: 0.7473 - accuracy: 0.6935 - recall: 0.5839 - val_loss: 0.9305 - val_accuracy: 0.6789 - val_recall: 0.6273
# Epoch 22/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7460 - accuracy: 0.6937 - recall: 0.5847 - val_loss: 0.9905 - val_accuracy: 0.6596 - val_recall: 0.6172
# Epoch 23/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7457 - accuracy: 0.6933 - recall: 0.5844 - val_loss: 0.9089 - val_accuracy: 0.6862 - val_recall: 0.6330
# Epoch 24/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7457 - accuracy: 0.6947 - recall: 0.5846 - val_loss: 0.9707 - val_accuracy: 0.6648 - val_recall: 0.6266
# Epoch 25/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7457 - accuracy: 0.6934 - recall: 0.5842 - val_loss: 0.9002 - val_accuracy: 0.6767 - val_recall: 0.6286
# Epoch 26/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7432 - accuracy: 0.6951 - recall: 0.5845 - val_loss: 0.9193 - val_accuracy: 0.6781 - val_recall: 0.6248
# Epoch 27/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7425 - accuracy: 0.6958 - recall: 0.5862 - val_loss: 0.9180 - val_accuracy: 0.6681 - val_recall: 0.6062
# Epoch 28/50
# 5308/5308 [==============================] - 44s 8ms/step - loss: 0.7424 - accuracy: 0.6960 - recall: 0.5859 - val_loss: 0.8960 - val_accuracy: 0.6927 - val_recall: 0.6502
# Epoch 29/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7406 - accuracy: 0.6951 - recall: 0.5855 - val_loss: 0.9323 - val_accuracy: 0.6766 - val_recall: 0.6325
# Epoch 30/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7396 - accuracy: 0.6965 - recall: 0.5863 - val_loss: 0.8972 - val_accuracy: 0.6963 - val_recall: 0.6425
# Epoch 31/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7395 - accuracy: 0.6958 - recall: 0.5860 - val_loss: 0.9045 - val_accuracy: 0.6879 - val_recall: 0.6416
# Epoch 32/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7389 - accuracy: 0.6978 - recall: 0.5875 - val_loss: 0.8971 - val_accuracy: 0.6800 - val_recall: 0.6282
# Epoch 33/50
# 5308/5308 [==============================] - 46s 9ms/step - loss: 0.7395 - accuracy: 0.6964 - recall: 0.5868 - val_loss: 0.9078 - val_accuracy: 0.6790 - val_recall: 0.6233
# Epoch 34/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7369 - accuracy: 0.6971 - recall: 0.5880 - val_loss: 0.9420 - val_accuracy: 0.6827 - val_recall: 0.6422
# Epoch 35/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7357 - accuracy: 0.6975 - recall: 0.5895 - val_loss: 0.9120 - val_accuracy: 0.6828 - val_recall: 0.6364
# Epoch 36/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7379 - accuracy: 0.6966 - recall: 0.5893 - val_loss: 0.8606 - val_accuracy: 0.6975 - val_recall: 0.6374
# Epoch 37/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7361 - accuracy: 0.6981 - recall: 0.5896 - val_loss: 0.8944 - val_accuracy: 0.6888 - val_recall: 0.6479
# Epoch 38/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7336 - accuracy: 0.6988 - recall: 0.5906 - val_loss: 0.9420 - val_accuracy: 0.6806 - val_recall: 0.6350
# Epoch 39/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7353 - accuracy: 0.6976 - recall: 0.5893 - val_loss: 0.9210 - val_accuracy: 0.6825 - val_recall: 0.6382
# Epoch 40/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7324 - accuracy: 0.6991 - recall: 0.5901 - val_loss: 0.8943 - val_accuracy: 0.6936 - val_recall: 0.6461
# Epoch 41/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7329 - accuracy: 0.6986 - recall: 0.5907 - val_loss: 0.9134 - val_accuracy: 0.6878 - val_recall: 0.6425
# Epoch 42/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7329 - accuracy: 0.6983 - recall: 0.5902 - val_loss: 0.9398 - val_accuracy: 0.6790 - val_recall: 0.6374
# Epoch 43/50
# 5308/5308 [==============================] - 45s 9ms/step - loss: 0.7321 - accuracy: 0.6981 - recall: 0.5904 - val_loss: 0.9577 - val_accuracy: 0.6826 - val_recall: 0.6379
# Epoch 44/50
# 5308/5308 [==============================] - 45s 8ms/step - loss: 0.7323 - accuracy: 0.6992 - recall: 0.5919 - val_loss: 0.9147 - val_accuracy: 0.6849 - val_recall: 0.6377
# Epoch 45/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7298 - accuracy: 0.7001 - recall: 0.5920 - val_loss: 0.8877 - val_accuracy: 0.6954 - val_recall: 0.6472
# Epoch 46/50
# 5308/5308 [==============================] - 51s 10ms/step - loss: 0.7309 - accuracy: 0.6998 - recall: 0.5911 - val_loss: 0.9621 - val_accuracy: 0.6795 - val_recall: 0.6399
# Epoch 47/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7299 - accuracy: 0.6993 - recall: 0.5905 - val_loss: 0.9598 - val_accuracy: 0.6771 - val_recall: 0.6367
# Epoch 48/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7290 - accuracy: 0.6999 - recall: 0.5922 - val_loss: 0.9359 - val_accuracy: 0.6770 - val_recall: 0.6449
# Epoch 49/50
# 5308/5308 [==============================] - 48s 9ms/step - loss: 0.7276 - accuracy: 0.6993 - recall: 0.5918 - val_loss: 0.9880 - val_accuracy: 0.6823 - val_recall: 0.6437
# Epoch 50/50
# 5308/5308 [==============================] - 49s 9ms/step - loss: 0.7258 - accuracy: 0.7010 - recall: 0.5925 - val_loss: 0.9799 - val_accuracy: 0.6877 - val_recall: 0.6535

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall = model.evaluate(X_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
# Out:
# 3730/3730 [==============================] - 18s 5ms/step - loss: 0.9799 - accuracy: 0.6877 - recall: 0.6535
# Test Loss: 0.9799169898033142
# Test Accuracy: 0.6876534819602966
# Test Recall: 0.6535376906394958

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 3730/3730 [==============================] - 7s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.077
# Backdoor: 0.054982817869415807
# DoS: 0.714728429293753
# Exploits: 0.44677409692685555
# Fuzzers: 0.7187087549494061
# Generic: 0.9781994549863746
# Reconnaissance: 0.4779292592239489
# Shellcode: 0.7908208296557812
# Worms: 0.16923076923076924

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import pickle

# %%
# save the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/predicted_classes.pkl', 'wb') as model_file:
    pickle.dump(predicted_classes, model_file)

# %%
# load the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/predicted_classes.pkl', 'rb') as model_file:
    predicted_classes = pickle.load(model_file)
