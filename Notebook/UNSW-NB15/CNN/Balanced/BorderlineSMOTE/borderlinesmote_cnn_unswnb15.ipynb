# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall, Precision

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data-Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data-Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 5
# 6

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ' 'RST']
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'RST')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'ACC') & (data_test_attack['state'] != 'CLO')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 182, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Initialize Train Data and Test Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((119329, 182), (119329,), (45329, 182), (45329,))

# %% [markdown]
# ## BorderlineSMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE

borderlinesmote = BorderlineSMOTE()
X_borderlinesmote, y_borderlinesmote = borderlinesmote.fit_resample(X_train, y_train)

X_borderlinesmote.shape, y_borderlinesmote.shape
# Out:
# ((359991, 182), (359991,))

# %%
#Create new dataframe from X_borderlinesmote and y_borderlinesmote to count every attack
data_borderlinesmote = pd.concat([X_borderlinesmote, y_borderlinesmote], axis=1)

sns.countplot(data=data_borderlinesmote, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Backdoor'),
#   Text(1, 0, 'Analysis'),
#   Text(2, 0, 'Fuzzers'),
#   Text(3, 0, 'Shellcode'),
#   Text(4, 0, 'Reconnaissance'),
#   Text(5, 0, 'Exploits'),
#   Text(6, 0, 'DoS'),
#   Text(7, 0, 'Worms'),
#   Text(8, 0, 'Generic')])

# %%
#data_borderlinesmote.drop_duplicates(inplace=True)
print(data_borderlinesmote.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_borderlinesmote.shape))
print("--------------------")
print("Duplicates: " + str(data_borderlinesmote.duplicated().sum()))
# Out:
# attack_cat
# Analysis          39999
# Backdoor          39999
# DoS               39999
# Exploits          39999
# Fuzzers           39999
# Generic           39999
# Reconnaissance    39999
# Shellcode         39999
# Worms             39999
# Name: count, dtype: int64
# --------------------
# Shape: (359991, 183)
# --------------------
# Duplicates: 104530

# %% [markdown]
# # Model Architecture

# %%
# from keras import backend as K
import tensorflow_addons as tfa
# Out:
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (182, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision(), tfa.metrics.F1Score(num_classes=9, 
                                                                                                                                 average='macro')])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 178, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 177, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5664)              0
#
#  batch_normalization (BatchN  (None, 5664)             22656
#  ormalization)
#
#  dropout (Dropout)           (None, 5664)              0
#
#  dense (Dense)               (None, 32)                181280
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 204,809
# Trainable params: 193,481
# Non-trainable params: 11,328
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_borderlinesmote = le.fit_transform(y_borderlinesmote)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_borderlinesmote = to_categorical(y_borderlinesmote, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_borderlinesmote = np.array(X_borderlinesmote, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_borderlinesmote, y_borderlinesmote, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 11250/11250 [==============================] - 96s 8ms/step - loss: 1.0484 - accuracy: 0.5822 - recall: 0.4280 - precision: 0.8040 - f1_score: 0.5827 - val_loss: 1.8455 - val_accuracy: 0.5471 - val_recall: 0.5011 - val_precision: 0.5873 - val_f1_score: 0.2718
# Epoch 2/50
# 11250/11250 [==============================] - 92s 8ms/step - loss: 0.9401 - accuracy: 0.6256 - recall: 0.4906 - precision: 0.8339 - f1_score: 0.6295 - val_loss: 0.9458 - val_accuracy: 0.6370 - val_recall: 0.5960 - val_precision: 0.7765 - val_f1_score: 0.3396
# Epoch 3/50
# 11250/11250 [==============================] - 96s 9ms/step - loss: 0.9103 - accuracy: 0.6387 - recall: 0.5074 - precision: 0.8441 - f1_score: 0.6429 - val_loss: 0.9491 - val_accuracy: 0.6537 - val_recall: 0.6108 - val_precision: 0.7838 - val_f1_score: 0.3603
# Epoch 4/50
# 11250/11250 [==============================] - 95s 8ms/step - loss: 0.8917 - accuracy: 0.6472 - recall: 0.5169 - precision: 0.8508 - f1_score: 0.6512 - val_loss: 0.9347 - val_accuracy: 0.6478 - val_recall: 0.6059 - val_precision: 0.7814 - val_f1_score: 0.3526
# Epoch 5/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8778 - accuracy: 0.6529 - recall: 0.5251 - precision: 0.8579 - f1_score: 0.6568 - val_loss: 0.9689 - val_accuracy: 0.6372 - val_recall: 0.6016 - val_precision: 0.7712 - val_f1_score: 0.3482
# Epoch 6/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8672 - accuracy: 0.6569 - recall: 0.5302 - precision: 0.8605 - f1_score: 0.6610 - val_loss: 1.0286 - val_accuracy: 0.6489 - val_recall: 0.6125 - val_precision: 0.7728 - val_f1_score: 0.3489
# Epoch 7/50
# 11250/11250 [==============================] - 88s 8ms/step - loss: 0.8605 - accuracy: 0.6600 - recall: 0.5350 - precision: 0.8632 - f1_score: 0.6642 - val_loss: 0.9942 - val_accuracy: 0.6525 - val_recall: 0.6079 - val_precision: 0.7779 - val_f1_score: 0.3556
# Epoch 8/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8551 - accuracy: 0.6624 - recall: 0.5374 - precision: 0.8640 - f1_score: 0.6665 - val_loss: 1.1700 - val_accuracy: 0.6351 - val_recall: 0.6138 - val_precision: 0.6995 - val_f1_score: 0.3401
# Epoch 9/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8491 - accuracy: 0.6640 - recall: 0.5398 - precision: 0.8661 - f1_score: 0.6680 - val_loss: 0.9434 - val_accuracy: 0.6467 - val_recall: 0.6050 - val_precision: 0.7875 - val_f1_score: 0.3419
# Epoch 10/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8468 - accuracy: 0.6652 - recall: 0.5413 - precision: 0.8666 - f1_score: 0.6692 - val_loss: 1.0024 - val_accuracy: 0.6352 - val_recall: 0.5902 - val_precision: 0.7550 - val_f1_score: 0.3447
# Epoch 11/50
# 11250/11250 [==============================] - 101s 9ms/step - loss: 0.8433 - accuracy: 0.6662 - recall: 0.5430 - precision: 0.8665 - f1_score: 0.6704 - val_loss: 0.9717 - val_accuracy: 0.6582 - val_recall: 0.6260 - val_precision: 0.7833 - val_f1_score: 0.3591
# Epoch 12/50
# 11250/11250 [==============================] - 92s 8ms/step - loss: 0.8390 - accuracy: 0.6675 - recall: 0.5455 - precision: 0.8681 - f1_score: 0.6717 - val_loss: 0.9486 - val_accuracy: 0.6568 - val_recall: 0.6233 - val_precision: 0.7952 - val_f1_score: 0.3556
# Epoch 13/50
# 11250/11250 [==============================] - 94s 8ms/step - loss: 0.8381 - accuracy: 0.6684 - recall: 0.5461 - precision: 0.8687 - f1_score: 0.6726 - val_loss: 0.9391 - val_accuracy: 0.6437 - val_recall: 0.6020 - val_precision: 0.7648 - val_f1_score: 0.3568
# Epoch 14/50
# 11250/11250 [==============================] - 94s 8ms/step - loss: 0.8363 - accuracy: 0.6699 - recall: 0.5471 - precision: 0.8689 - f1_score: 0.6742 - val_loss: 0.9336 - val_accuracy: 0.6620 - val_recall: 0.6223 - val_precision: 0.7848 - val_f1_score: 0.3670
# Epoch 15/50
# 11250/11250 [==============================] - 94s 8ms/step - loss: 0.8337 - accuracy: 0.6696 - recall: 0.5476 - precision: 0.8696 - f1_score: 0.6741 - val_loss: 0.9425 - val_accuracy: 0.6577 - val_recall: 0.6215 - val_precision: 0.7866 - val_f1_score: 0.3594
# Epoch 16/50
# 11250/11250 [==============================] - 92s 8ms/step - loss: 0.8319 - accuracy: 0.6704 - recall: 0.5484 - precision: 0.8701 - f1_score: 0.6748 - val_loss: 0.9161 - val_accuracy: 0.6611 - val_recall: 0.6281 - val_precision: 0.7772 - val_f1_score: 0.3699
# Epoch 17/50
# 11250/11250 [==============================] - 93s 8ms/step - loss: 0.8289 - accuracy: 0.6714 - recall: 0.5499 - precision: 0.8703 - f1_score: 0.6758 - val_loss: 1.0054 - val_accuracy: 0.6441 - val_recall: 0.6087 - val_precision: 0.7744 - val_f1_score: 0.3523
# Epoch 18/50
# 11250/11250 [==============================] - 92s 8ms/step - loss: 0.8279 - accuracy: 0.6726 - recall: 0.5507 - precision: 0.8710 - f1_score: 0.6772 - val_loss: 1.0581 - val_accuracy: 0.6406 - val_recall: 0.6009 - val_precision: 0.7601 - val_f1_score: 0.3395
# Epoch 19/50
# 11250/11250 [==============================] - 96s 9ms/step - loss: 0.8273 - accuracy: 0.6724 - recall: 0.5508 - precision: 0.8717 - f1_score: 0.6770 - val_loss: 0.9906 - val_accuracy: 0.6391 - val_recall: 0.6023 - val_precision: 0.7523 - val_f1_score: 0.3478
# Epoch 20/50
# 11250/11250 [==============================] - 90s 8ms/step - loss: 0.8245 - accuracy: 0.6732 - recall: 0.5515 - precision: 0.8719 - f1_score: 0.6777 - val_loss: 0.9408 - val_accuracy: 0.6574 - val_recall: 0.6174 - val_precision: 0.7668 - val_f1_score: 0.3637
# Epoch 21/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8227 - accuracy: 0.6743 - recall: 0.5528 - precision: 0.8724 - f1_score: 0.6789 - val_loss: 0.9336 - val_accuracy: 0.6577 - val_recall: 0.6289 - val_precision: 0.7885 - val_f1_score: 0.3591
# Epoch 22/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8216 - accuracy: 0.6739 - recall: 0.5531 - precision: 0.8728 - f1_score: 0.6788 - val_loss: 1.3347 - val_accuracy: 0.6249 - val_recall: 0.6122 - val_precision: 0.6567 - val_f1_score: 0.3268
# Epoch 23/50
# 11250/11250 [==============================] - 88s 8ms/step - loss: 0.8209 - accuracy: 0.6745 - recall: 0.5528 - precision: 0.8733 - f1_score: 0.6793 - val_loss: 0.9215 - val_accuracy: 0.6623 - val_recall: 0.6253 - val_precision: 0.8048 - val_f1_score: 0.3538
# Epoch 24/50
# 11250/11250 [==============================] - 88s 8ms/step - loss: 0.8198 - accuracy: 0.6750 - recall: 0.5537 - precision: 0.8734 - f1_score: 0.6797 - val_loss: 0.9784 - val_accuracy: 0.6520 - val_recall: 0.6165 - val_precision: 0.7702 - val_f1_score: 0.3578
# Epoch 25/50
# 11250/11250 [==============================] - 90s 8ms/step - loss: 0.8185 - accuracy: 0.6759 - recall: 0.5551 - precision: 0.8744 - f1_score: 0.6807 - val_loss: 1.0459 - val_accuracy: 0.6625 - val_recall: 0.6249 - val_precision: 0.7827 - val_f1_score: 0.3828
# Epoch 26/50
# 11250/11250 [==============================] - 88s 8ms/step - loss: 0.8179 - accuracy: 0.6759 - recall: 0.5543 - precision: 0.8737 - f1_score: 0.6807 - val_loss: 0.9564 - val_accuracy: 0.6603 - val_recall: 0.6273 - val_precision: 0.7708 - val_f1_score: 0.3661
# Epoch 27/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8170 - accuracy: 0.6753 - recall: 0.5548 - precision: 0.8738 - f1_score: 0.6802 - val_loss: 1.0500 - val_accuracy: 0.6439 - val_recall: 0.6037 - val_precision: 0.7552 - val_f1_score: 0.3467
# Epoch 28/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8162 - accuracy: 0.6763 - recall: 0.5556 - precision: 0.8746 - f1_score: 0.6814 - val_loss: 0.8750 - val_accuracy: 0.6696 - val_recall: 0.6281 - val_precision: 0.7966 - val_f1_score: 0.3694
# Epoch 29/50
# 11250/11250 [==============================] - 87s 8ms/step - loss: 0.8162 - accuracy: 0.6767 - recall: 0.5562 - precision: 0.8743 - f1_score: 0.6816 - val_loss: 0.9224 - val_accuracy: 0.6601 - val_recall: 0.6191 - val_precision: 0.8064 - val_f1_score: 0.3686
# Epoch 30/50
# 11250/11250 [==============================] - 88s 8ms/step - loss: 0.8162 - accuracy: 0.6762 - recall: 0.5561 - precision: 0.8748 - f1_score: 0.6812 - val_loss: 1.0514 - val_accuracy: 0.6460 - val_recall: 0.6063 - val_precision: 0.7409 - val_f1_score: 0.3599
# Epoch 31/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8146 - accuracy: 0.6767 - recall: 0.5566 - precision: 0.8743 - f1_score: 0.6817 - val_loss: 0.9894 - val_accuracy: 0.6613 - val_recall: 0.6290 - val_precision: 0.7701 - val_f1_score: 0.3473
# Epoch 32/50
# 11250/11250 [==============================] - 90s 8ms/step - loss: 0.8137 - accuracy: 0.6770 - recall: 0.5567 - precision: 0.8748 - f1_score: 0.6820 - val_loss: 0.9674 - val_accuracy: 0.6736 - val_recall: 0.6383 - val_precision: 0.7868 - val_f1_score: 0.3784
# Epoch 33/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8130 - accuracy: 0.6777 - recall: 0.5573 - precision: 0.8751 - f1_score: 0.6828 - val_loss: 0.9702 - val_accuracy: 0.6675 - val_recall: 0.6282 - val_precision: 0.7936 - val_f1_score: 0.3576
# Epoch 34/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8130 - accuracy: 0.6771 - recall: 0.5572 - precision: 0.8748 - f1_score: 0.6823 - val_loss: 0.9973 - val_accuracy: 0.6514 - val_recall: 0.6135 - val_precision: 0.7694 - val_f1_score: 0.3648
# Epoch 35/50
# 11250/11250 [==============================] - 88s 8ms/step - loss: 0.8116 - accuracy: 0.6778 - recall: 0.5574 - precision: 0.8753 - f1_score: 0.6827 - val_loss: 1.0860 - val_accuracy: 0.6392 - val_recall: 0.6051 - val_precision: 0.7676 - val_f1_score: 0.3411
# Epoch 36/50
# 11250/11250 [==============================] - 89s 8ms/step - loss: 0.8111 - accuracy: 0.6789 - recall: 0.5585 - precision: 0.8749 - f1_score: 0.6840 - val_loss: 0.9640 - val_accuracy: 0.6570 - val_recall: 0.6201 - val_precision: 0.7824 - val_f1_score: 0.3482
# Epoch 37/50
# 11250/11250 [==============================] - 85s 8ms/step - loss: 0.8097 - accuracy: 0.6782 - recall: 0.5585 - precision: 0.8749 - f1_score: 0.6832 - val_loss: 1.1584 - val_accuracy: 0.6379 - val_recall: 0.6050 - val_precision: 0.7552 - val_f1_score: 0.3398
# Epoch 38/50
# 11250/11250 [==============================] - 84s 7ms/step - loss: 0.8098 - accuracy: 0.6783 - recall: 0.5586 - precision: 0.8749 - f1_score: 0.6835 - val_loss: 0.9908 - val_accuracy: 0.6418 - val_recall: 0.5968 - val_precision: 0.7584 - val_f1_score: 0.3495
# Epoch 39/50
# 11250/11250 [==============================] - 87s 8ms/step - loss: 0.8094 - accuracy: 0.6782 - recall: 0.5593 - precision: 0.8755 - f1_score: 0.6836 - val_loss: 1.0971 - val_accuracy: 0.6534 - val_recall: 0.6175 - val_precision: 0.7508 - val_f1_score: 0.3458
# Epoch 40/50
# 11250/11250 [==============================] - 87s 8ms/step - loss: 0.8087 - accuracy: 0.6791 - recall: 0.5591 - precision: 0.8758 - f1_score: 0.6843 - val_loss: 0.9847 - val_accuracy: 0.6598 - val_recall: 0.6238 - val_precision: 0.7876 - val_f1_score: 0.3585
# Epoch 41/50
# 11250/11250 [==============================] - 86s 8ms/step - loss: 0.8083 - accuracy: 0.6795 - recall: 0.5595 - precision: 0.8765 - f1_score: 0.6848 - val_loss: 1.0728 - val_accuracy: 0.6584 - val_recall: 0.6214 - val_precision: 0.7715 - val_f1_score: 0.3663
# Epoch 42/50
# 11250/11250 [==============================] - 86s 8ms/step - loss: 0.8076 - accuracy: 0.6795 - recall: 0.5601 - precision: 0.8757 - f1_score: 0.6845 - val_loss: 1.2504 - val_accuracy: 0.6334 - val_recall: 0.6003 - val_precision: 0.7358 - val_f1_score: 0.3278
# Epoch 43/50
# 11250/11250 [==============================] - 86s 8ms/step - loss: 0.8073 - accuracy: 0.6794 - recall: 0.5601 - precision: 0.8768 - f1_score: 0.6845 - val_loss: 1.2716 - val_accuracy: 0.6408 - val_recall: 0.6027 - val_precision: 0.7550 - val_f1_score: 0.3446
# Epoch 44/50
# 11250/11250 [==============================] - 87s 8ms/step - loss: 0.8063 - accuracy: 0.6799 - recall: 0.5603 - precision: 0.8758 - f1_score: 0.6850 - val_loss: 0.9381 - val_accuracy: 0.6554 - val_recall: 0.6203 - val_precision: 0.7896 - val_f1_score: 0.3564
# Epoch 45/50
# 11250/11250 [==============================] - 87s 8ms/step - loss: 0.8058 - accuracy: 0.6800 - recall: 0.5613 - precision: 0.8763 - f1_score: 0.6852 - val_loss: 1.0459 - val_accuracy: 0.6449 - val_recall: 0.6113 - val_precision: 0.7482 - val_f1_score: 0.3436
# Epoch 46/50
# 11250/11250 [==============================] - 85s 8ms/step - loss: 0.8054 - accuracy: 0.6813 - recall: 0.5620 - precision: 0.8762 - f1_score: 0.6866 - val_loss: 0.9843 - val_accuracy: 0.6688 - val_recall: 0.6153 - val_precision: 0.7966 - val_f1_score: 0.3517
# Epoch 47/50
# 11250/11250 [==============================] - 96s 9ms/step - loss: 0.8057 - accuracy: 0.6810 - recall: 0.5613 - precision: 0.8768 - f1_score: 0.6862 - val_loss: 0.9750 - val_accuracy: 0.6564 - val_recall: 0.6248 - val_precision: 0.7737 - val_f1_score: 0.3566
# Epoch 48/50
# 11250/11250 [==============================] - 94s 8ms/step - loss: 0.8042 - accuracy: 0.6804 - recall: 0.5619 - precision: 0.8777 - f1_score: 0.6858 - val_loss: 1.0103 - val_accuracy: 0.6574 - val_recall: 0.6153 - val_precision: 0.7687 - val_f1_score: 0.3526
# Epoch 49/50
# 11250/11250 [==============================] - 92s 8ms/step - loss: 0.8044 - accuracy: 0.6809 - recall: 0.5617 - precision: 0.8771 - f1_score: 0.6862 - val_loss: 1.0363 - val_accuracy: 0.6423 - val_recall: 0.5984 - val_precision: 0.7510 - val_f1_score: 0.3533
# Epoch 50/50
# 11250/11250 [==============================] - 91s 8ms/step - loss: 0.8043 - accuracy: 0.6803 - recall: 0.5614 - precision: 0.8768 - f1_score: 0.6856 - val_loss: 1.0451 - val_accuracy: 0.6539 - val_recall: 0.6144 - val_precision: 0.7574 - val_f1_score: 0.3506

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall, precision, f1_score = model.evaluate(X_test, y_test)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
print('Test Precision:', precision)
print('Test F1-Score:', f1_score)
# Out:
# 1417/1417 [==============================] - 8s 5ms/step - loss: 1.0451 - accuracy: 0.6539 - recall: 0.6144 - precision: 0.7574 - f1_score: 0.3506
# Test Loss: 1.0451289415359497
# Test Accuracy: 0.6538639664649963
# Test Recall: 0.614352822303772
# Test Precision: 0.7573771476745605
# Test F1-Score: 0.6784087224245697

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 1417/1417 [==============================] - 3s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.033973412112259974
# Backdoor: 0.451114922813036
# DoS: 0.2983614575690878
# Exploits: 0.514239511274818
# Fuzzers: 0.5870318429302095
# Generic: 0.9555932383021567
# Reconnaissance: 0.1290414878397711
# Shellcode: 0.8862433862433863
# Worms: 0.7272727272727273

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import joblib

# %%
# save predicted
joblib.dump(predicted_classes, '/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/predicted_classes.joblib', compress=('zlib', 3))
# Out:
# ['/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/predicted_classes.joblib']

# %%
# load the predicted
predicted_classes = joblib.load('/Data/Visual Studio Code/Data-Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/predicted_classes.joblib')
