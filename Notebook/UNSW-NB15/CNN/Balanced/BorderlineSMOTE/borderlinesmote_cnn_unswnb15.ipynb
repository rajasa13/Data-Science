# %% [markdown]
# # Data Preprocessing

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.metrics import Recall, Precision

# %%
#Check GPU device available
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
data_train = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_training-set.csv')
data_test = pd.read_csv('/Data/Visual Studio Code/Data Science/Dataset/UNSW-NB15/UNSW_NB15_testing-set.csv')

# %%
# Handle missing value and duplicate if any
data_train.dropna(inplace=True)
data_train.drop_duplicates(inplace=True)

data_test.dropna(inplace=True)
data_test.drop_duplicates(inplace=True)

# %%
#Split Attack and Normal from dataframe
data_train_attack = data_train[data_train['label'] == 1]
data_test_attack = data_test[data_test['label'] == 1]

#Optional
#data_train_normal = data_train[data_train['label'] == 0]
#data_test_normal = data_test[data_test['label'] == 0]

# %%
# Drop id and label from train and test data
data_train_attack = data_train_attack.drop('id', axis=1)
data_train_attack = data_train_attack.drop('label', axis=1)

data_test_attack = data_test_attack.drop('id', axis=1)
data_test_attack = data_test_attack.drop('label', axis=1)

# %%
print(data_train_attack['state'].nunique())
print(data_test_attack['state'].nunique())
# Out:
# 6
# 5

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'ACC' 'CON' 'REQ' 'CLO']
# ['INT' 'FIN' 'CON' 'REQ' 'RST']

# %%
#Drop ACC, CLO, and RST from data
data_train_attack = data_train_attack[(data_train_attack['state'] != 'ACC') & (data_train_attack['state'] != 'CLO')]
data_test_attack = data_test_attack[(data_test_attack['state'] != 'RST')]

# %%
print(data_train_attack['state'].unique())
print(data_test_attack['state'].unique())
# Out:
# ['INT' 'FIN' 'CON' 'REQ']
# ['INT' 'FIN' 'CON' 'REQ']

# %% [markdown]
# ## Encode Train and Test Data

# %%
#column to encode
cols = ['proto','state','service']
cols
# Out:
# ['proto', 'state', 'service']

# %%
#One-hot Encoding
# Encode train data
data_train_attack = pd.get_dummies(data_train_attack, columns=cols)

# Encode test data
data_test_attack = pd.get_dummies(data_test_attack, columns=cols)

# %%
train_attack_cat = data_train_attack.pop('attack_cat')
test_attack_cat = data_test_attack.pop('attack_cat')

# %% [markdown]
# ## Normalization

# %%
# Min-Max Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cols_to_norm = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 
                'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 
                'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 
                'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 
                'ct_srv_dst', 'is_sm_ips_ports']

data_train_attack[cols_to_norm] = scaler.fit_transform(data_train_attack[cols_to_norm])
data_test_attack[cols_to_norm] = scaler.fit_transform(data_test_attack[cols_to_norm])

# %% [markdown]
# ## Feature Selection

# %%
#Feature Selection
feature = data_train_attack.drop(['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'], axis=1)
feature.dtypes
# Out:
# dur               float64
# spkts             float64
# dpkts             float64
# sbytes            float64
# dbytes            float64
#                    ...
# service_radius       bool
# service_smtp         bool
# service_snmp         bool
# service_ssh          bool
# service_ssl          bool
# Length: 181, dtype: object

# %% [markdown]
# # Balancing Data

# %% [markdown]
# ## Split Data

# %%
#Splitting the dataset into dependent and independent feature
X_train = feature
y_train = train_attack_cat

X_test = data_test_attack.drop(columns=['dinpkt', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'is_sm_ips_ports'])
y_test = test_attack_cat

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((45329, 181), (45329,), (119329, 181), (119329,))

# %% [markdown]
# ## BorderlineSMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE

borderlinesmote = BorderlineSMOTE()
X_borderlinesmote, y_borderlinesmote = borderlinesmote.fit_resample(X_train, y_train)

X_borderlinesmote.shape, y_borderlinesmote.shape
# Out:
# ((169839, 181), (169839,))

# %%
#Create new dataframe from X_borderlinesmote and y_borderlinesmote to count every attack
data_borderlinesmote = pd.concat([X_borderlinesmote, y_borderlinesmote], axis=1)

sns.countplot(data=data_borderlinesmote, x="attack_cat")
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Reconnaissance'),
#   Text(1, 0, 'Backdoor'),
#   Text(2, 0, 'DoS'),
#   Text(3, 0, 'Exploits'),
#   Text(4, 0, 'Analysis'),
#   Text(5, 0, 'Fuzzers'),
#   Text(6, 0, 'Worms'),
#   Text(7, 0, 'Shellcode'),
#   Text(8, 0, 'Generic')])

# %%
#data_borderlinesmote.drop_duplicates(inplace=True)
print(data_borderlinesmote.value_counts('attack_cat'))
print("--------------------")
print("Shape: " + str(data_borderlinesmote.shape))
print("--------------------")
print("Duplicates: " + str(data_borderlinesmote.duplicated().sum()))
# Out:
# attack_cat
# Analysis          18871
# Backdoor          18871
# DoS               18871
# Exploits          18871
# Fuzzers           18871
# Generic           18871
# Reconnaissance    18871
# Shellcode         18871
# Worms             18871
# Name: count, dtype: int64
# --------------------
# Shape: (169839, 182)
# --------------------
# Duplicates: 49418

# %% [markdown]
# # Model Architecture

# %%
# from keras import backend as K
import tensorflow_addons as tfa
# Out:
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Acer\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## 1D-CNN (1 layer) Model

# %%
# Define the input shape
input_shape = (181, 1)

# Create the sequential model
model = Sequential()

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=5, activation='sigmoid', input_shape=input_shape))

# MaxPooling1D layer
model.add(MaxPooling1D(pool_size=2, strides=1))

# Flatten layer
model.add(Flatten())

# Batch Normalization layer
model.add(BatchNormalization(axis=-1))

# Dropout layer with dropout 0.5
model.add(Dropout(0.5))

# Two Fully-connected layers
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output
model.add(Dense(units=9, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision(), tfa.metrics.F1Score(num_classes=9, 
                                                                                                                                 average='macro')])

# %%
#Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 177, 32)           192
#
#  max_pooling1d (MaxPooling1D  (None, 176, 32)          0
#  )
#
#  flatten (Flatten)           (None, 5632)              0
#
#  batch_normalization (BatchN  (None, 5632)             22528
#  ormalization)
#
#  dropout (Dropout)           (None, 5632)              0
#
#  dense (Dense)               (None, 32)                180256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 9)                 153
#
# =================================================================
# Total params: 203,657
# Trainable params: 192,393
# Non-trainable params: 11,264
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_borderlinesmote = le.fit_transform(y_borderlinesmote)
y_test = le.fit_transform(y_test)

# %%
num_class = 9
y_borderlinesmote = to_categorical(y_borderlinesmote, num_class)
y_test = to_categorical(y_test, num_class)

# %%
X_borderlinesmote = np.array(X_borderlinesmote, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

# %%
#Define epochs and batch size
epochs = 50
batch_size = 32

#Train the model
history = model.fit(X_borderlinesmote, y_borderlinesmote, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5308/5308 [==============================] - 60s 11ms/step - loss: 0.9637 - accuracy: 0.6104 - recall: 0.4497 - precision: 0.7694 - f1_score: 0.6018 - val_loss: 1.1673 - val_accuracy: 0.5685 - val_recall: 0.5269 - val_precision: 0.6975 - val_f1_score: 0.3444
# Epoch 2/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.8675 - accuracy: 0.6446 - recall: 0.5123 - precision: 0.7819 - f1_score: 0.6373 - val_loss: 1.7178 - val_accuracy: 0.6292 - val_recall: 0.6083 - val_precision: 0.6719 - val_f1_score: 0.3817
# Epoch 3/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.8380 - accuracy: 0.6555 - recall: 0.5288 - precision: 0.7892 - f1_score: 0.6491 - val_loss: 1.8620 - val_accuracy: 0.5920 - val_recall: 0.5745 - val_precision: 0.6491 - val_f1_score: 0.3578
# Epoch 4/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.8258 - accuracy: 0.6591 - recall: 0.5348 - precision: 0.7923 - f1_score: 0.6531 - val_loss: 1.0169 - val_accuracy: 0.6392 - val_recall: 0.5927 - val_precision: 0.7640 - val_f1_score: 0.3969
# Epoch 5/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.8120 - accuracy: 0.6647 - recall: 0.5426 - precision: 0.7956 - f1_score: 0.6585 - val_loss: 2.3530 - val_accuracy: 0.5821 - val_recall: 0.5642 - val_precision: 0.6198 - val_f1_score: 0.3654
# Epoch 6/50
# 5308/5308 [==============================] - 51s 10ms/step - loss: 0.8027 - accuracy: 0.6679 - recall: 0.5456 - precision: 0.7984 - f1_score: 0.6621 - val_loss: 0.9677 - val_accuracy: 0.6843 - val_recall: 0.6280 - val_precision: 0.7759 - val_f1_score: 0.4158
# Epoch 7/50
# 5308/5308 [==============================] - 52s 10ms/step - loss: 0.7963 - accuracy: 0.6706 - recall: 0.5498 - precision: 0.8001 - f1_score: 0.6643 - val_loss: 0.9467 - val_accuracy: 0.6824 - val_recall: 0.6322 - val_precision: 0.7745 - val_f1_score: 0.4226
# Epoch 8/50
# 5308/5308 [==============================] - 51s 10ms/step - loss: 0.7898 - accuracy: 0.6734 - recall: 0.5547 - precision: 0.8003 - f1_score: 0.6671 - val_loss: 1.1751 - val_accuracy: 0.6284 - val_recall: 0.5879 - val_precision: 0.7428 - val_f1_score: 0.3910
# Epoch 9/50
# 5308/5308 [==============================] - 52s 10ms/step - loss: 0.7865 - accuracy: 0.6738 - recall: 0.5559 - precision: 0.8025 - f1_score: 0.6676 - val_loss: 0.9963 - val_accuracy: 0.6783 - val_recall: 0.6241 - val_precision: 0.7693 - val_f1_score: 0.4189
# Epoch 10/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7837 - accuracy: 0.6756 - recall: 0.5571 - precision: 0.8038 - f1_score: 0.6693 - val_loss: 1.0081 - val_accuracy: 0.6701 - val_recall: 0.6048 - val_precision: 0.7845 - val_f1_score: 0.4163
# Epoch 11/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7780 - accuracy: 0.6776 - recall: 0.5603 - precision: 0.8053 - f1_score: 0.6712 - val_loss: 1.0864 - val_accuracy: 0.6696 - val_recall: 0.6211 - val_precision: 0.7653 - val_f1_score: 0.4225
# Epoch 12/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7763 - accuracy: 0.6787 - recall: 0.5611 - precision: 0.8053 - f1_score: 0.6724 - val_loss: 1.0306 - val_accuracy: 0.6726 - val_recall: 0.6199 - val_precision: 0.8010 - val_f1_score: 0.4334
# Epoch 13/50
# 5308/5308 [==============================] - 63s 12ms/step - loss: 0.7739 - accuracy: 0.6803 - recall: 0.5626 - precision: 0.8065 - f1_score: 0.6741 - val_loss: 1.0375 - val_accuracy: 0.6673 - val_recall: 0.6143 - val_precision: 0.7535 - val_f1_score: 0.4084
# Epoch 14/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7695 - accuracy: 0.6810 - recall: 0.5649 - precision: 0.8075 - f1_score: 0.6742 - val_loss: 1.0683 - val_accuracy: 0.6712 - val_recall: 0.6272 - val_precision: 0.7410 - val_f1_score: 0.4178
# Epoch 15/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7686 - accuracy: 0.6823 - recall: 0.5658 - precision: 0.8089 - f1_score: 0.6758 - val_loss: 1.0211 - val_accuracy: 0.6715 - val_recall: 0.6183 - val_precision: 0.7753 - val_f1_score: 0.4214
# Epoch 16/50
# 5308/5308 [==============================] - 52s 10ms/step - loss: 0.7677 - accuracy: 0.6825 - recall: 0.5669 - precision: 0.8085 - f1_score: 0.6752 - val_loss: 1.0316 - val_accuracy: 0.6711 - val_recall: 0.6303 - val_precision: 0.7515 - val_f1_score: 0.4218
# Epoch 17/50
# 5308/5308 [==============================] - 52s 10ms/step - loss: 0.7644 - accuracy: 0.6837 - recall: 0.5674 - precision: 0.8091 - f1_score: 0.6766 - val_loss: 1.0353 - val_accuracy: 0.6784 - val_recall: 0.6315 - val_precision: 0.7586 - val_f1_score: 0.4246
# Epoch 18/50
# 5308/5308 [==============================] - 51s 10ms/step - loss: 0.7634 - accuracy: 0.6849 - recall: 0.5687 - precision: 0.8104 - f1_score: 0.6780 - val_loss: 1.0553 - val_accuracy: 0.6643 - val_recall: 0.6137 - val_precision: 0.7713 - val_f1_score: 0.4227
# Epoch 19/50
# 5308/5308 [==============================] - 52s 10ms/step - loss: 0.7609 - accuracy: 0.6858 - recall: 0.5707 - precision: 0.8108 - f1_score: 0.6789 - val_loss: 1.0191 - val_accuracy: 0.6819 - val_recall: 0.6292 - val_precision: 0.7769 - val_f1_score: 0.4300
# Epoch 20/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7611 - accuracy: 0.6864 - recall: 0.5706 - precision: 0.8117 - f1_score: 0.6789 - val_loss: 1.0097 - val_accuracy: 0.6860 - val_recall: 0.6398 - val_precision: 0.7691 - val_f1_score: 0.4270
# Epoch 21/50
# 5308/5308 [==============================] - 53s 10ms/step - loss: 0.7571 - accuracy: 0.6873 - recall: 0.5724 - precision: 0.8122 - f1_score: 0.6803 - val_loss: 1.1524 - val_accuracy: 0.6438 - val_recall: 0.5950 - val_precision: 0.7211 - val_f1_score: 0.3988
# Epoch 22/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7555 - accuracy: 0.6889 - recall: 0.5730 - precision: 0.8132 - f1_score: 0.6814 - val_loss: 1.1272 - val_accuracy: 0.6645 - val_recall: 0.6174 - val_precision: 0.7450 - val_f1_score: 0.4159
# Epoch 23/50
# 5308/5308 [==============================] - 54s 10ms/step - loss: 0.7544 - accuracy: 0.6902 - recall: 0.5752 - precision: 0.8152 - f1_score: 0.6831 - val_loss: 1.0186 - val_accuracy: 0.6764 - val_recall: 0.6167 - val_precision: 0.7855 - val_f1_score: 0.4206
# Epoch 24/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7519 - accuracy: 0.6910 - recall: 0.5768 - precision: 0.8167 - f1_score: 0.6831 - val_loss: 1.0814 - val_accuracy: 0.6594 - val_recall: 0.5986 - val_precision: 0.7686 - val_f1_score: 0.4139
# Epoch 25/50
# 5308/5308 [==============================] - 58s 11ms/step - loss: 0.7472 - accuracy: 0.6932 - recall: 0.5787 - precision: 0.8187 - f1_score: 0.6863 - val_loss: 1.0391 - val_accuracy: 0.6680 - val_recall: 0.6111 - val_precision: 0.7682 - val_f1_score: 0.4217
# Epoch 26/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7459 - accuracy: 0.6943 - recall: 0.5801 - precision: 0.8196 - f1_score: 0.6873 - val_loss: 1.0575 - val_accuracy: 0.6700 - val_recall: 0.6343 - val_precision: 0.7278 - val_f1_score: 0.4224
# Epoch 27/50
# 5308/5308 [==============================] - 60s 11ms/step - loss: 0.7435 - accuracy: 0.6950 - recall: 0.5817 - precision: 0.8206 - f1_score: 0.6878 - val_loss: 1.0149 - val_accuracy: 0.6764 - val_recall: 0.6329 - val_precision: 0.7584 - val_f1_score: 0.4339
# Epoch 28/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7405 - accuracy: 0.6955 - recall: 0.5830 - precision: 0.8212 - f1_score: 0.6885 - val_loss: 1.1213 - val_accuracy: 0.6540 - val_recall: 0.6084 - val_precision: 0.7344 - val_f1_score: 0.4101
# Epoch 29/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7405 - accuracy: 0.6956 - recall: 0.5833 - precision: 0.8206 - f1_score: 0.6882 - val_loss: 1.0152 - val_accuracy: 0.6764 - val_recall: 0.6411 - val_precision: 0.7420 - val_f1_score: 0.4257
# Epoch 30/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7398 - accuracy: 0.6965 - recall: 0.5847 - precision: 0.8220 - f1_score: 0.6896 - val_loss: 1.0119 - val_accuracy: 0.6701 - val_recall: 0.6033 - val_precision: 0.7754 - val_f1_score: 0.4196
# Epoch 31/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7394 - accuracy: 0.6964 - recall: 0.5838 - precision: 0.8220 - f1_score: 0.6884 - val_loss: 1.0615 - val_accuracy: 0.6678 - val_recall: 0.6208 - val_precision: 0.7621 - val_f1_score: 0.4163
# Epoch 32/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7374 - accuracy: 0.6970 - recall: 0.5846 - precision: 0.8228 - f1_score: 0.6899 - val_loss: 1.0525 - val_accuracy: 0.6655 - val_recall: 0.6142 - val_precision: 0.7652 - val_f1_score: 0.4245
# Epoch 33/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7348 - accuracy: 0.6986 - recall: 0.5872 - precision: 0.8241 - f1_score: 0.6914 - val_loss: 1.0558 - val_accuracy: 0.6701 - val_recall: 0.6259 - val_precision: 0.7441 - val_f1_score: 0.4272
# Epoch 34/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7342 - accuracy: 0.6986 - recall: 0.5879 - precision: 0.8228 - f1_score: 0.6914 - val_loss: 1.0414 - val_accuracy: 0.6589 - val_recall: 0.6112 - val_precision: 0.7531 - val_f1_score: 0.4150
# Epoch 35/50
# 5308/5308 [==============================] - 58s 11ms/step - loss: 0.7332 - accuracy: 0.6984 - recall: 0.5874 - precision: 0.8235 - f1_score: 0.6916 - val_loss: 1.0403 - val_accuracy: 0.6743 - val_recall: 0.6288 - val_precision: 0.7578 - val_f1_score: 0.4241
# Epoch 36/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7322 - accuracy: 0.6991 - recall: 0.5886 - precision: 0.8243 - f1_score: 0.6925 - val_loss: 1.0678 - val_accuracy: 0.6636 - val_recall: 0.6194 - val_precision: 0.7438 - val_f1_score: 0.3984
# Epoch 37/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7320 - accuracy: 0.6989 - recall: 0.5883 - precision: 0.8243 - f1_score: 0.6922 - val_loss: 1.0564 - val_accuracy: 0.6715 - val_recall: 0.6329 - val_precision: 0.7373 - val_f1_score: 0.4319
# Epoch 38/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7301 - accuracy: 0.7002 - recall: 0.5904 - precision: 0.8253 - f1_score: 0.6931 - val_loss: 1.0999 - val_accuracy: 0.6513 - val_recall: 0.6187 - val_precision: 0.7126 - val_f1_score: 0.3924
# Epoch 39/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7303 - accuracy: 0.7008 - recall: 0.5903 - precision: 0.8241 - f1_score: 0.6939 - val_loss: 0.9695 - val_accuracy: 0.6786 - val_recall: 0.6386 - val_precision: 0.7516 - val_f1_score: 0.4250
# Epoch 40/50
# 5308/5308 [==============================] - 55s 10ms/step - loss: 0.7296 - accuracy: 0.6999 - recall: 0.5899 - precision: 0.8244 - f1_score: 0.6925 - val_loss: 1.0050 - val_accuracy: 0.6690 - val_recall: 0.6225 - val_precision: 0.7551 - val_f1_score: 0.4287
# Epoch 41/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7266 - accuracy: 0.7018 - recall: 0.5909 - precision: 0.8253 - f1_score: 0.6948 - val_loss: 1.0355 - val_accuracy: 0.6670 - val_recall: 0.6287 - val_precision: 0.7385 - val_f1_score: 0.4102
# Epoch 42/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7272 - accuracy: 0.7008 - recall: 0.5921 - precision: 0.8244 - f1_score: 0.6941 - val_loss: 1.2415 - val_accuracy: 0.6589 - val_recall: 0.6150 - val_precision: 0.7740 - val_f1_score: 0.3807
# Epoch 43/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7257 - accuracy: 0.7015 - recall: 0.5925 - precision: 0.8253 - f1_score: 0.6947 - val_loss: 1.0112 - val_accuracy: 0.6780 - val_recall: 0.6347 - val_precision: 0.7701 - val_f1_score: 0.4308
# Epoch 44/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7249 - accuracy: 0.7011 - recall: 0.5932 - precision: 0.8243 - f1_score: 0.6945 - val_loss: 0.9915 - val_accuracy: 0.6802 - val_recall: 0.6326 - val_precision: 0.7633 - val_f1_score: 0.4359
# Epoch 45/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7233 - accuracy: 0.7020 - recall: 0.5933 - precision: 0.8259 - f1_score: 0.6950 - val_loss: 1.0189 - val_accuracy: 0.6814 - val_recall: 0.6478 - val_precision: 0.7495 - val_f1_score: 0.4419
# Epoch 46/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7228 - accuracy: 0.7022 - recall: 0.5942 - precision: 0.8257 - f1_score: 0.6955 - val_loss: 1.0920 - val_accuracy: 0.6655 - val_recall: 0.6373 - val_precision: 0.7228 - val_f1_score: 0.4227
# Epoch 47/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7235 - accuracy: 0.7019 - recall: 0.5937 - precision: 0.8258 - f1_score: 0.6950 - val_loss: 0.9816 - val_accuracy: 0.6799 - val_recall: 0.6206 - val_precision: 0.7818 - val_f1_score: 0.4322
# Epoch 48/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7211 - accuracy: 0.7026 - recall: 0.5938 - precision: 0.8252 - f1_score: 0.6956 - val_loss: 1.0713 - val_accuracy: 0.6600 - val_recall: 0.6185 - val_precision: 0.7321 - val_f1_score: 0.4114
# Epoch 49/50
# 5308/5308 [==============================] - 56s 11ms/step - loss: 0.7219 - accuracy: 0.7026 - recall: 0.5940 - precision: 0.8255 - f1_score: 0.6963 - val_loss: 0.9836 - val_accuracy: 0.6833 - val_recall: 0.6380 - val_precision: 0.7629 - val_f1_score: 0.4315
# Epoch 50/50
# 5308/5308 [==============================] - 57s 11ms/step - loss: 0.7208 - accuracy: 0.7031 - recall: 0.5953 - precision: 0.8267 - f1_score: 0.6969 - val_loss: 1.0291 - val_accuracy: 0.6762 - val_recall: 0.6305 - val_precision: 0.7595 - val_f1_score: 0.4327

# %% [markdown]
# # Evaluate The Model

# %%
#Evaluate the model on test data
loss, accuracy, recall, precision, f1_score = model.evaluate(X_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
print('Test Recall:', recall)
print('Test Precision:', precision)
print('Test F1-Score:', f1_score)
# Out:
# 3730/3730 [==============================] - 21s 6ms/step - loss: 1.0291 - accuracy: 0.6762 - recall: 0.6305 - precision: 0.7595 - f1_score: 0.4327
# Test Loss: 1.0290873050689697
# Test Accuracy: 0.6761809587478638
# Test Recall: 0.6305005550384521
# Test Precision: 0.7595170736312866
# Test F1-Score: 0.4327327311038971

# %%
# make a predictions
predictions = model.predict(X_test)
# Out:
# 3730/3730 [==============================] - 6s 2ms/step

# %%
# convert one-hot encode predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)
y_test_categorical = np.argmax(y_test, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
# function to calculate recall from confusion matrix
def calculate_recall(confusion_matrix):
    num_class = len(confusion_matrix)
    recalls = []

    for i in range(num_class):
        true_positive = confusion_matrix[i][i]
        false_negative = sum(confusion_matrix[i]) - true_positive

        recall = true_positive / (true_positive + false_negative)
        recalls.append(recall)
    
    return recalls

# %%
# function to display the recall score
def display_recall(recalls):
    print('Recall Scores for each class:')
    print('Analysis:', recalls[0])
    print('Backdoor:', recalls[1])
    print('DoS:', recalls[2])
    print('Exploits:', recalls[3])
    print('Fuzzers:', recalls[4])
    print('Generic:', recalls[5])
    print('Reconnaissance:', recalls[6])
    print('Shellcode:', recalls[7])
    print('Worms:', recalls[8])

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test_categorical, predicted_classes)
matrix_df = pd.DataFrame(matrix, 
                         index= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'], 
                         columns= ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'])

# %%
# Plotting Confusion Matrix
plt.figure(figsize = (20, 20))
sns.heatmap(matrix_df, fmt='.0f', annot=True)
plt.title('Confusion Matrix (1D CNN)')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
recalls = calculate_recall(matrix)
display_recall(recalls)
# Out:
# Recall Scores for each class:
# Analysis: 0.1005
# Backdoor: 0.1013745704467354
# DoS: 0.6570706246941771
# Exploits: 0.44033427185047624
# Fuzzers: 0.7132644082710075
# Generic: 0.9777494437360934
# Reconnaissance: 0.4292115549623415
# Shellcode: 0.8375992939099736
# Worms: 0.16923076923076924

# %% [markdown]
# ## Save and load the model

# %%
from keras.models import load_model

# %%
# save the 1D CNN trained model using keras
model.save('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/cnn1d.keras')

# %%
# load the 1D CNN trained model using keras
model = load_model('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/cnn1d.keras')

# %% [markdown]
# ## Save and load the predicted

# %%
import pickle

# %%
# save the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/predicted_classes.pkl', 'wb') as model_file:
    pickle.dump(predicted_classes, model_file)

# %%
# load the decision tree trained model
with open('/Data/Visual Studio Code/Data Science/Notebook/UNSW-NB15/CNN/Balanced/BorderlineSMOTE/Saved/predicted_classes.pkl', 'rb') as model_file:
    predicted_classes = pickle.load(model_file)
